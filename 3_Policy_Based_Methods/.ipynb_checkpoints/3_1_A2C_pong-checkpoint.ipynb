# %% [markdown]
# ## 필요한 모듈 설치 확인

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import random
import os
import pickle
import time
from collections import deque

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from wrappers import wrap, wrap_cover, SubprocVecEnv
from runner import Runner

# %% [markdown]
# ## 하이퍼 파라미터 정의하기

# %%
'''A2C Settings'''
TRAJ_LEN = 100
ENT_COEF = 1e-2
LAMBDA = 0.95

'''Environment Settings'''
# sequential images to define state
STATE_LEN = 4
# openai gym env name
ENV_NAME = 'PongNoFrameskip-v4'
# number of environments for A2C
N_ENVS = 4
# define gym 
env = SubprocVecEnv([wrap_cover(ENV_NAME) for i in range(N_ENVS)])
# check gym setting
N_ACTIONS = env.action_space.n;print('N_ACTIONS : ',N_ACTIONS) #  6
N_STATES = env.observation_space.shape;print('N_STATES : ',N_STATES) # (4, 84, 84)
# Total simulation step
N_STEP = 10**7
# gamma for MDP
GAMMA = 0.99
# visualize for agent playing
RENDERING = False

'''Training settings'''
# check GPU usage
USE_GPU = torch.cuda.is_available()
print('USE GPU: '+str(USE_GPU))
# learning rage
LR = 1e-4
# clip gradient
MAX_GRAD_NORM = 0.1
# log optimization
LOG_OPT = False

'''Save&Load Settings'''
# log frequency
LOG_FREQ = 100
# check save/load
SAVE = True
LOAD = False
# paths for predction net, target net, result log
NET_PATH = './data/model/a2c_net.pkl'
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# N_ACTIONS :  6
# N_STATES :  (4, 84, 84)
# USE GPU: True
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## 네트워크 구조 정의하기

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc = nn.Linear(7 * 7 * 64, 256)
        # actor
        self.actor = nn.Linear(256, N_ACTIONS)
        # critic
        self.critic = nn.Linear(256, 1)
            
        # parameter initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc(x))
        # use log_softmax for numerical stability
        action_log_prob = F.log_softmax(self.actor(x), dim=1)
        state_value = self.critic(x)

        return action_log_prob, state_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## A2C 정의하기

# %%
class A2C:
    def __init__(self):
        self.net = ConvNet()
        # use gpu
        if USE_GPU:
            self.net = self.net.cuda()
            
        # simulator step conter
        self.memory_counter = 0
        
        # define optimizer
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=LR)
        
    def save_model(self):
        self.net.cpu()
        self.net.save(NET_PATH)
        if USE_GPU:
            self.net.cuda()
            
    def load_model(self):
        self.net.cpu()
        self.net.load(NET_PATH)
        if USE_GPU:
            self.net.cuda()
        
    def choose_action(self, x):
        self.memory_counter += 1
        # Assume that x is a np.array of shape (nenvs, 4, 84, 84)
        x = torch.FloatTensor(x)
        if USE_GPU:
            x = x.cuda()
        # get action log probs and state values
        action_log_probs, state_values = self.net(x) # (nenvs, N_ACTIONS)
        probs = F.softmax(action_log_probs, dim=1).data.cpu().numpy()
        probs = (probs+1e-8)/np.sum((probs+1e-8), axis=1, keepdims=True)
        # sample actions
        actions = np.array([np.random.choice(N_ACTIONS,p=probs[i]) for i in range(len(probs))])
        # convert tensor to np.array
        action_log_probs , state_values = action_log_probs.data.cpu().numpy() , state_values.squeeze(1).data.cpu().numpy()
        # calc selected logprob
        selected_log_probs = np.array([action_log_probs[i][actions[i]] for i in range(len(probs))])
        return actions, state_values, selected_log_probs

    def learn(self, obs, returns, masks, actions, values, selected_log_probs):
        
        # calculate the advantages
        advs = returns - values
        
        # np.array -> torch.Tensor
        obs = torch.FloatTensor(obs) # (m, 4, 84, 84)
        returns = torch.FloatTensor(returns) # (m)
        advs = torch.FloatTensor(advs) # (m)
        actions = torch.LongTensor(actions) # (m)
        selected_log_probs = torch.FloatTensor(selected_log_probs) # (m)
        values = torch.FloatTensor(values) # (m)
        if USE_GPU:
            obs = obs.cuda()
            returns = returns.cuda()
            advs = advs.cuda()
            actions = actions.cuda()
            selected_log_probs = selected_log_probs.cuda()
            values = values.cuda()
        
        # get action log probs and state values
        action_log_probs, state_values = self.net(obs)
        # (m, N_ACTIONS), (m, 1)
        
        # calc probs
        probs = F.softmax(action_log_probs, dim=1)
        # (m, N_ACTIONS)
        
        # calc entropy loss
        ent_loss = ENT_COEF *((action_log_probs * probs).sum(dim=1)).mean()
        # (1)
        
        # calc log probs
        cur_log_probs = action_log_probs.gather(1,actions.unsqueeze(1))
        # cur : (m, 1)
        
        # actor loss
        actor_loss = torch.mean(- cur_log_probs.squeeze(1) * advs) # (1)
        # critic loss
        critic_loss = F.smooth_l1_loss(state_values.squeeze(1), returns) # (1)

        loss = actor_loss + critic_loss + ent_loss # (1)
        
        actor_loss, critic_loss, ent_loss, total_loss = actor_loss.data.cpu().numpy(), \
        critic_loss.data.cpu().numpy(), ent_loss.data.cpu().numpy(), loss.data.cpu().numpy()

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.net.parameters(), MAX_GRAD_NORM)
        self.optimizer.step()
        
        return round(float(actor_loss), 4), round(float(critic_loss), 4),\
    round(float(ent_loss), 4), round(float(total_loss), 4)

# %% [markdown]
# ## 학습

# %%
a2c = A2C()
runner = Runner(env=env, model=a2c, nsteps=TRAJ_LEN, gamma=GAMMA, lam=LAMBDA)

# model load with check
if LOAD and os.path.isfile(PRED_PATH) and os.path.isfile(TARGET_PATH):
    a2c.load_model()
    pkl_file = open(RESULT_PATH,'rb')
    result = pickle.load(pkl_file)
    pkl_file.close()
    print('Load complete!')
else:
    result = []
    print('Initialize results!')

print('Collecting experience...')

# episode step for accumulate reward 
epinfobuf = deque(maxlen=100)
# in A2C, we iterate over optimization step
nbatch = N_ENVS * TRAJ_LEN
nupdates = N_STEP// nbatch
# check learning time
start_time = time.time()

for update in range(1, nupdates+1):
    # get minibatch
    obs, returns, masks, actions, values, neglogpacs, epinfos = runner.run()
    epinfobuf.extend(epinfos)
    slices = (obs, returns, masks, actions, values, neglogpacs)
    actor_loss, critic_loss, ent_loss, total_loss = a2c.learn(*slices)
    
    # print opt log
    if LOG_OPT and update % LOG_FREQ == 0:
        print('Iter ',_,
             'actor loss : ',round(actor_loss, 3),
             'critic loss : ', round(critic_loss, 3),
             'ent loss : ', round(ent_loss, 3),
             'total loss : ', round(total_loss, 3))
            
    if update % LOG_FREQ == 0:
        # print log and save
        # check time interval
        time_interval = round(time.time() - start_time, 2)
        # calc mean return
        mean_100_ep_return = round(np.mean([epinfo['r'] for epinfo in epinfobuf]),2)
        result.append(mean_100_ep_return)
        # print epi log
        print('N update: ',update,
              '| Mean ep 100 return: ', mean_100_ep_return,
              '/Used Time:',time_interval,
              '/Used Step:',a2c.memory_counter*N_ENVS)
        # save model
        if SAVE:
            a2c.save_model()
# Out:
# Initialize results!
# Collecting experience...
# N update:  100 | Mean ep 100 return:  -20.64 /Used Time: 41.05 /Used Step: 40400
# N update:  200 | Mean ep 100 return:  -20.6 /Used Time: 82.13 /Used Step: 80800
# N update:  300 | Mean ep 100 return:  -20.44 /Used Time: 123.16 /Used Step: 121200
# N update:  400 | Mean ep 100 return:  -20.33 /Used Time: 163.98 /Used Step: 161600
# N update:  500 | Mean ep 100 return:  -20.44 /Used Time: 204.74 /Used Step: 202000
# N update:  600 | Mean ep 100 return:  -20.56 /Used Time: 245.34 /Used Step: 242400
# N update:  700 | Mean ep 100 return:  -20.47 /Used Time: 285.18 /Used Step: 282800
# N update:  800 | Mean ep 100 return:  -20.36 /Used Time: 325.31 /Used Step: 323200
# N update:  900 | Mean ep 100 return:  -20.52 /Used Time: 365.08 /Used Step: 363600
# N update:  1000 | Mean ep 100 return:  -20.51 /Used Time: 404.96 /Used Step: 404000
# N update:  1100 | Mean ep 100 return:  -20.32 /Used Time: 444.78 /Used Step: 444400
# N update:  1200 | Mean ep 100 return:  -20.38 /Used Time: 484.59 /Used Step: 484800
# N update:  1300 | Mean ep 100 return:  -20.37 /Used Time: 524.72 /Used Step: 525200
# N update:  1400 | Mean ep 100 return:  -20.48 /Used Time: 564.86 /Used Step: 565600
# N update:  1500 | Mean ep 100 return:  -20.4 /Used Time: 605.07 /Used Step: 606000
# N update:  1600 | Mean ep 100 return:  -20.23 /Used Time: 645.67 /Used Step: 646400
# N update:  1700 | Mean ep 100 return:  -20.42 /Used Time: 686.53 /Used Step: 686800
# N update:  1800 | Mean ep 100 return:  -20.58 /Used Time: 727.12 /Used Step: 727200
# N update:  1900 | Mean ep 100 return:  -20.51 /Used Time: 767.78 /Used Step: 767600
# N update:  2000 | Mean ep 100 return:  -20.39 /Used Time: 808.96 /Used Step: 808000
# N update:  2100 | Mean ep 100 return:  -20.12 /Used Time: 850.06 /Used Step: 848400
# N update:  2200 | Mean ep 100 return:  -20.07 /Used Time: 891.26 /Used Step: 888800
# N update:  2300 | Mean ep 100 return:  -20.04 /Used Time: 932.64 /Used Step: 929200
# N update:  2400 | Mean ep 100 return:  -19.98 /Used Time: 974.09 /Used Step: 969600
# N update:  2500 | Mean ep 100 return:  -19.97 /Used Time: 1015.24 /Used Step: 1010000
# N update:  2600 | Mean ep 100 return:  -20.0 /Used Time: 1056.29 /Used Step: 1050400
# N update:  2700 | Mean ep 100 return:  -19.94 /Used Time: 1097.33 /Used Step: 1090800
# N update:  2800 | Mean ep 100 return:  -19.91 /Used Time: 1138.01 /Used Step: 1131200
# N update:  2900 | Mean ep 100 return:  -20.01 /Used Time: 1178.5 /Used Step: 1171600
# N update:  12700 | Mean ep 100 return:  -10.98 /Used Time: 4704.62 /Used Step: 5130800
# N update:  12800 | Mean ep 100 return:  -10.93 /Used Time: 4738.95 /Used Step: 5171200
# N update:  12900 | Mean ep 100 return:  -11.18 /Used Time: 4773.32 /Used Step: 5211600
# N update:  13000 | Mean ep 100 return:  -11.17 /Used Time: 4808.14 /Used Step: 5252000
# N update:  13100 | Mean ep 100 return:  -11.49 /Used Time: 4843.04 /Used Step: 5292400
# N update:  13200 | Mean ep 100 return:  -11.36 /Used Time: 4877.57 /Used Step: 5332800
# N update:  13300 | Mean ep 100 return:  -10.42 /Used Time: 4911.93 /Used Step: 5373200
# N update:  13400 | Mean ep 100 return:  -10.27 /Used Time: 4946.35 /Used Step: 5413600
# N update:  13500 | Mean ep 100 return:  -9.51 /Used Time: 4981.03 /Used Step: 5454000
# N update:  13600 | Mean ep 100 return:  -9.21 /Used Time: 5015.33 /Used Step: 5494400
# N update:  13700 | Mean ep 100 return:  -8.34 /Used Time: 5050.42 /Used Step: 5534800
# N update:  13800 | Mean ep 100 return:  -7.7 /Used Time: 5084.68 /Used Step: 5575200
# N update:  13900 | Mean ep 100 return:  -7.28 /Used Time: 5119.02 /Used Step: 5615600
# N update:  14000 | Mean ep 100 return:  -6.92 /Used Time: 5153.27 /Used Step: 5656000
# N update:  14100 | Mean ep 100 return:  -6.31 /Used Time: 5188.12 /Used Step: 5696400
# N update:  14200 | Mean ep 100 return:  -6.08 /Used Time: 5222.52 /Used Step: 5736800
# N update:  14300 | Mean ep 100 return:  -5.68 /Used Time: 5256.71 /Used Step: 5777200
# N update:  14400 | Mean ep 100 return:  -5.26 /Used Time: 5290.9 /Used Step: 5817600
# N update:  14500 | Mean ep 100 return:  -4.79 /Used Time: 5325.1 /Used Step: 5858000
# N update:  14600 | Mean ep 100 return:  -4.27 /Used Time: 5359.11 /Used Step: 5898400
# N update:  14700 | Mean ep 100 return:  -3.67 /Used Time: 5393.41 /Used Step: 5938800
# N update:  14800 | Mean ep 100 return:  -3.32 /Used Time: 5427.91 /Used Step: 5979200
# N update:  14900 | Mean ep 100 return:  -2.95 /Used Time: 5462.25 /Used Step: 6019600
# N update:  15000 | Mean ep 100 return:  -2.27 /Used Time: 5496.95 /Used Step: 6060000
# N update:  15100 | Mean ep 100 return:  -1.67 /Used Time: 5531.39 /Used Step: 6100400
# N update:  15200 | Mean ep 100 return:  -1.32 /Used Time: 5565.55 /Used Step: 6140800
# N update:  15300 | Mean ep 100 return:  -0.78 /Used Time: 5599.92 /Used Step: 6181200
# N update:  15400 | Mean ep 100 return:  -0.42 /Used Time: 5634.11 /Used Step: 6221600
# N update:  15500 | Mean ep 100 return:  0.17 /Used Time: 5669.18 /Used Step: 6262000
# N update:  15600 | Mean ep 100 return:  0.7 /Used Time: 5703.33 /Used Step: 6302400
# N update:  15700 | Mean ep 100 return:  1.43 /Used Time: 5737.45 /Used Step: 6342800
# N update:  15800 | Mean ep 100 return:  1.52 /Used Time: 5771.67 /Used Step: 6383200
# N update:  15900 | Mean ep 100 return:  2.43 /Used Time: 5806.54 /Used Step: 6423600
# N update:  22600 | Mean ep 100 return:  17.73 /Used Time: 8120.31 /Used Step: 9130400
# N update:  22700 | Mean ep 100 return:  17.99 /Used Time: 8155.19 /Used Step: 9170800
# N update:  22800 | Mean ep 100 return:  18.25 /Used Time: 8189.24 /Used Step: 9211200
# N update:  22900 | Mean ep 100 return:  18.57 /Used Time: 8224.27 /Used Step: 9251600
# N update:  23000 | Mean ep 100 return:  18.82 /Used Time: 8258.96 /Used Step: 9292000
# N update:  23100 | Mean ep 100 return:  18.9 /Used Time: 8293.57 /Used Step: 9332400
# N update:  23200 | Mean ep 100 return:  18.95 /Used Time: 8327.84 /Used Step: 9372800
# N update:  23300 | Mean ep 100 return:  18.75 /Used Time: 8361.79 /Used Step: 9413200
# N update:  23400 | Mean ep 100 return:  18.67 /Used Time: 8395.98 /Used Step: 9453600
# N update:  23500 | Mean ep 100 return:  18.83 /Used Time: 8431.16 /Used Step: 9494000
# N update:  23600 | Mean ep 100 return:  18.77 /Used Time: 8465.61 /Used Step: 9534400
# N update:  23700 | Mean ep 100 return:  18.39 /Used Time: 8500.1 /Used Step: 9574800
# N update:  23800 | Mean ep 100 return:  18.5 /Used Time: 8534.87 /Used Step: 9615200
# N update:  23900 | Mean ep 100 return:  18.56 /Used Time: 8569.34 /Used Step: 9655600
# N update:  24000 | Mean ep 100 return:  18.48 /Used Time: 8603.85 /Used Step: 9696000
# N update:  24100 | Mean ep 100 return:  18.17 /Used Time: 8638.44 /Used Step: 9736400
# N update:  24200 | Mean ep 100 return:  18.55 /Used Time: 8673.22 /Used Step: 9776800
# N update:  24300 | Mean ep 100 return:  18.08 /Used Time: 8707.92 /Used Step: 9817200
# N update:  24400 | Mean ep 100 return:  17.71 /Used Time: 8742.17 /Used Step: 9857600
# N update:  24500 | Mean ep 100 return:  17.44 /Used Time: 8776.91 /Used Step: 9898000
# N update:  24600 | Mean ep 100 return:  17.77 /Used Time: 8811.9 /Used Step: 9938400
# N update:  24700 | Mean ep 100 return:  17.75 /Used Time: 8846.43 /Used Step: 9978800
# N update:  24800 | Mean ep 100 return:  17.81 /Used Time: 8880.89 /Used Step: 10019200
# N update:  24900 | Mean ep 100 return:  18.34 /Used Time: 8915.31 /Used Step: 10059600
# N update:  25000 | Mean ep 100 return:  18.16 /Used Time: 8950.11 /Used Step: 10100000

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot(range(len(result)), result)
plt.tight_layout()
plt.show()

# %%
from matplotlib import animation

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./a2c_pong_result.gif', writer='imagemagick', fps=30)

# %%
env = wrap(gym.make('PongNoFrameskip-v4'))
s = np.array(env.reset())
total_reward = 0
frames = []

for t in range(10000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    a, v, l = a2c.choose_action(np.expand_dims(s,axis=0))
    # take action and get next state
    s_, r, done, info = env.step(a)
    s_ = np.array(s_)
    total_reward += r
    if done:
        break
    s = s_
env.close()
print('Total Reward : %.2f'%total_reward)
display_frames_as_gif(frames)
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Total Reward : 18.00

# %% [markdown]
# ![alt text](./a2c_pong_result.gif "segment")
