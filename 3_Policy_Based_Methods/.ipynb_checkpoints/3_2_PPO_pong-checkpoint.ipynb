# %% [markdown]
# ## 필요한 모듈 설치 확인

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import random
import os
import pickle
import time
from collections import deque

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from wrappers import wrap_cover, SubprocVecEnv
from runner import Runner

# %% [markdown]
# ## 하이퍼 파라미터 정의하기

# %%
'''PPO Settings'''
TRAJ_LEN = 1000
N_OPT_EPOCHS = 4
ENT_COEF = 1e-2
CLIP_RANGE = 0.1
LAMBDA = 0.95

'''Environment Settings'''
# sequential images to define state
STATE_LEN = 4
# openai gym env name
ENV_NAME = 'PongNoFrameskip-v4'
# number of environments for A2C
N_ENVS = 4
# define gym 
env = SubprocVecEnv([wrap_cover(ENV_NAME) for i in range(N_ENVS)])
# check gym setting
N_ACTIONS = env.action_space.n;print('N_ACTIONS : ',N_ACTIONS) #  6
N_STATES = env.observation_space.shape;print('N_STATES : ',N_STATES) # (4, 84, 84)
# Total simulation step
N_STEP = 10**7
# gamma for MDP
GAMMA = 0.99
# visualize for agent playing
RENDERING = False

'''Training settings'''
# check GPU usage
USE_GPU = torch.cuda.is_available()
print('USE GPU: '+str(USE_GPU))
# mini-batch size
BATCH_SIZE = 32
# learning rage
LR = 1e-4
# clip gradient
MAX_GRAD_NORM = 0.1
# log optimization
LOG_OPT = False

'''Save&Load Settings'''
# log frequency
LOG_FREQ = 10
# check save/load
SAVE = True
LOAD = False
# paths for predction net, target net, result log
NET_PATH = './data/model/ppo_net.pkl'
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# N_ACTIONS :  6
# N_STATES :  (4, 84, 84)
# USE GPU: True
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## 네트워크 구조 정의하기

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc = nn.Linear(7 * 7 * 64, 256)
        # actor
        self.actor = nn.Linear(256, N_ACTIONS)
        # critic
        self.critic = nn.Linear(256, 1)
            
        # parameter initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc(x))
        # use log_softmax for numerical stability
        action_log_prob = F.log_softmax(self.actor(x), dim=1)
        state_value = self.critic(x)

        return action_log_prob, state_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## PPO 정의하기

# %%
class PPO:
    def __init__(self):
        self.net = ConvNet()
        # use gpu
        if USE_GPU:
            self.net = self.net.cuda()
            
        # simulator step conter
        self.memory_counter = 0
        
        # define optimizer
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=LR)
        
        # ppo clip range
        self.clip_range = CLIP_RANGE
        
    def save_model(self):
        self.net.cpu()
        self.net.save(NET_PATH)
        if USE_GPU:
            self.net.cuda()
            
    def load_model(self):
        self.net.cpu()
        self.net.load(NET_PATH)
        if USE_GPU:
            self.net.cuda()
        
    def choose_action(self, x):
        self.memory_counter += 1
        # Assume that x is a np.array of shape (nenvs, 4, 84, 84)
        x = torch.FloatTensor(x)
        if USE_GPU:
            x = x.cuda()
        # get action log probs and state values
        action_log_probs, state_values = self.net(x) # (nenvs, N_ACTIONS)
        probs = F.softmax(action_log_probs, dim=1).data.cpu().numpy()
        probs = (probs+1e-8)/np.sum((probs+1e-8), axis=1, keepdims=True)
        # sample actions
        actions = np.array([np.random.choice(N_ACTIONS,p=probs[i]) for i in range(len(probs))])
        # convert tensor to np.array
        action_log_probs , state_values = action_log_probs.data.cpu().numpy() , state_values.squeeze(1).data.cpu().numpy()
        # calc selected logprob
        selected_log_probs = np.array([action_log_probs[i][actions[i]] for i in range(len(probs))])
        return actions, state_values, selected_log_probs

    def learn(self, obs, returns, masks, actions, values, selected_log_probs):
        
        # calculate the advantages
        advs = returns - values
        
        # np.array -> torch.Tensor
        obs = torch.FloatTensor(obs) # (m, 4, 84, 84)
        returns = torch.FloatTensor(returns) # (m)
        advs = torch.FloatTensor(advs) # (m)
        actions = torch.LongTensor(actions) # (m)
        selected_log_probs = torch.FloatTensor(selected_log_probs) # (m)
        values = torch.FloatTensor(values) # (m)
        if USE_GPU:
            obs = obs.cuda()
            returns = returns.cuda()
            advs = advs.cuda()
            actions = actions.cuda()
            selected_log_probs = selected_log_probs.cuda()
            values = values.cuda()
        
        # get action log probs and state values
        action_log_probs, state_values = self.net(obs)
        # (m, N_ACTIONS), (m, 1)
        
        # calc probs
        probs = F.softmax(action_log_probs, dim=1)
        # (m, N_ACTIONS)
        
        # calc entropy loss
        ent_loss = ENT_COEF *((action_log_probs * probs).sum(dim=1)).mean()
        # (1)
        
        # calc log probs
        cur_log_probs = action_log_probs.gather(1,actions.unsqueeze(1))
        # cur : (m, 1)
        ratio = torch.exp(cur_log_probs.squeeze(1)-selected_log_probs)
        # (m)
        
        # actor loss
        surr1 = ratio * advs # (m)
        surr2 = torch.clamp(ratio, 1.0 - self.clip_range, 1.0 + self.clip_range)*advs # (m)
        actor_loss = -torch.min(surr1, surr2).mean() # (1)
        # critic loss
        critic_loss = F.smooth_l1_loss(state_values.squeeze(1), returns) # (1)

        loss = actor_loss + critic_loss + ent_loss # (1)
        
        actor_loss, critic_loss, ent_loss, total_loss = actor_loss.data.cpu().numpy(), \
        critic_loss.data.cpu().numpy(), ent_loss.data.cpu().numpy(), loss.data.cpu().numpy()

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.net.parameters(), MAX_GRAD_NORM)
        self.optimizer.step()
        
        return round(float(actor_loss), 4), round(float(critic_loss), 4),\
    round(float(ent_loss), 4), round(float(total_loss), 4)

# %% [markdown]
# ## 학습

# %%
ppo = PPO()
runner = Runner(env=env, model=ppo, nsteps=TRAJ_LEN, gamma=GAMMA, lam=LAMBDA)

# model load with check
if LOAD and os.path.isfile(PRED_PATH) and os.path.isfile(TARGET_PATH):
    ppo.load_model()
    pkl_file = open(RESULT_PATH,'rb')
    result = pickle.load(pkl_file)
    pkl_file.close()
    print('Load complete!')
else:
    result = []
    print('Initialize results!')

print('Collecting experience...')

# episode step for accumulate reward 
epinfobuf = deque(maxlen=100)
# in PPO, we iterate over optimization step
nbatch = N_ENVS * TRAJ_LEN
nupdates = N_STEP// nbatch
# check learning time
start_time = time.time()

for update in range(1, nupdates+1):
    # get minibatch
    obs, returns, masks, actions, values, neglogpacs, epinfos = runner.run()
    epinfobuf.extend(epinfos)
    
    # calculate loss
    inds = np.arange(nbatch)
    for _ in range(N_OPT_EPOCHS):
        a_losses, c_losses, e_losses, t_losses = list(), list(), list(), list()
        # shuffle indices for i.i.d.
        np.random.shuffle(inds)
        # 0 to batch_size with batch_train_size step
        for start in range(0, nbatch, BATCH_SIZE):
            end = start + BATCH_SIZE
            mbinds = inds[start:end]
            slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
            actor_loss, critic_loss, ent_loss, total_loss = ppo.learn(*slices)
            # save opt log
            a_losses.append(actor_loss)
            c_losses.append(critic_loss)
            e_losses.append(ent_loss)
            t_losses.append(total_loss)
        # print opt log
        if LOG_OPT:
            print('Iter ',_,
                 'actor loss : ',round(float(np.mean(a_losses)), 3),
                 'critic loss : ', round(float(np.mean(c_losses)), 3),
                 'ent loss : ', round(float(np.mean(e_losses)), 3),
                 'total loss : ', round(float(np.mean(t_losses)), 3))
            
    if update % LOG_FREQ == 0:
        # print log and save
        # check time interval
        time_interval = round(time.time() - start_time, 2)
        # calc mean return
        mean_100_ep_return = round(np.mean([epinfo['r'] for epinfo in epinfobuf]),2)
        result.append(mean_100_ep_return)
        # print epi log
        print('N update: ',update,
              '| Mean ep 100 return: ', mean_100_ep_return,
              '/Used Time:',time_interval,
              '/Used Step:',ppo.memory_counter*N_ENVS)
        # save model
        if SAVE:
            ppo.save_model()
# Out:
# Initialize results!
# Collecting experience...
# N update:  10 | Mean ep 100 return:  -20.23 /Used Time: 66.1 /Used Step: 40040
# N update:  20 | Mean ep 100 return:  -20.26 /Used Time: 133.16 /Used Step: 80080
# N update:  30 | Mean ep 100 return:  -20.03 /Used Time: 199.95 /Used Step: 120120
# N update:  40 | Mean ep 100 return:  -19.86 /Used Time: 266.74 /Used Step: 160160
# N update:  50 | Mean ep 100 return:  -19.47 /Used Time: 332.46 /Used Step: 200200
# N update:  60 | Mean ep 100 return:  -19.27 /Used Time: 398.73 /Used Step: 240240
# N update:  70 | Mean ep 100 return:  -18.66 /Used Time: 464.97 /Used Step: 280280
# N update:  80 | Mean ep 100 return:  -18.12 /Used Time: 531.95 /Used Step: 320320
# N update:  90 | Mean ep 100 return:  -17.32 /Used Time: 598.32 /Used Step: 360360
# N update:  100 | Mean ep 100 return:  -16.7 /Used Time: 665.58 /Used Step: 400400
# N update:  110 | Mean ep 100 return:  -15.97 /Used Time: 732.04 /Used Step: 440440
# N update:  120 | Mean ep 100 return:  -14.85 /Used Time: 798.18 /Used Step: 480480
# N update:  130 | Mean ep 100 return:  -13.25 /Used Time: 863.15 /Used Step: 520520
# N update:  140 | Mean ep 100 return:  -11.4 /Used Time: 928.94 /Used Step: 560560
# N update:  150 | Mean ep 100 return:  -9.62 /Used Time: 994.71 /Used Step: 600600
# N update:  160 | Mean ep 100 return:  -7.68 /Used Time: 1059.92 /Used Step: 640640
# N update:  170 | Mean ep 100 return:  -6.06 /Used Time: 1125.82 /Used Step: 680680
# N update:  180 | Mean ep 100 return:  -4.83 /Used Time: 1191.27 /Used Step: 720720
# N update:  190 | Mean ep 100 return:  -4.49 /Used Time: 1256.45 /Used Step: 760760
# N update:  200 | Mean ep 100 return:  -4.5 /Used Time: 1321.89 /Used Step: 800800
# N update:  210 | Mean ep 100 return:  -4.51 /Used Time: 1387.26 /Used Step: 840840
# N update:  220 | Mean ep 100 return:  -4.2 /Used Time: 1452.45 /Used Step: 880880
# N update:  230 | Mean ep 100 return:  -3.57 /Used Time: 1517.7 /Used Step: 920920
# N update:  240 | Mean ep 100 return:  -3.54 /Used Time: 1582.9 /Used Step: 960960
# N update:  250 | Mean ep 100 return:  -3.24 /Used Time: 1648.08 /Used Step: 1001000
# N update:  260 | Mean ep 100 return:  -3.62 /Used Time: 1713.8 /Used Step: 1041040
# N update:  270 | Mean ep 100 return:  -3.66 /Used Time: 1778.74 /Used Step: 1081080
# N update:  280 | Mean ep 100 return:  -3.8 /Used Time: 1844.39 /Used Step: 1121120
# N update:  290 | Mean ep 100 return:  -3.97 /Used Time: 1909.98 /Used Step: 1161160
# N update:  300 | Mean ep 100 return:  -4.18 /Used Time: 1975.73 /Used Step: 1201200
# N update:  310 | Mean ep 100 return:  -4.49 /Used Time: 2040.85 /Used Step: 1241240
# N update:  320 | Mean ep 100 return:  -4.37 /Used Time: 2106.17 /Used Step: 1281280
# N update:  330 | Mean ep 100 return:  -4.27 /Used Time: 2171.71 /Used Step: 1321320
# N update:  340 | Mean ep 100 return:  -4.46 /Used Time: 2237.27 /Used Step: 1361360
# N update:  350 | Mean ep 100 return:  -4.71 /Used Time: 2302.61 /Used Step: 1401400
# N update:  360 | Mean ep 100 return:  -4.53 /Used Time: 2368.25 /Used Step: 1441440
# N update:  370 | Mean ep 100 return:  -4.69 /Used Time: 2433.87 /Used Step: 1481480
# N update:  380 | Mean ep 100 return:  -4.61 /Used Time: 2499.28 /Used Step: 1521520
# N update:  390 | Mean ep 100 return:  -4.56 /Used Time: 2564.61 /Used Step: 1561560
# N update:  400 | Mean ep 100 return:  -4.4 /Used Time: 2630.51 /Used Step: 1601600
# N update:  410 | Mean ep 100 return:  -4.35 /Used Time: 2696.04 /Used Step: 1641640
# N update:  420 | Mean ep 100 return:  -4.32 /Used Time: 2761.56 /Used Step: 1681680
# N update:  430 | Mean ep 100 return:  -4.45 /Used Time: 2827.17 /Used Step: 1721720
# N update:  440 | Mean ep 100 return:  -4.19 /Used Time: 2892.74 /Used Step: 1761760
# N update:  450 | Mean ep 100 return:  -4.41 /Used Time: 2957.56 /Used Step: 1801800
# N update:  460 | Mean ep 100 return:  -4.43 /Used Time: 3022.42 /Used Step: 1841840
# N update:  470 | Mean ep 100 return:  -4.35 /Used Time: 3088.02 /Used Step: 1881880
# N update:  480 | Mean ep 100 return:  -4.21 /Used Time: 3153.59 /Used Step: 1921920
# N update:  490 | Mean ep 100 return:  -4.13 /Used Time: 3218.97 /Used Step: 1961960
# N update:  500 | Mean ep 100 return:  -3.98 /Used Time: 3283.81 /Used Step: 2002000
# N update:  510 | Mean ep 100 return:  -3.81 /Used Time: 3348.99 /Used Step: 2042040
# N update:  520 | Mean ep 100 return:  -3.65 /Used Time: 3414.51 /Used Step: 2082080
# N update:  530 | Mean ep 100 return:  -3.45 /Used Time: 3480.2 /Used Step: 2122120
# N update:  540 | Mean ep 100 return:  -3.08 /Used Time: 3545.27 /Used Step: 2162160
# N update:  550 | Mean ep 100 return:  -2.86 /Used Time: 3610.52 /Used Step: 2202200
# N update:  560 | Mean ep 100 return:  -2.66 /Used Time: 3676.08 /Used Step: 2242240
# N update:  570 | Mean ep 100 return:  -2.17 /Used Time: 3741.27 /Used Step: 2282280
# N update:  580 | Mean ep 100 return:  -1.81 /Used Time: 3806.4 /Used Step: 2322320
# N update:  590 | Mean ep 100 return:  -1.32 /Used Time: 3871.41 /Used Step: 2362360
# N update:  600 | Mean ep 100 return:  -0.26 /Used Time: 3936.56 /Used Step: 2402400
# N update:  610 | Mean ep 100 return:  2.37 /Used Time: 4001.96 /Used Step: 2442440
# N update:  620 | Mean ep 100 return:  4.59 /Used Time: 4067.52 /Used Step: 2482480
# N update:  630 | Mean ep 100 return:  6.96 /Used Time: 4132.91 /Used Step: 2522520
# N update:  640 | Mean ep 100 return:  9.4 /Used Time: 4198.85 /Used Step: 2562560
# N update:  650 | Mean ep 100 return:  11.21 /Used Time: 4263.67 /Used Step: 2602600
# N update:  660 | Mean ep 100 return:  10.88 /Used Time: 4328.87 /Used Step: 2642640
# N update:  670 | Mean ep 100 return:  12.03 /Used Time: 4394.61 /Used Step: 2682680
# N update:  680 | Mean ep 100 return:  12.93 /Used Time: 4460.13 /Used Step: 2722720
# N update:  690 | Mean ep 100 return:  12.52 /Used Time: 4525.01 /Used Step: 2762760
# N update:  700 | Mean ep 100 return:  12.89 /Used Time: 4590.18 /Used Step: 2802800
# N update:  710 | Mean ep 100 return:  12.52 /Used Time: 4656.03 /Used Step: 2842840
# N update:  720 | Mean ep 100 return:  12.34 /Used Time: 4721.09 /Used Step: 2882880
# N update:  730 | Mean ep 100 return:  12.72 /Used Time: 4786.49 /Used Step: 2922920
# N update:  740 | Mean ep 100 return:  12.24 /Used Time: 4852.05 /Used Step: 2962960
# N update:  750 | Mean ep 100 return:  13.52 /Used Time: 4917.73 /Used Step: 3003000
# N update:  760 | Mean ep 100 return:  13.73 /Used Time: 4983.41 /Used Step: 3043040
# N update:  770 | Mean ep 100 return:  14.56 /Used Time: 5048.88 /Used Step: 3083080
# N update:  780 | Mean ep 100 return:  15.24 /Used Time: 5114.18 /Used Step: 3123120
# N update:  790 | Mean ep 100 return:  15.21 /Used Time: 5179.41 /Used Step: 3163160
# N update:  800 | Mean ep 100 return:  14.99 /Used Time: 5244.25 /Used Step: 3203200
# N update:  810 | Mean ep 100 return:  14.58 /Used Time: 5309.61 /Used Step: 3243240
# N update:  820 | Mean ep 100 return:  13.4 /Used Time: 5375.07 /Used Step: 3283280
# N update:  830 | Mean ep 100 return:  13.53 /Used Time: 5440.28 /Used Step: 3323320
# N update:  840 | Mean ep 100 return:  12.74 /Used Time: 5505.42 /Used Step: 3363360
# N update:  850 | Mean ep 100 return:  12.93 /Used Time: 5570.8 /Used Step: 3403400
# N update:  860 | Mean ep 100 return:  13.87 /Used Time: 5636.04 /Used Step: 3443440
# N update:  870 | Mean ep 100 return:  13.29 /Used Time: 5700.96 /Used Step: 3483480
# N update:  880 | Mean ep 100 return:  14.41 /Used Time: 5766.59 /Used Step: 3523520
# N update:  890 | Mean ep 100 return:  14.82 /Used Time: 5831.91 /Used Step: 3563560
# N update:  900 | Mean ep 100 return:  14.69 /Used Time: 5897.42 /Used Step: 3603600
# N update:  910 | Mean ep 100 return:  15.22 /Used Time: 5962.88 /Used Step: 3643640
# N update:  920 | Mean ep 100 return:  15.1 /Used Time: 6027.87 /Used Step: 3683680
# N update:  930 | Mean ep 100 return:  15.04 /Used Time: 6093.38 /Used Step: 3723720
# N update:  940 | Mean ep 100 return:  15.37 /Used Time: 6158.69 /Used Step: 3763760
# N update:  950 | Mean ep 100 return:  15.5 /Used Time: 6223.93 /Used Step: 3803800
# N update:  960 | Mean ep 100 return:  14.54 /Used Time: 6289.21 /Used Step: 3843840
# N update:  970 | Mean ep 100 return:  13.59 /Used Time: 6354.55 /Used Step: 3883880
# N update:  980 | Mean ep 100 return:  13.54 /Used Time: 6419.9 /Used Step: 3923920
# N update:  990 | Mean ep 100 return:  13.55 /Used Time: 6485.35 /Used Step: 3963960
# N update:  1000 | Mean ep 100 return:  13.07 /Used Time: 6550.42 /Used Step: 4004000
# N update:  1010 | Mean ep 100 return:  13.31 /Used Time: 6615.76 /Used Step: 4044040
# N update:  1020 | Mean ep 100 return:  13.55 /Used Time: 6681.19 /Used Step: 4084080
# N update:  1030 | Mean ep 100 return:  13.47 /Used Time: 6746.64 /Used Step: 4124120
# N update:  1040 | Mean ep 100 return:  14.21 /Used Time: 6812.22 /Used Step: 4164160
# N update:  1050 | Mean ep 100 return:  15.65 /Used Time: 6877.53 /Used Step: 4204200
# N update:  1060 | Mean ep 100 return:  15.93 /Used Time: 6942.47 /Used Step: 4244240
# N update:  1070 | Mean ep 100 return:  15.36 /Used Time: 7008.06 /Used Step: 4284280
# N update:  1080 | Mean ep 100 return:  15.05 /Used Time: 7073.25 /Used Step: 4324320
# N update:  1090 | Mean ep 100 return:  14.78 /Used Time: 7138.66 /Used Step: 4364360
# N update:  1100 | Mean ep 100 return:  15.16 /Used Time: 7204.24 /Used Step: 4404400
# N update:  1110 | Mean ep 100 return:  15.55 /Used Time: 7270.27 /Used Step: 4444440
# N update:  1120 | Mean ep 100 return:  16.15 /Used Time: 7335.99 /Used Step: 4484480
# N update:  1130 | Mean ep 100 return:  16.39 /Used Time: 7401.55 /Used Step: 4524520
# N update:  1140 | Mean ep 100 return:  16.15 /Used Time: 7466.88 /Used Step: 4564560
# N update:  1150 | Mean ep 100 return:  15.66 /Used Time: 7531.72 /Used Step: 4604600
# N update:  1160 | Mean ep 100 return:  15.9 /Used Time: 7597.24 /Used Step: 4644640
# N update:  1170 | Mean ep 100 return:  15.88 /Used Time: 7662.63 /Used Step: 4684680
# N update:  1180 | Mean ep 100 return:  15.15 /Used Time: 7728.01 /Used Step: 4724720
# N update:  1190 | Mean ep 100 return:  15.16 /Used Time: 7793.51 /Used Step: 4764760
# N update:  1200 | Mean ep 100 return:  15.26 /Used Time: 7858.81 /Used Step: 4804800
# N update:  1210 | Mean ep 100 return:  15.62 /Used Time: 7923.95 /Used Step: 4844840
# N update:  1220 | Mean ep 100 return:  15.63 /Used Time: 7989.79 /Used Step: 4884880
# N update:  1230 | Mean ep 100 return:  16.84 /Used Time: 8054.93 /Used Step: 4924920
# N update:  1240 | Mean ep 100 return:  17.23 /Used Time: 8120.04 /Used Step: 4964960
# N update:  1250 | Mean ep 100 return:  16.65 /Used Time: 8185.31 /Used Step: 5005000
# N update:  1260 | Mean ep 100 return:  17.17 /Used Time: 8250.75 /Used Step: 5045040
# N update:  1270 | Mean ep 100 return:  16.98 /Used Time: 8315.74 /Used Step: 5085080
# N update:  1280 | Mean ep 100 return:  16.95 /Used Time: 8381.06 /Used Step: 5125120
# N update:  1290 | Mean ep 100 return:  17.36 /Used Time: 8445.98 /Used Step: 5165160
# N update:  1300 | Mean ep 100 return:  17.56 /Used Time: 8511.35 /Used Step: 5205200
# N update:  1310 | Mean ep 100 return:  17.22 /Used Time: 8576.81 /Used Step: 5245240
# N update:  1320 | Mean ep 100 return:  17.31 /Used Time: 8642.33 /Used Step: 5285280
# N update:  1330 | Mean ep 100 return:  16.68 /Used Time: 8706.19 /Used Step: 5325320
# N update:  1340 | Mean ep 100 return:  16.59 /Used Time: 8755.81 /Used Step: 5365360
# N update:  1350 | Mean ep 100 return:  16.74 /Used Time: 8805.65 /Used Step: 5405400
# N update:  1360 | Mean ep 100 return:  16.43 /Used Time: 8855.62 /Used Step: 5445440
# N update:  1370 | Mean ep 100 return:  17.23 /Used Time: 8905.56 /Used Step: 5485480
# N update:  1380 | Mean ep 100 return:  17.33 /Used Time: 8955.19 /Used Step: 5525520
# N update:  1390 | Mean ep 100 return:  16.66 /Used Time: 9005.11 /Used Step: 5565560
# N update:  1400 | Mean ep 100 return:  17.05 /Used Time: 9054.87 /Used Step: 5605600
# N update:  1410 | Mean ep 100 return:  17.35 /Used Time: 9105.06 /Used Step: 5645640
# N update:  1420 | Mean ep 100 return:  18.0 /Used Time: 9154.85 /Used Step: 5685680
# N update:  1430 | Mean ep 100 return:  18.03 /Used Time: 9204.57 /Used Step: 5725720
# N update:  1440 | Mean ep 100 return:  17.98 /Used Time: 9254.29 /Used Step: 5765760
# N update:  1450 | Mean ep 100 return:  17.9 /Used Time: 9303.81 /Used Step: 5805800
# N update:  1460 | Mean ep 100 return:  17.42 /Used Time: 9353.62 /Used Step: 5845840
# N update:  1470 | Mean ep 100 return:  17.59 /Used Time: 9403.46 /Used Step: 5885880
# N update:  1480 | Mean ep 100 return:  17.76 /Used Time: 9455.12 /Used Step: 5925920
# N update:  1490 | Mean ep 100 return:  17.89 /Used Time: 9505.42 /Used Step: 5965960
# N update:  1500 | Mean ep 100 return:  18.03 /Used Time: 9556.44 /Used Step: 6006000
# N update:  1510 | Mean ep 100 return:  17.76 /Used Time: 9607.69 /Used Step: 6046040
# N update:  1520 | Mean ep 100 return:  17.7 /Used Time: 9658.96 /Used Step: 6086080
# N update:  1530 | Mean ep 100 return:  18.03 /Used Time: 9709.91 /Used Step: 6126120
# N update:  1540 | Mean ep 100 return:  18.45 /Used Time: 9773.44 /Used Step: 6166160
# N update:  1550 | Mean ep 100 return:  18.91 /Used Time: 9837.13 /Used Step: 6206200
# N update:  1560 | Mean ep 100 return:  18.93 /Used Time: 9909.16 /Used Step: 6246240
# N update:  1570 | Mean ep 100 return:  18.47 /Used Time: 9963.77 /Used Step: 6286280
# N update:  1580 | Mean ep 100 return:  18.52 /Used Time: 10015.29 /Used Step: 6326320
# N update:  1590 | Mean ep 100 return:  18.22 /Used Time: 10069.46 /Used Step: 6366360
# N update:  1600 | Mean ep 100 return:  18.17 /Used Time: 10141.04 /Used Step: 6406400
# N update:  1610 | Mean ep 100 return:  18.13 /Used Time: 10212.72 /Used Step: 6446440
# N update:  1620 | Mean ep 100 return:  18.36 /Used Time: 10284.57 /Used Step: 6486480
# N update:  1630 | Mean ep 100 return:  18.15 /Used Time: 10356.58 /Used Step: 6526520
# N update:  1640 | Mean ep 100 return:  18.67 /Used Time: 10428.81 /Used Step: 6566560
# N update:  1650 | Mean ep 100 return:  18.13 /Used Time: 10495.67 /Used Step: 6606600
# N update:  1660 | Mean ep 100 return:  17.48 /Used Time: 10567.14 /Used Step: 6646640
# N update:  1670 | Mean ep 100 return:  17.41 /Used Time: 10637.43 /Used Step: 6686680
# N update:  1680 | Mean ep 100 return:  17.3 /Used Time: 10704.88 /Used Step: 6726720
# N update:  1690 | Mean ep 100 return:  17.49 /Used Time: 10776.34 /Used Step: 6766760
# N update:  1700 | Mean ep 100 return:  18.35 /Used Time: 10846.22 /Used Step: 6806800
# N update:  1710 | Mean ep 100 return:  18.07 /Used Time: 10910.7 /Used Step: 6846840
# N update:  1720 | Mean ep 100 return:  17.91 /Used Time: 10982.01 /Used Step: 6886880
# N update:  1730 | Mean ep 100 return:  17.59 /Used Time: 11053.18 /Used Step: 6926920

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot(range(len(result)), result)
plt.tight_layout()
plt.show()

# %%
from matplotlib import animation

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./ppo_pong_result.gif', writer='imagemagick', fps=30)

# %%
env = wrap(gym.make('PongNoFrameskip-v4'))
s = np.array(env.reset())
total_reward = 0
frames = []

dqn = DQN()
dqn.load_model()

for t in range(10000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    a = dqn.choose_action(s, 1.0)
    # take action and get next state
    s_, r, done, info = env.step(a)
    s_ = np.array(s_)
    total_reward += r
    if done:
        break
    s = s_
env.close()
print('Total Reward : %.2f'%total_reward)
display_frames_as_gif(frames)

# %% [markdown]
# ![alt text](./ppo_pong_result.gif "segment")
