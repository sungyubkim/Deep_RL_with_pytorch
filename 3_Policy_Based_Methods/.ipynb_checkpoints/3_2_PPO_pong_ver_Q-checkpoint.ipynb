# %% [markdown]
# ## 필요한 모듈 설치 확인

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import random
import os
import pickle
import time
from collections import deque

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from wrappers import wrap, wrap_cover, SubprocVecEnv
from runner import Runner

# %% [markdown]
# ## 하이퍼 파라미터 정의하기

# %%
'''PPO Settings'''
TRAJ_LEN = 1000
N_OPT_EPOCHS = 4
ENT_COEF = 1e-2
CLIP_RANGE = 0.1
LAMBDA = 0.95

'''Environment Settings'''
# sequential images to define state
STATE_LEN = 4
# openai gym env name
ENV_NAME = 'PongNoFrameskip-v4'
# number of environments for A2C
N_ENVS = 4
# define gym 
env = SubprocVecEnv([wrap_cover(ENV_NAME) for i in range(N_ENVS)])
# check gym setting
N_ACTIONS = env.action_space.n;print('N_ACTIONS : ',N_ACTIONS) #  6
N_STATES = env.observation_space.shape;print('N_STATES : ',N_STATES) # (4, 84, 84)
# Total simulation step
N_STEP = 10**7
# gamma for MDP
GAMMA = 0.99
# visualize for agent playing
RENDERING = False

'''Training settings'''
# check GPU usage
USE_GPU = torch.cuda.is_available()
print('USE GPU: '+str(USE_GPU))
# mini-batch size
BATCH_SIZE = 32
# learning rage
LR = 1e-4
# clip gradient
MAX_GRAD_NORM = 0.1
# log optimization
LOG_OPT = False

'''Save&Load Settings'''
# log frequency
LOG_FREQ = 10
# check save/load
SAVE = True
LOAD = False
# paths for predction net, target net, result log
NET_PATH = './data/model/ppo_net.pkl'
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# N_ACTIONS :  6
# N_STATES :  (4, 84, 84)
# USE GPU: True
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## 네트워크 구조 정의하기

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc = nn.Linear(7 * 7 * 64, 256)
        # actor
        self.actor = nn.Linear(256, N_ACTIONS)
        # critic
        self.critic = nn.Linear(256, 1)
            
        # parameter initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc(x))
        # use log_softmax for numerical stability
        action_log_prob = F.log_softmax(self.actor(x), dim=1)
        state_value = self.critic(x)

        return action_log_prob, state_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## PPO 정의하기

# %%
class PPO:
    def __init__(self):
        self.net = ConvNet()
        # use gpu
        if USE_GPU:
            self.net = self.net.cuda()
            
        # simulator step conter
        self.memory_counter = 0
        
        # define optimizer
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=LR)
        
        # ppo clip range
        self.clip_range = CLIP_RANGE
        
    def save_model(self):
        self.net.cpu()
        self.net.save(NET_PATH)
        if USE_GPU:
            self.net.cuda()
            
    def load_model(self):
        self.net.cpu()
        self.net.load(NET_PATH)
        if USE_GPU:
            self.net.cuda()
        
    def choose_action(self, x):
        self.memory_counter += 1
        # Assume that x is a np.array of shape (nenvs, 4, 84, 84)
        x = torch.FloatTensor(x)
        if USE_GPU:
            x = x.cuda()
        # get action log probs and state values
        action_log_probs, state_values = self.net(x) # (nenvs, N_ACTIONS)
        probs = F.softmax(action_log_probs, dim=1).data.cpu().numpy()
        probs = (probs+1e-8)/np.sum((probs+1e-8), axis=1, keepdims=True)
        # sample actions
        actions = np.array([np.random.choice(N_ACTIONS,p=probs[i]) for i in range(len(probs))])
        # convert tensor to np.array
        action_log_probs , state_values = action_log_probs.data.cpu().numpy() , state_values.squeeze(1).data.cpu().numpy()
        # calc selected logprob
        selected_log_probs = np.array([action_log_probs[i][actions[i]] for i in range(len(probs))])
        return actions, state_values, selected_log_probs

    def learn(self, obs, returns, masks, actions, values, selected_log_probs):
        
        # calculate the advantages
        advs = returns - values
        
        # np.array -> torch.Tensor
        obs = torch.FloatTensor(obs) # (m, 4, 84, 84)
        returns = torch.FloatTensor(returns) # (m)
        advs = torch.FloatTensor(advs) # (m)
        actions = torch.LongTensor(actions) # (m)
        selected_log_probs = torch.FloatTensor(selected_log_probs) # (m)
        values = torch.FloatTensor(values) # (m)
        if USE_GPU:
            obs = obs.cuda()
            returns = returns.cuda()
            advs = advs.cuda()
            actions = actions.cuda()
            selected_log_probs = selected_log_probs.cuda()
            values = values.cuda()
        
        # get action log probs and state values
        action_log_probs, state_values = self.net(obs)
        # (m, N_ACTIONS), (m, 1)
        
        # calc probs
        probs = F.softmax(action_log_probs, dim=1)
        # (m, N_ACTIONS)
        
        # calc entropy loss
        ent_loss = ENT_COEF *((action_log_probs * probs).sum(dim=1)).mean()
        # (1)
        
        # calc log probs
        cur_log_probs = action_log_probs.gather(1,actions.unsqueeze(1))
        # cur : (m, 1)
        ratio = torch.exp(cur_log_probs.squeeze(1)-selected_log_probs)
        # (m)
        
        # actor loss
        '''
        문제 : PPO의 목적 함수를 작성해 주세요.
        힌트 : PPO는 A2C와 달리 이전 정책의 확률을 기반으로 목적 함수를 계산합니다.
                또 이전 정책과 현재 정책의 확률비를 기반으로 clipping을 합니다.
        '''
        # critic loss
        critic_loss = F.smooth_l1_loss(state_values.squeeze(1), returns) # (1)

        loss = actor_loss + critic_loss + ent_loss # (1)
        
        actor_loss, critic_loss, ent_loss, total_loss = actor_loss.data.cpu().numpy(), \
        critic_loss.data.cpu().numpy(), ent_loss.data.cpu().numpy(), loss.data.cpu().numpy()

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.net.parameters(), MAX_GRAD_NORM)
        self.optimizer.step()
        
        return round(float(actor_loss), 4), round(float(critic_loss), 4),\
    round(float(ent_loss), 4), round(float(total_loss), 4)

# %% [markdown]
# ## 학습

# %%
ppo = PPO()
runner = Runner(env=env, model=ppo, nsteps=TRAJ_LEN, gamma=GAMMA, lam=LAMBDA)

# model load with check
if LOAD and os.path.isfile(PRED_PATH) and os.path.isfile(TARGET_PATH):
    ppo.load_model()
    pkl_file = open(RESULT_PATH,'rb')
    result = pickle.load(pkl_file)
    pkl_file.close()
    print('Load complete!')
else:
    result = []
    print('Initialize results!')

print('Collecting experience...')

# episode step for accumulate reward 
epinfobuf = deque(maxlen=100)
# in PPO, we iterate over optimization step
nbatch = N_ENVS * TRAJ_LEN
nupdates = N_STEP// nbatch
# check learning time
start_time = time.time()

for update in range(1, nupdates+1):
    # get minibatch
    obs, returns, masks, actions, values, neglogpacs, epinfos = runner.run()
    epinfobuf.extend(epinfos)
    
    # calculate loss
    inds = np.arange(nbatch)
    for _ in range(N_OPT_EPOCHS):
        a_losses, c_losses, e_losses, t_losses = list(), list(), list(), list()
        # shuffle indices for i.i.d.
        np.random.shuffle(inds)
        # 0 to batch_size with batch_train_size step
        for start in range(0, nbatch, BATCH_SIZE):
            end = start + BATCH_SIZE
            mbinds = inds[start:end]
            slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
            actor_loss, critic_loss, ent_loss, total_loss = ppo.learn(*slices)
            # save opt log
            a_losses.append(actor_loss)
            c_losses.append(critic_loss)
            e_losses.append(ent_loss)
            t_losses.append(total_loss)
        # print opt log
        if LOG_OPT:
            print('Iter ',_,
                 'actor loss : ',round(float(np.mean(a_losses)), 3),
                 'critic loss : ', round(float(np.mean(c_losses)), 3),
                 'ent loss : ', round(float(np.mean(e_losses)), 3),
                 'total loss : ', round(float(np.mean(t_losses)), 3))
            
    if update % LOG_FREQ == 0:
        # print log and save
        # check time interval
        time_interval = round(time.time() - start_time, 2)
        # calc mean return
        mean_100_ep_return = round(np.mean([epinfo['r'] for epinfo in epinfobuf]),2)
        result.append(mean_100_ep_return)
        # print epi log
        print('N update: ',update,
              '| Mean ep 100 return: ', mean_100_ep_return,
              '/Used Time:',time_interval,
              '/Used Step:',ppo.memory_counter*N_ENVS)
        # save model
        if SAVE:
            ppo.save_model()
# Out:
# Initialize results!
# Collecting experience...
# N update:  10 | Mean ep 100 return:  -20.92 /Used Time: 88.69 /Used Step: 40040
# N update:  20 | Mean ep 100 return:  -20.63 /Used Time: 178.36 /Used Step: 80080
# N update:  30 | Mean ep 100 return:  -20.18 /Used Time: 265.61 /Used Step: 120120
# N update:  40 | Mean ep 100 return:  -19.92 /Used Time: 351.05 /Used Step: 160160
# N update:  50 | Mean ep 100 return:  -19.56 /Used Time: 434.99 /Used Step: 200200
# N update:  60 | Mean ep 100 return:  -19.22 /Used Time: 517.92 /Used Step: 240240
# N update:  70 | Mean ep 100 return:  -18.48 /Used Time: 600.38 /Used Step: 280280
# N update:  80 | Mean ep 100 return:  -17.65 /Used Time: 681.96 /Used Step: 320320
# N update:  90 | Mean ep 100 return:  -16.62 /Used Time: 762.86 /Used Step: 360360
# N update:  100 | Mean ep 100 return:  -15.02 /Used Time: 843.83 /Used Step: 400400
# N update:  110 | Mean ep 100 return:  -13.02 /Used Time: 925.07 /Used Step: 440440
# N update:  120 | Mean ep 100 return:  -11.35 /Used Time: 1006.26 /Used Step: 480480
# N update:  130 | Mean ep 100 return:  -9.64 /Used Time: 1087.47 /Used Step: 520520
# N update:  140 | Mean ep 100 return:  -7.69 /Used Time: 1169.05 /Used Step: 560560
# N update:  150 | Mean ep 100 return:  -6.07 /Used Time: 1247.3 /Used Step: 600600
# N update:  160 | Mean ep 100 return:  -4.64 /Used Time: 1323.78 /Used Step: 640640
# N update:  170 | Mean ep 100 return:  -3.49 /Used Time: 1404.5 /Used Step: 680680
# N update:  180 | Mean ep 100 return:  -2.41 /Used Time: 1485.55 /Used Step: 720720
# N update:  190 | Mean ep 100 return:  -1.88 /Used Time: 1566.5 /Used Step: 760760
# N update:  200 | Mean ep 100 return:  -1.2 /Used Time: 1647.14 /Used Step: 800800
# N update:  210 | Mean ep 100 return:  -0.41 /Used Time: 1727.97 /Used Step: 840840
# N update:  220 | Mean ep 100 return:  -0.08 /Used Time: 1808.66 /Used Step: 880880
# N update:  230 | Mean ep 100 return:  0.28 /Used Time: 1889.32 /Used Step: 920920
# N update:  240 | Mean ep 100 return:  0.6 /Used Time: 1969.9 /Used Step: 960960
# N update:  250 | Mean ep 100 return:  1.68 /Used Time: 2050.86 /Used Step: 1001000
# N update:  260 | Mean ep 100 return:  3.3 /Used Time: 2131.66 /Used Step: 1041040
# N update:  270 | Mean ep 100 return:  5.61 /Used Time: 2212.35 /Used Step: 1081080
# N update:  280 | Mean ep 100 return:  8.84 /Used Time: 2292.9 /Used Step: 1121120
# N update:  290 | Mean ep 100 return:  11.96 /Used Time: 2373.55 /Used Step: 1161160
# N update:  300 | Mean ep 100 return:  15.29 /Used Time: 2454.92 /Used Step: 1201200
# N update:  310 | Mean ep 100 return:  16.79 /Used Time: 2536.57 /Used Step: 1241240
# N update:  320 | Mean ep 100 return:  17.89 /Used Time: 2618.76 /Used Step: 1281280
# N update:  330 | Mean ep 100 return:  18.12 /Used Time: 2701.52 /Used Step: 1321320
# N update:  340 | Mean ep 100 return:  18.16 /Used Time: 2784.87 /Used Step: 1361360
# N update:  350 | Mean ep 100 return:  18.15 /Used Time: 2869.33 /Used Step: 1401400
# N update:  360 | Mean ep 100 return:  18.29 /Used Time: 2950.56 /Used Step: 1441440
# N update:  370 | Mean ep 100 return:  17.82 /Used Time: 3031.74 /Used Step: 1481480
# N update:  380 | Mean ep 100 return:  17.79 /Used Time: 3114.52 /Used Step: 1521520
# N update:  390 | Mean ep 100 return:  17.75 /Used Time: 3198.73 /Used Step: 1561560
# N update:  400 | Mean ep 100 return:  17.81 /Used Time: 3283.59 /Used Step: 1601600
# N update:  410 | Mean ep 100 return:  17.48 /Used Time: 3367.08 /Used Step: 1641640
# N update:  420 | Mean ep 100 return:  17.79 /Used Time: 3449.42 /Used Step: 1681680
# N update:  430 | Mean ep 100 return:  17.96 /Used Time: 3529.57 /Used Step: 1721720
# N update:  440 | Mean ep 100 return:  17.96 /Used Time: 3608.24 /Used Step: 1761760
# N update:  450 | Mean ep 100 return:  18.01 /Used Time: 3685.06 /Used Step: 1801800
# N update:  460 | Mean ep 100 return:  18.2 /Used Time: 3757.96 /Used Step: 1841840
# N update:  470 | Mean ep 100 return:  18.16 /Used Time: 3833.29 /Used Step: 1881880
# N update:  480 | Mean ep 100 return:  18.18 /Used Time: 3909.89 /Used Step: 1921920
# N update:  490 | Mean ep 100 return:  18.4 /Used Time: 3988.32 /Used Step: 1961960
# N update:  500 | Mean ep 100 return:  18.33 /Used Time: 4067.35 /Used Step: 2002000
# N update:  510 | Mean ep 100 return:  18.41 /Used Time: 4148.46 /Used Step: 2042040
# N update:  520 | Mean ep 100 return:  18.51 /Used Time: 4231.22 /Used Step: 2082080
# N update:  530 | Mean ep 100 return:  18.82 /Used Time: 4314.77 /Used Step: 2122120
# N update:  540 | Mean ep 100 return:  18.77 /Used Time: 4396.28 /Used Step: 2162160
# N update:  550 | Mean ep 100 return:  18.46 /Used Time: 4475.89 /Used Step: 2202200
# N update:  560 | Mean ep 100 return:  18.54 /Used Time: 4553.87 /Used Step: 2242240
# N update:  570 | Mean ep 100 return:  18.29 /Used Time: 4630.85 /Used Step: 2282280
# N update:  580 | Mean ep 100 return:  18.09 /Used Time: 4706.24 /Used Step: 2322320
# N update:  590 | Mean ep 100 return:  18.1 /Used Time: 4781.18 /Used Step: 2362360
# N update:  600 | Mean ep 100 return:  18.3 /Used Time: 4857.29 /Used Step: 2402400
# N update:  610 | Mean ep 100 return:  18.21 /Used Time: 4934.59 /Used Step: 2442440
# N update:  620 | Mean ep 100 return:  18.24 /Used Time: 5012.9 /Used Step: 2482480
# N update:  630 | Mean ep 100 return:  18.39 /Used Time: 5092.11 /Used Step: 2522520
# N update:  640 | Mean ep 100 return:  18.34 /Used Time: 5172.56 /Used Step: 2562560
# N update:  650 | Mean ep 100 return:  18.03 /Used Time: 5253.98 /Used Step: 2602600
# N update:  660 | Mean ep 100 return:  18.11 /Used Time: 5336.6 /Used Step: 2642640
# N update:  670 | Mean ep 100 return:  18.16 /Used Time: 5420.4 /Used Step: 2682680
# N update:  680 | Mean ep 100 return:  18.16 /Used Time: 5502.38 /Used Step: 2722720
# N update:  690 | Mean ep 100 return:  18.2 /Used Time: 5582.63 /Used Step: 2762760
# N update:  700 | Mean ep 100 return:  18.28 /Used Time: 5661.2 /Used Step: 2802800
# N update:  710 | Mean ep 100 return:  18.39 /Used Time: 5737.74 /Used Step: 2842840
# N update:  720 | Mean ep 100 return:  18.23 /Used Time: 5813.06 /Used Step: 2882880
# N update:  730 | Mean ep 100 return:  18.52 /Used Time: 5888.85 /Used Step: 2922920
# N update:  740 | Mean ep 100 return:  18.4 /Used Time: 5958.08 /Used Step: 2962960
# N update:  750 | Mean ep 100 return:  18.7 /Used Time: 6024.24 /Used Step: 3003000
# N update:  760 | Mean ep 100 return:  18.43 /Used Time: 6090.44 /Used Step: 3043040
# N update:  770 | Mean ep 100 return:  18.54 /Used Time: 6156.44 /Used Step: 3083080
# N update:  780 | Mean ep 100 return:  18.41 /Used Time: 6222.25 /Used Step: 3123120
# N update:  790 | Mean ep 100 return:  18.45 /Used Time: 6288.36 /Used Step: 3163160
# N update:  800 | Mean ep 100 return:  18.54 /Used Time: 6354.69 /Used Step: 3203200
# N update:  810 | Mean ep 100 return:  18.84 /Used Time: 6420.75 /Used Step: 3243240
# N update:  820 | Mean ep 100 return:  18.93 /Used Time: 6486.94 /Used Step: 3283280
# N update:  830 | Mean ep 100 return:  18.98 /Used Time: 6552.66 /Used Step: 3323320
# N update:  840 | Mean ep 100 return:  18.85 /Used Time: 6618.37 /Used Step: 3363360
# N update:  850 | Mean ep 100 return:  18.71 /Used Time: 6684.26 /Used Step: 3403400
# N update:  860 | Mean ep 100 return:  18.57 /Used Time: 6750.05 /Used Step: 3443440
# N update:  870 | Mean ep 100 return:  18.4 /Used Time: 6816.23 /Used Step: 3483480
# N update:  880 | Mean ep 100 return:  18.46 /Used Time: 6882.19 /Used Step: 3523520
# N update:  890 | Mean ep 100 return:  18.34 /Used Time: 6947.77 /Used Step: 3563560
# N update:  900 | Mean ep 100 return:  18.56 /Used Time: 7013.72 /Used Step: 3603600
# N update:  910 | Mean ep 100 return:  18.55 /Used Time: 7078.96 /Used Step: 3643640
# N update:  920 | Mean ep 100 return:  18.2 /Used Time: 7144.63 /Used Step: 3683680
# N update:  930 | Mean ep 100 return:  18.47 /Used Time: 7210.34 /Used Step: 3723720
# N update:  940 | Mean ep 100 return:  18.54 /Used Time: 7276.35 /Used Step: 3763760
# N update:  950 | Mean ep 100 return:  18.49 /Used Time: 7342.58 /Used Step: 3803800
# N update:  960 | Mean ep 100 return:  18.51 /Used Time: 7408.43 /Used Step: 3843840
# N update:  970 | Mean ep 100 return:  18.71 /Used Time: 7474.3 /Used Step: 3883880
# N update:  980 | Mean ep 100 return:  18.74 /Used Time: 7540.75 /Used Step: 3923920
# N update:  990 | Mean ep 100 return:  18.89 /Used Time: 7606.27 /Used Step: 3963960
# N update:  1000 | Mean ep 100 return:  18.86 /Used Time: 7672.35 /Used Step: 4004000
# N update:  1010 | Mean ep 100 return:  19.08 /Used Time: 7737.68 /Used Step: 4044040
# N update:  1020 | Mean ep 100 return:  19.38 /Used Time: 7803.45 /Used Step: 4084080
# N update:  1030 | Mean ep 100 return:  19.37 /Used Time: 7868.89 /Used Step: 4124120
# N update:  1040 | Mean ep 100 return:  19.23 /Used Time: 7934.94 /Used Step: 4164160
# N update:  1050 | Mean ep 100 return:  19.12 /Used Time: 8000.49 /Used Step: 4204200
# N update:  1060 | Mean ep 100 return:  18.97 /Used Time: 8066.56 /Used Step: 4244240
# N update:  1070 | Mean ep 100 return:  18.98 /Used Time: 8132.18 /Used Step: 4284280
# N update:  1080 | Mean ep 100 return:  19.01 /Used Time: 8198.22 /Used Step: 4324320
# N update:  1090 | Mean ep 100 return:  19.08 /Used Time: 8264.05 /Used Step: 4364360
# N update:  1100 | Mean ep 100 return:  19.12 /Used Time: 8329.84 /Used Step: 4404400
# N update:  1110 | Mean ep 100 return:  19.15 /Used Time: 8395.41 /Used Step: 4444440
# N update:  1120 | Mean ep 100 return:  19.06 /Used Time: 8461.03 /Used Step: 4484480
# N update:  1130 | Mean ep 100 return:  18.97 /Used Time: 8527.4 /Used Step: 4524520
# N update:  1140 | Mean ep 100 return:  18.77 /Used Time: 8592.64 /Used Step: 4564560
# N update:  1150 | Mean ep 100 return:  18.8 /Used Time: 8658.84 /Used Step: 4604600
# N update:  1160 | Mean ep 100 return:  18.76 /Used Time: 8724.02 /Used Step: 4644640
# N update:  1170 | Mean ep 100 return:  18.97 /Used Time: 8789.45 /Used Step: 4684680
# N update:  1180 | Mean ep 100 return:  18.97 /Used Time: 8855.73 /Used Step: 4724720
# N update:  1190 | Mean ep 100 return:  19.06 /Used Time: 8921.02 /Used Step: 4764760
# N update:  1200 | Mean ep 100 return:  19.25 /Used Time: 8987.06 /Used Step: 4804800
# N update:  1210 | Mean ep 100 return:  19.23 /Used Time: 9052.84 /Used Step: 4844840
# N update:  1220 | Mean ep 100 return:  19.22 /Used Time: 9118.65 /Used Step: 4884880
# N update:  1230 | Mean ep 100 return:  19.26 /Used Time: 9183.86 /Used Step: 4924920
# N update:  1240 | Mean ep 100 return:  19.07 /Used Time: 9249.74 /Used Step: 4964960
# N update:  1250 | Mean ep 100 return:  19.02 /Used Time: 9315.05 /Used Step: 5005000
# N update:  1260 | Mean ep 100 return:  18.95 /Used Time: 9380.73 /Used Step: 5045040
# N update:  1270 | Mean ep 100 return:  19.03 /Used Time: 9446.7 /Used Step: 5085080
# N update:  1280 | Mean ep 100 return:  19.04 /Used Time: 9512.76 /Used Step: 5125120
# N update:  1290 | Mean ep 100 return:  19.15 /Used Time: 9578.5 /Used Step: 5165160
# N update:  1300 | Mean ep 100 return:  19.07 /Used Time: 9643.79 /Used Step: 5205200
# N update:  1310 | Mean ep 100 return:  19.12 /Used Time: 9709.57 /Used Step: 5245240
# N update:  1320 | Mean ep 100 return:  19.32 /Used Time: 9775.11 /Used Step: 5285280
# N update:  1330 | Mean ep 100 return:  19.35 /Used Time: 9841.02 /Used Step: 5325320
# N update:  1340 | Mean ep 100 return:  19.41 /Used Time: 9906.45 /Used Step: 5365360
# N update:  1350 | Mean ep 100 return:  19.16 /Used Time: 9972.71 /Used Step: 5405400
# N update:  1360 | Mean ep 100 return:  19.26 /Used Time: 10038.69 /Used Step: 5445440
# N update:  1370 | Mean ep 100 return:  19.0 /Used Time: 10104.2 /Used Step: 5485480
# N update:  1380 | Mean ep 100 return:  18.94 /Used Time: 10170.03 /Used Step: 5525520
# N update:  1390 | Mean ep 100 return:  18.92 /Used Time: 10236.22 /Used Step: 5565560
# N update:  1400 | Mean ep 100 return:  19.06 /Used Time: 10302.04 /Used Step: 5605600
# N update:  1410 | Mean ep 100 return:  19.01 /Used Time: 10367.74 /Used Step: 5645640
# N update:  1420 | Mean ep 100 return:  18.94 /Used Time: 10433.72 /Used Step: 5685680
# N update:  1430 | Mean ep 100 return:  18.97 /Used Time: 10499.78 /Used Step: 5725720
# N update:  1440 | Mean ep 100 return:  18.89 /Used Time: 10565.22 /Used Step: 5765760
# N update:  1450 | Mean ep 100 return:  18.79 /Used Time: 10630.77 /Used Step: 5805800
# N update:  1460 | Mean ep 100 return:  19.0 /Used Time: 10696.62 /Used Step: 5845840
# N update:  1470 | Mean ep 100 return:  18.99 /Used Time: 10762.21 /Used Step: 5885880
# N update:  1480 | Mean ep 100 return:  18.93 /Used Time: 10828.08 /Used Step: 5925920
# N update:  1490 | Mean ep 100 return:  18.98 /Used Time: 10893.65 /Used Step: 5965960
# N update:  1500 | Mean ep 100 return:  18.97 /Used Time: 10959.33 /Used Step: 6006000
# N update:  1510 | Mean ep 100 return:  18.96 /Used Time: 11025.31 /Used Step: 6046040
# N update:  1520 | Mean ep 100 return:  18.81 /Used Time: 11091.23 /Used Step: 6086080
# N update:  1530 | Mean ep 100 return:  19.03 /Used Time: 11157.28 /Used Step: 6126120
# N update:  1540 | Mean ep 100 return:  19.07 /Used Time: 11223.01 /Used Step: 6166160
# N update:  1550 | Mean ep 100 return:  19.09 /Used Time: 11288.39 /Used Step: 6206200
# N update:  1560 | Mean ep 100 return:  19.1 /Used Time: 11354.56 /Used Step: 6246240
# N update:  1570 | Mean ep 100 return:  19.12 /Used Time: 11420.5 /Used Step: 6286280
# N update:  1580 | Mean ep 100 return:  19.1 /Used Time: 11486.13 /Used Step: 6326320
# N update:  1590 | Mean ep 100 return:  19.02 /Used Time: 11551.63 /Used Step: 6366360
# N update:  1600 | Mean ep 100 return:  19.04 /Used Time: 11617.2 /Used Step: 6406400
# N update:  1610 | Mean ep 100 return:  19.01 /Used Time: 11683.05 /Used Step: 6446440
# N update:  1620 | Mean ep 100 return:  18.89 /Used Time: 11748.69 /Used Step: 6486480
# N update:  1630 | Mean ep 100 return:  19.09 /Used Time: 11814.12 /Used Step: 6526520
# N update:  1640 | Mean ep 100 return:  18.78 /Used Time: 11879.97 /Used Step: 6566560
# N update:  1650 | Mean ep 100 return:  18.97 /Used Time: 11945.83 /Used Step: 6606600
# N update:  1660 | Mean ep 100 return:  19.19 /Used Time: 12011.62 /Used Step: 6646640
# N update:  1670 | Mean ep 100 return:  19.33 /Used Time: 12077.54 /Used Step: 6686680
# N update:  1680 | Mean ep 100 return:  19.26 /Used Time: 12143.53 /Used Step: 6726720
# N update:  1690 | Mean ep 100 return:  19.43 /Used Time: 12208.94 /Used Step: 6766760
# N update:  1700 | Mean ep 100 return:  19.05 /Used Time: 12274.92 /Used Step: 6806800
# N update:  1710 | Mean ep 100 return:  18.95 /Used Time: 12341.09 /Used Step: 6846840
# N update:  1720 | Mean ep 100 return:  18.89 /Used Time: 12406.5 /Used Step: 6886880
# N update:  1730 | Mean ep 100 return:  18.87 /Used Time: 12472.0 /Used Step: 6926920
# N update:  1740 | Mean ep 100 return:  18.87 /Used Time: 12538.03 /Used Step: 6966960
# N update:  1750 | Mean ep 100 return:  19.14 /Used Time: 12603.6 /Used Step: 7007000
# N update:  1760 | Mean ep 100 return:  19.1 /Used Time: 12669.26 /Used Step: 7047040
# N update:  1770 | Mean ep 100 return:  19.25 /Used Time: 12734.58 /Used Step: 7087080
# N update:  1780 | Mean ep 100 return:  19.17 /Used Time: 12791.83 /Used Step: 7127120
# N update:  1790 | Mean ep 100 return:  19.22 /Used Time: 12841.31 /Used Step: 7167160
# N update:  1800 | Mean ep 100 return:  19.02 /Used Time: 12891.3 /Used Step: 7207200
# N update:  1810 | Mean ep 100 return:  19.09 /Used Time: 12941.01 /Used Step: 7247240
# N update:  1820 | Mean ep 100 return:  19.09 /Used Time: 12990.84 /Used Step: 7287280
# N update:  1830 | Mean ep 100 return:  19.07 /Used Time: 13040.46 /Used Step: 7327320
# N update:  1840 | Mean ep 100 return:  19.09 /Used Time: 13090.23 /Used Step: 7367360
# N update:  1850 | Mean ep 100 return:  19.05 /Used Time: 13139.93 /Used Step: 7407400
# N update:  1860 | Mean ep 100 return:  18.9 /Used Time: 13189.5 /Used Step: 7447440
# N update:  1870 | Mean ep 100 return:  18.8 /Used Time: 13239.18 /Used Step: 7487480
# N update:  1880 | Mean ep 100 return:  18.9 /Used Time: 13288.4 /Used Step: 7527520
# N update:  1890 | Mean ep 100 return:  18.79 /Used Time: 13338.14 /Used Step: 7567560
# N update:  1900 | Mean ep 100 return:  18.78 /Used Time: 13387.67 /Used Step: 7607600
# N update:  1910 | Mean ep 100 return:  18.82 /Used Time: 13436.44 /Used Step: 7647640
# N update:  1920 | Mean ep 100 return:  18.84 /Used Time: 13485.97 /Used Step: 7687680
# N update:  1930 | Mean ep 100 return:  18.73 /Used Time: 13535.42 /Used Step: 7727720
# N update:  1940 | Mean ep 100 return:  18.85 /Used Time: 13584.84 /Used Step: 7767760
# N update:  1950 | Mean ep 100 return:  19.16 /Used Time: 13634.26 /Used Step: 7807800
# N update:  1960 | Mean ep 100 return:  19.1 /Used Time: 13683.8 /Used Step: 7847840
# N update:  1970 | Mean ep 100 return:  19.16 /Used Time: 13733.28 /Used Step: 7887880
# N update:  1980 | Mean ep 100 return:  19.13 /Used Time: 13782.78 /Used Step: 7927920
# N update:  1990 | Mean ep 100 return:  18.93 /Used Time: 13832.4 /Used Step: 7967960
# N update:  2000 | Mean ep 100 return:  18.77 /Used Time: 13882.03 /Used Step: 8008000
# N update:  2010 | Mean ep 100 return:  18.81 /Used Time: 13931.48 /Used Step: 8048040
# N update:  2020 | Mean ep 100 return:  18.73 /Used Time: 13981.05 /Used Step: 8088080
# N update:  2030 | Mean ep 100 return:  18.83 /Used Time: 14030.68 /Used Step: 8128120
# N update:  2040 | Mean ep 100 return:  18.88 /Used Time: 14080.18 /Used Step: 8168160
# N update:  2050 | Mean ep 100 return:  18.88 /Used Time: 14129.96 /Used Step: 8208200
# N update:  2060 | Mean ep 100 return:  18.79 /Used Time: 14179.84 /Used Step: 8248240
# N update:  2070 | Mean ep 100 return:  19.08 /Used Time: 14229.29 /Used Step: 8288280
# N update:  2080 | Mean ep 100 return:  18.97 /Used Time: 14278.95 /Used Step: 8328320
# N update:  2090 | Mean ep 100 return:  18.98 /Used Time: 14328.28 /Used Step: 8368360
# N update:  2100 | Mean ep 100 return:  19.06 /Used Time: 14377.28 /Used Step: 8408400
# N update:  2110 | Mean ep 100 return:  19.24 /Used Time: 14427.06 /Used Step: 8448440
# N update:  2120 | Mean ep 100 return:  19.19 /Used Time: 14476.66 /Used Step: 8488480
# N update:  2130 | Mean ep 100 return:  19.23 /Used Time: 14526.12 /Used Step: 8528520
# N update:  2140 | Mean ep 100 return:  19.12 /Used Time: 14575.77 /Used Step: 8568560
# N update:  2150 | Mean ep 100 return:  19.05 /Used Time: 14625.02 /Used Step: 8608600
# N update:  2160 | Mean ep 100 return:  18.92 /Used Time: 14674.47 /Used Step: 8648640
# N update:  2170 | Mean ep 100 return:  18.89 /Used Time: 14723.75 /Used Step: 8688680
# N update:  2180 | Mean ep 100 return:  18.96 /Used Time: 14773.3 /Used Step: 8728720
# N update:  2190 | Mean ep 100 return:  19.08 /Used Time: 14822.91 /Used Step: 8768760
# N update:  2200 | Mean ep 100 return:  19.21 /Used Time: 14872.27 /Used Step: 8808800
# N update:  2210 | Mean ep 100 return:  19.22 /Used Time: 14922.04 /Used Step: 8848840
# N update:  2220 | Mean ep 100 return:  19.25 /Used Time: 14971.39 /Used Step: 8888880
# N update:  2230 | Mean ep 100 return:  19.21 /Used Time: 15020.8 /Used Step: 8928920
# N update:  2240 | Mean ep 100 return:  19.12 /Used Time: 15070.33 /Used Step: 8968960
# N update:  2250 | Mean ep 100 return:  19.01 /Used Time: 15120.01 /Used Step: 9009000
# N update:  2260 | Mean ep 100 return:  19.07 /Used Time: 15169.49 /Used Step: 9049040
# N update:  2270 | Mean ep 100 return:  18.99 /Used Time: 15219.1 /Used Step: 9089080
# N update:  2280 | Mean ep 100 return:  19.1 /Used Time: 15268.73 /Used Step: 9129120
# N update:  2290 | Mean ep 100 return:  18.99 /Used Time: 15318.35 /Used Step: 9169160
# N update:  2300 | Mean ep 100 return:  18.87 /Used Time: 15367.84 /Used Step: 9209200
# N update:  2310 | Mean ep 100 return:  18.88 /Used Time: 15417.08 /Used Step: 9249240
# N update:  2320 | Mean ep 100 return:  18.82 /Used Time: 15466.72 /Used Step: 9289280
# N update:  2330 | Mean ep 100 return:  18.96 /Used Time: 15516.24 /Used Step: 9329320
# N update:  2340 | Mean ep 100 return:  18.72 /Used Time: 15565.63 /Used Step: 9369360
# N update:  2350 | Mean ep 100 return:  18.95 /Used Time: 15615.13 /Used Step: 9409400
# N update:  2360 | Mean ep 100 return:  18.95 /Used Time: 15664.63 /Used Step: 9449440
# N update:  2370 | Mean ep 100 return:  19.04 /Used Time: 15714.03 /Used Step: 9489480
# N update:  2380 | Mean ep 100 return:  18.96 /Used Time: 15763.53 /Used Step: 9529520
# N update:  2390 | Mean ep 100 return:  19.07 /Used Time: 15812.72 /Used Step: 9569560
# N update:  2400 | Mean ep 100 return:  19.05 /Used Time: 15862.22 /Used Step: 9609600
# N update:  2410 | Mean ep 100 return:  19.09 /Used Time: 15911.83 /Used Step: 9649640
# N update:  2420 | Mean ep 100 return:  19.1 /Used Time: 15961.28 /Used Step: 9689680
# N update:  2430 | Mean ep 100 return:  18.99 /Used Time: 16010.72 /Used Step: 9729720
# N update:  2440 | Mean ep 100 return:  19.21 /Used Time: 16059.91 /Used Step: 9769760
# N update:  2450 | Mean ep 100 return:  19.01 /Used Time: 16109.22 /Used Step: 9809800
# N update:  2460 | Mean ep 100 return:  19.17 /Used Time: 16158.5 /Used Step: 9849840
# N update:  2470 | Mean ep 100 return:  19.14 /Used Time: 16207.74 /Used Step: 9889880
# N update:  2480 | Mean ep 100 return:  19.19 /Used Time: 16257.03 /Used Step: 9929920
# N update:  2490 | Mean ep 100 return:  19.09 /Used Time: 16306.5 /Used Step: 9969960
# N update:  2500 | Mean ep 100 return:  18.98 /Used Time: 16355.83 /Used Step: 10010000

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot(range(len(result)), result)
plt.tight_layout()
plt.show()

# %%
from matplotlib import animation

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./ppo_pong_result.gif', writer='imagemagick', fps=30)

# %%
env = wrap(gym.make('PongNoFrameskip-v4'))
s = np.array(env.reset())
total_reward = 0
frames = []

for t in range(10000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    a, v, l = ppo.choose_action(np.expand_dims(s,axis=0))
    # take action and get next state
    s_, r, done, info = env.step(a)
    s_ = np.array(s_)
    total_reward += r
    if done:
        break
    s = s_
env.close()
print('Total Reward : %.2f'%total_reward)
display_frames_as_gif(frames)
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Total Reward : 20.00

# %% [markdown]
# ![alt text](./ppo_pong_result.gif "segment")
