# %% [markdown]
# ## 필요한 모듈 설치 확인

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import random
import os
import pickle
import time
from collections import deque

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from wrappers import wrap_cover, SubprocVecEnv
from runner import Runner

# %% [markdown]
# ## 하이퍼 파라미터 정의하기

# %%
'''A2C Settings'''
TRAJ_LEN = 1000
ENT_COEF = 1e-2
LAMBDA = 0.95

'''Environment Settings'''
# sequential images to define state
STATE_LEN = 4
# openai gym env name
ENV_NAME = 'PongNoFrameskip-v4'
# number of environments for A2C
N_ENVS = 4
# define gym 
env = SubprocVecEnv([wrap_cover(ENV_NAME) for i in range(N_ENVS)])
# check gym setting
N_ACTIONS = env.action_space.n;print('N_ACTIONS : ',N_ACTIONS) #  6
N_STATES = env.observation_space.shape;print('N_STATES : ',N_STATES) # (4, 84, 84)
# Total simulation step
N_STEP = 10**7
# gamma for MDP
GAMMA = 0.99
# visualize for agent playing
RENDERING = False

'''Training settings'''
# check GPU usage
USE_GPU = torch.cuda.is_available()
print('USE GPU: '+str(USE_GPU))
# learning rage
LR = 1e-4
# epsilon-greedy
EPSILON = 0.0
# clip gradient
MAX_GRAD_NORM = 0.1
# log optimization
LOG_OPT = False

'''Save&Load Settings'''
# log frequency
LOG_FREQ = 10
# check save/load
SAVE = True
LOAD = False
# paths for predction net, target net, result log
NET_PATH = './data/model/a2c_net.pkl'
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# N_ACTIONS :  6
# N_STATES :  (4, 84, 84)
# USE GPU: True
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## 네트워크 구조 정의하기

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc = nn.Linear(7 * 7 * 64, 256)
        # actor
        self.actor = nn.Linear(256, N_ACTIONS)
        # critic
        self.critic = nn.Linear(256, 1)
            
        # parameter initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc(x))
        # use log_softmax for numerical stability
        action_log_prob = F.log_softmax(self.actor(x), dim=1)
        state_value = self.critic(x)

        return action_log_prob, state_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## A2C 정의하기

# %%
class A2C:
    def __init__(self):
        self.net = ConvNet()
        # use gpu
        if USE_GPU:
            self.net = self.net.cuda()
            
        # simulator step conter
        self.memory_counter = 0
        
        # define optimizer
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=LR, weight_decay=1e-4)
        
    def save_model(self):
        self.net.cpu()
        self.net.save(NET_PATH)
        if USE_GPU:
            self.net.cuda()
            
    def load_model(self):
        self.net.cpu()
        self.net.load(NET_PATH)
        if USE_GPU:
            self.net.cuda()
        
    def choose_action(self, x):
        self.memory_counter += 1
        # Assume that x is a np.array of shape (nenvs, 4, 84, 84)
        x = torch.FloatTensor(x)
        if USE_GPU:
            x = x.cuda()
        # get action log probs and state values
        action_log_probs, state_values = self.net(x) # (nenvs, N_ACTIONS)
        probs = F.softmax(action_log_probs, dim=1).data.cpu().numpy()
        probs = (probs+1e-8)/np.sum((probs+1e-8), axis=1, keepdims=True)
        # sample actions
        actions = np.array([np.random.choice(N_ACTIONS,p=probs[i]) for i in range(len(probs))])
        # convert tensor to np.array
        action_log_probs , state_values = action_log_probs.data.cpu().numpy() , state_values.squeeze(1).data.cpu().numpy()
        # calc selected logprob
        selected_log_probs = np.array([action_log_probs[i][actions[i]] for i in range(len(probs))])
        return actions, state_values, selected_log_probs

    def learn(self, obs, returns, masks, actions, values, selected_log_probs):
        
        # calculate the advantages
        advs = returns - values
        # Normalize the advantages for numerical stability
        advs = (advs - advs.mean()) / (advs.std() + 1e-8)
        
        # np.array -> torch.Tensor
        obs = torch.FloatTensor(obs) # (m, 4, 84, 84)
        advs = torch.FloatTensor(advs) # (m)
        actions = torch.LongTensor(actions) # (m)
        selected_log_probs = torch.FloatTensor(selected_log_probs) # (m)
        values = torch.FloatTensor(values) # (m)
        if USE_GPU:
            obs = obs.cuda()
            advs = advs.cuda()
            actions = actions.cuda()
            selected_log_probs = selected_log_probs.cuda()
            values = values.cuda()
        
        # get action log probs and state values
        action_log_probs, state_values = self.net(obs)
        # (m, N_ACTIONS), (m, 1)
        
        # calc probs
        probs = F.softmax(action_log_probs, dim=1)
        # (m, N_ACTIONS)
        
        # calc entropy loss
        ent_loss = ENT_COEF *((action_log_probs * probs).sum(dim=1)).mean()
        # (1)
        
        # calc log probs
        cur_log_probs = action_log_probs.gather(1,actions.unsqueeze(1))
        # cur : (m, 1)
        
        # actor loss
        actor_loss = torch.mean(- cur_log_probs.squeeze(1) * advs) # (1)
        # critic loss
        critic_loss = 0.5 * torch.mean( (state_values.squeeze(1) - values)**2 ) # (1)

        loss = actor_loss + critic_loss + ent_loss # (1)
        
        actor_loss, critic_loss, ent_loss, total_loss = actor_loss.data.cpu().numpy(), \
        critic_loss.data.cpu().numpy(), ent_loss.data.cpu().numpy(), loss.data.cpu().numpy()

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.net.parameters(), MAX_GRAD_NORM)
        self.optimizer.step()
        
        return round(float(actor_loss), 4), round(float(critic_loss), 4),\
    round(float(ent_loss), 4), round(float(total_loss), 4)

# %% [markdown]
# ## 학습

# %%
a2c = A2C()
runner = Runner(env=env, model=a2c, nsteps=TRAJ_LEN, gamma=GAMMA, lam=LAMBDA)

# model load with check
if LOAD and os.path.isfile(PRED_PATH) and os.path.isfile(TARGET_PATH):
    a2c.load_model()
    pkl_file = open(RESULT_PATH,'rb')
    result = pickle.load(pkl_file)
    pkl_file.close()
    print('Load complete!')
else:
    result = []
    print('Initialize results!')

print('Collecting experience...')

# episode step for accumulate reward 
epinfobuf = deque(maxlen=100)
# in A2C, we iterate over optimization step
nbatch = N_ENVS * TRAJ_LEN
nupdates = N_STEP// nbatch
# check learning time
start_time = time.time()

for update in range(1, nupdates+1):
    # get minibatch
    obs, returns, masks, actions, values, neglogpacs, epinfos = runner.run()
    epinfobuf.extend(epinfos)
    slices = (obs, returns, masks, actions, values, neglogpacs)
    actor_loss, critic_loss, ent_loss, total_loss = a2c.learn(*slices)
    
    # print opt log
    if LOG_OPT and update % LOG_FREQ == 0:
        print('Iter ',_,
             'actor loss : ',round(actor_loss, 3),
             'critic loss : ', round(critic_loss, 3),
             'ent loss : ', round(ent_loss, 3),
             'total loss : ', round(total_loss, 3))
            
    if update % LOG_FREQ == 0:
        # print log and save
        # check time interval
        time_interval = round(time.time() - start_time, 2)
        # calc mean return
        mean_100_ep_return = round(np.mean([epinfo['r'] for epinfo in epinfobuf]),2)
        result.append(mean_100_ep_return)
        # print epi log
        print('N update: ',update,
              '| Mean ep 100 return: ', mean_100_ep_return,
              '/Used Time:',time_interval,
              '/Used Step:',a2c.memory_counter*N_ENVS)
        # save model
        if SAVE:
            a2c.save_model()
# Out:
# Initialize results!
# Collecting experience...
# N update:  10 | Mean ep 100 return:  -20.5 /Used Time: 35.44 /Used Step: 40040
# N update:  20 | Mean ep 100 return:  -20.49 /Used Time: 71.21 /Used Step: 80080
# N update:  30 | Mean ep 100 return:  -20.61 /Used Time: 106.67 /Used Step: 120120
# N update:  40 | Mean ep 100 return:  -20.57 /Used Time: 142.51 /Used Step: 160160
# N update:  50 | Mean ep 100 return:  -20.34 /Used Time: 177.75 /Used Step: 200200
# N update:  60 | Mean ep 100 return:  -20.2 /Used Time: 213.81 /Used Step: 240240
# N update:  70 | Mean ep 100 return:  -20.35 /Used Time: 248.9 /Used Step: 280280
# N update:  80 | Mean ep 100 return:  -20.39 /Used Time: 283.52 /Used Step: 320320
# N update:  90 | Mean ep 100 return:  -20.19 /Used Time: 318.41 /Used Step: 360360
# N update:  100 | Mean ep 100 return:  -20.04 /Used Time: 353.7 /Used Step: 400400
# N update:  110 | Mean ep 100 return:  -20.06 /Used Time: 388.95 /Used Step: 440440
# N update:  120 | Mean ep 100 return:  -20.13 /Used Time: 424.26 /Used Step: 480480
# N update:  130 | Mean ep 100 return:  -20.24 /Used Time: 459.7 /Used Step: 520520
# N update:  140 | Mean ep 100 return:  -20.35 /Used Time: 496.03 /Used Step: 560560
# N update:  150 | Mean ep 100 return:  -20.24 /Used Time: 530.88 /Used Step: 600600
# N update:  160 | Mean ep 100 return:  -20.15 /Used Time: 566.69 /Used Step: 640640
# N update:  170 | Mean ep 100 return:  -20.15 /Used Time: 602.41 /Used Step: 680680
# N update:  180 | Mean ep 100 return:  -20.27 /Used Time: 638.67 /Used Step: 720720
# N update:  190 | Mean ep 100 return:  -20.29 /Used Time: 674.76 /Used Step: 760760
# N update:  200 | Mean ep 100 return:  -20.25 /Used Time: 710.17 /Used Step: 800800
# N update:  210 | Mean ep 100 return:  -20.15 /Used Time: 745.4 /Used Step: 840840
# N update:  220 | Mean ep 100 return:  -20.17 /Used Time: 780.3 /Used Step: 880880
# N update:  230 | Mean ep 100 return:  -20.21 /Used Time: 815.19 /Used Step: 920920
# N update:  240 | Mean ep 100 return:  -20.24 /Used Time: 849.77 /Used Step: 960960
# N update:  250 | Mean ep 100 return:  -20.32 /Used Time: 884.78 /Used Step: 1001000
# N update:  260 | Mean ep 100 return:  -20.3 /Used Time: 919.49 /Used Step: 1041040
# N update:  270 | Mean ep 100 return:  -20.26 /Used Time: 953.96 /Used Step: 1081080
# N update:  280 | Mean ep 100 return:  -20.16 /Used Time: 989.39 /Used Step: 1121120
# N update:  290 | Mean ep 100 return:  -20.2 /Used Time: 1023.85 /Used Step: 1161160
# N update:  300 | Mean ep 100 return:  -20.24 /Used Time: 1058.77 /Used Step: 1201200
# N update:  310 | Mean ep 100 return:  -20.22 /Used Time: 1093.79 /Used Step: 1241240
# N update:  320 | Mean ep 100 return:  -20.1 /Used Time: 1128.64 /Used Step: 1281280
# N update:  330 | Mean ep 100 return:  -20.06 /Used Time: 1163.58 /Used Step: 1321320
# N update:  340 | Mean ep 100 return:  -20.33 /Used Time: 1198.51 /Used Step: 1361360
# N update:  350 | Mean ep 100 return:  -20.17 /Used Time: 1233.32 /Used Step: 1401400
# N update:  360 | Mean ep 100 return:  -19.98 /Used Time: 1267.86 /Used Step: 1441440
# N update:  370 | Mean ep 100 return:  -20.02 /Used Time: 1302.7 /Used Step: 1481480
# N update:  380 | Mean ep 100 return:  -20.24 /Used Time: 1337.55 /Used Step: 1521520
# N update:  390 | Mean ep 100 return:  -20.37 /Used Time: 1372.15 /Used Step: 1561560
# N update:  400 | Mean ep 100 return:  -20.35 /Used Time: 1406.82 /Used Step: 1601600
# N update:  410 | Mean ep 100 return:  -20.39 /Used Time: 1441.57 /Used Step: 1641640
# N update:  420 | Mean ep 100 return:  -20.37 /Used Time: 1476.11 /Used Step: 1681680
# N update:  430 | Mean ep 100 return:  -20.3 /Used Time: 1511.2 /Used Step: 1721720
# N update:  440 | Mean ep 100 return:  -20.2 /Used Time: 1546.29 /Used Step: 1761760
# N update:  450 | Mean ep 100 return:  -20.2 /Used Time: 1580.51 /Used Step: 1801800
# N update:  460 | Mean ep 100 return:  -20.26 /Used Time: 1615.6 /Used Step: 1841840
# N update:  470 | Mean ep 100 return:  -20.34 /Used Time: 1650.94 /Used Step: 1881880
# N update:  480 | Mean ep 100 return:  -20.36 /Used Time: 1685.51 /Used Step: 1921920
# N update:  490 | Mean ep 100 return:  -20.42 /Used Time: 1720.59 /Used Step: 1961960
# N update:  500 | Mean ep 100 return:  -20.43 /Used Time: 1755.4 /Used Step: 2002000
# N update:  510 | Mean ep 100 return:  -20.42 /Used Time: 1790.53 /Used Step: 2042040
# N update:  520 | Mean ep 100 return:  -20.36 /Used Time: 1825.33 /Used Step: 2082080
# N update:  530 | Mean ep 100 return:  -20.29 /Used Time: 1860.21 /Used Step: 2122120
# N update:  540 | Mean ep 100 return:  -20.07 /Used Time: 1894.39 /Used Step: 2162160
# N update:  550 | Mean ep 100 return:  -20.02 /Used Time: 1928.69 /Used Step: 2202200
# N update:  560 | Mean ep 100 return:  -20.17 /Used Time: 1964.12 /Used Step: 2242240
# N update:  570 | Mean ep 100 return:  -20.29 /Used Time: 1998.54 /Used Step: 2282280
# N update:  580 | Mean ep 100 return:  -20.2 /Used Time: 2032.91 /Used Step: 2322320
# N update:  590 | Mean ep 100 return:  -20.19 /Used Time: 2067.73 /Used Step: 2362360
# N update:  600 | Mean ep 100 return:  -20.37 /Used Time: 2102.31 /Used Step: 2402400
# N update:  610 | Mean ep 100 return:  -20.37 /Used Time: 2136.95 /Used Step: 2442440
# N update:  620 | Mean ep 100 return:  -20.23 /Used Time: 2171.68 /Used Step: 2482480
# N update:  630 | Mean ep 100 return:  -20.16 /Used Time: 2206.55 /Used Step: 2522520
# N update:  640 | Mean ep 100 return:  -20.19 /Used Time: 2241.4 /Used Step: 2562560
# N update:  650 | Mean ep 100 return:  -20.15 /Used Time: 2276.07 /Used Step: 2602600
# N update:  660 | Mean ep 100 return:  -20.12 /Used Time: 2311.06 /Used Step: 2642640
# N update:  670 | Mean ep 100 return:  -20.11 /Used Time: 2345.81 /Used Step: 2682680
# N update:  680 | Mean ep 100 return:  -20.22 /Used Time: 2380.94 /Used Step: 2722720
# N update:  690 | Mean ep 100 return:  -20.33 /Used Time: 2416.12 /Used Step: 2762760
# N update:  700 | Mean ep 100 return:  -20.32 /Used Time: 2450.36 /Used Step: 2802800
# N update:  710 | Mean ep 100 return:  -20.31 /Used Time: 2485.48 /Used Step: 2842840
# N update:  720 | Mean ep 100 return:  -20.26 /Used Time: 2520.08 /Used Step: 2882880
# N update:  730 | Mean ep 100 return:  -20.27 /Used Time: 2554.87 /Used Step: 2922920
# N update:  740 | Mean ep 100 return:  -20.24 /Used Time: 2590.04 /Used Step: 2962960
# N update:  750 | Mean ep 100 return:  -20.2 /Used Time: 2624.97 /Used Step: 3003000
# N update:  760 | Mean ep 100 return:  -20.27 /Used Time: 2659.63 /Used Step: 3043040
# N update:  770 | Mean ep 100 return:  -20.18 /Used Time: 2693.83 /Used Step: 3083080
# N update:  780 | Mean ep 100 return:  -20.14 /Used Time: 2728.81 /Used Step: 3123120
# N update:  790 | Mean ep 100 return:  -20.21 /Used Time: 2763.53 /Used Step: 3163160
# N update:  800 | Mean ep 100 return:  -20.14 /Used Time: 2798.24 /Used Step: 3203200
# N update:  810 | Mean ep 100 return:  -20.22 /Used Time: 2833.41 /Used Step: 3243240
# N update:  820 | Mean ep 100 return:  -20.29 /Used Time: 2868.41 /Used Step: 3283280
# N update:  830 | Mean ep 100 return:  -20.12 /Used Time: 2902.84 /Used Step: 3323320
# N update:  840 | Mean ep 100 return:  -20.0 /Used Time: 2937.57 /Used Step: 3363360
# N update:  850 | Mean ep 100 return:  -20.06 /Used Time: 2972.15 /Used Step: 3403400
# N update:  860 | Mean ep 100 return:  -20.15 /Used Time: 3006.35 /Used Step: 3443440
# N update:  870 | Mean ep 100 return:  -20.21 /Used Time: 3041.11 /Used Step: 3483480
# N update:  880 | Mean ep 100 return:  -20.14 /Used Time: 3075.96 /Used Step: 3523520
# N update:  890 | Mean ep 100 return:  -20.2 /Used Time: 3110.79 /Used Step: 3563560
# N update:  900 | Mean ep 100 return:  -20.19 /Used Time: 3145.68 /Used Step: 3603600
# N update:  910 | Mean ep 100 return:  -20.15 /Used Time: 3180.88 /Used Step: 3643640
# N update:  920 | Mean ep 100 return:  -20.17 /Used Time: 3215.57 /Used Step: 3683680
# N update:  930 | Mean ep 100 return:  -20.3 /Used Time: 3250.2 /Used Step: 3723720
# N update:  940 | Mean ep 100 return:  -20.28 /Used Time: 3284.94 /Used Step: 3763760
# N update:  950 | Mean ep 100 return:  -20.22 /Used Time: 3319.41 /Used Step: 3803800
# N update:  960 | Mean ep 100 return:  -20.1 /Used Time: 3353.88 /Used Step: 3843840
# N update:  970 | Mean ep 100 return:  -20.09 /Used Time: 3388.48 /Used Step: 3883880
# N update:  980 | Mean ep 100 return:  -20.07 /Used Time: 3423.9 /Used Step: 3923920
# N update:  990 | Mean ep 100 return:  -20.05 /Used Time: 3458.41 /Used Step: 3963960
# N update:  1000 | Mean ep 100 return:  -20.12 /Used Time: 3492.92 /Used Step: 4004000
# N update:  1010 | Mean ep 100 return:  -20.06 /Used Time: 3527.66 /Used Step: 4044040
# N update:  1020 | Mean ep 100 return:  -20.01 /Used Time: 3562.22 /Used Step: 4084080
# N update:  1030 | Mean ep 100 return:  -20.04 /Used Time: 3596.83 /Used Step: 4124120
# N update:  1040 | Mean ep 100 return:  -20.07 /Used Time: 3631.88 /Used Step: 4164160
# N update:  1050 | Mean ep 100 return:  -20.16 /Used Time: 3666.27 /Used Step: 4204200
# N update:  1060 | Mean ep 100 return:  -20.16 /Used Time: 3701.01 /Used Step: 4244240
# N update:  1070 | Mean ep 100 return:  -20.03 /Used Time: 3736.24 /Used Step: 4284280
# N update:  1080 | Mean ep 100 return:  -19.88 /Used Time: 3770.99 /Used Step: 4324320
# N update:  1090 | Mean ep 100 return:  -19.89 /Used Time: 3805.53 /Used Step: 4364360
# N update:  1100 | Mean ep 100 return:  -19.93 /Used Time: 3840.26 /Used Step: 4404400
# N update:  1110 | Mean ep 100 return:  -20.13 /Used Time: 3875.09 /Used Step: 4444440
# N update:  1120 | Mean ep 100 return:  -20.14 /Used Time: 3909.76 /Used Step: 4484480
# N update:  1130 | Mean ep 100 return:  -20.14 /Used Time: 3944.88 /Used Step: 4524520
# N update:  1140 | Mean ep 100 return:  -20.17 /Used Time: 3979.5 /Used Step: 4564560
# N update:  1150 | Mean ep 100 return:  -20.21 /Used Time: 4014.08 /Used Step: 4604600
# N update:  1160 | Mean ep 100 return:  -20.27 /Used Time: 4048.97 /Used Step: 4644640
# N update:  1170 | Mean ep 100 return:  -20.22 /Used Time: 4083.51 /Used Step: 4684680
# N update:  1180 | Mean ep 100 return:  -20.29 /Used Time: 4117.71 /Used Step: 4724720
# N update:  1190 | Mean ep 100 return:  -20.18 /Used Time: 4153.1 /Used Step: 4764760
# N update:  1200 | Mean ep 100 return:  -20.06 /Used Time: 4188.39 /Used Step: 4804800
# N update:  1210 | Mean ep 100 return:  -19.97 /Used Time: 4222.94 /Used Step: 4844840
# N update:  1220 | Mean ep 100 return:  -19.88 /Used Time: 4257.9 /Used Step: 4884880
# N update:  1230 | Mean ep 100 return:  -19.91 /Used Time: 4292.59 /Used Step: 4924920
# N update:  1240 | Mean ep 100 return:  -19.89 /Used Time: 4326.87 /Used Step: 4964960
# N update:  1250 | Mean ep 100 return:  -19.93 /Used Time: 4361.89 /Used Step: 5005000
# N update:  1260 | Mean ep 100 return:  -19.89 /Used Time: 4397.11 /Used Step: 5045040
# N update:  1270 | Mean ep 100 return:  -19.99 /Used Time: 4431.77 /Used Step: 5085080
# N update:  1280 | Mean ep 100 return:  -19.95 /Used Time: 4466.64 /Used Step: 5125120
# N update:  1290 | Mean ep 100 return:  -19.86 /Used Time: 4501.19 /Used Step: 5165160
# N update:  1300 | Mean ep 100 return:  -19.78 /Used Time: 4535.63 /Used Step: 5205200
# N update:  1310 | Mean ep 100 return:  -19.93 /Used Time: 4570.13 /Used Step: 5245240
# N update:  1320 | Mean ep 100 return:  -19.92 /Used Time: 4604.74 /Used Step: 5285280
# N update:  1330 | Mean ep 100 return:  -19.81 /Used Time: 4639.93 /Used Step: 5325320
# N update:  1340 | Mean ep 100 return:  -19.78 /Used Time: 4674.22 /Used Step: 5365360
# N update:  1350 | Mean ep 100 return:  -19.72 /Used Time: 4708.91 /Used Step: 5405400
# N update:  1360 | Mean ep 100 return:  -19.63 /Used Time: 4743.62 /Used Step: 5445440
# N update:  1370 | Mean ep 100 return:  -19.74 /Used Time: 4777.87 /Used Step: 5485480
# N update:  1380 | Mean ep 100 return:  -19.71 /Used Time: 4812.98 /Used Step: 5525520
# N update:  1390 | Mean ep 100 return:  -19.8 /Used Time: 4847.82 /Used Step: 5565560
# N update:  1400 | Mean ep 100 return:  -19.67 /Used Time: 4882.51 /Used Step: 5605600
# N update:  1410 | Mean ep 100 return:  -19.63 /Used Time: 4916.8 /Used Step: 5645640
# N update:  1420 | Mean ep 100 return:  -19.67 /Used Time: 4952.19 /Used Step: 5685680
# N update:  1430 | Mean ep 100 return:  -19.76 /Used Time: 4987.13 /Used Step: 5725720
# N update:  1440 | Mean ep 100 return:  -19.76 /Used Time: 5022.13 /Used Step: 5765760
# N update:  1450 | Mean ep 100 return:  -19.52 /Used Time: 5056.78 /Used Step: 5805800
# N update:  1460 | Mean ep 100 return:  -19.61 /Used Time: 5091.13 /Used Step: 5845840

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot(range(len(result)), result)
plt.tight_layout()
plt.show()

# %%
from matplotlib import animation

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./a2c_pong_result.gif', writer='imagemagick', fps=30)

# %%
env = wrap(gym.make('PongNoFrameskip-v4'))
s = np.array(env.reset())
total_reward = 0
frames = []

dqn = DQN()
dqn.load_model()

for t in range(10000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    a = dqn.choose_action(s, 1.0)
    # take action and get next state
    s_, r, done, info = env.step(a)
    s_ = np.array(s_)
    total_reward += r
    if done:
        break
    s = s_
env.close()
print('Total Reward : %.2f'%total_reward)
display_frames_as_gif(frames)

# %% [markdown]
# ![alt text](./a2c_pong_result.gif "segment")
