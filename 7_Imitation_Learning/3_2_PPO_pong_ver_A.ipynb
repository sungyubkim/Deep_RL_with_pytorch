# %% [markdown]
# ## 필요한 모듈 설치 확인

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import numpy as np

import random
import os
import pickle
import time
from collections import deque

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from wrappers import wrap, wrap_cover, SubprocVecEnv
from runner import Runner

# %% [markdown]
# ## 하이퍼 파라미터 정의하기

# %%
'''PPO Settings'''
TRAJ_LEN = 1000
N_OPT_EPOCHS = 4
ENT_COEF = 1e-2
CLIP_RANGE = 0.1
LAMBDA = 0.95

'''Environment Settings'''
# sequential images to define state
STATE_LEN = 4
# openai gym env name
ENV_NAME = 'BreakoutNoFrameskip-v4'
# number of environments for A2C
N_ENVS = 4
# define gym 
env = SubprocVecEnv([wrap_cover(ENV_NAME) for i in range(N_ENVS)])
# check gym setting
N_ACTIONS = env.action_space.n;print('N_ACTIONS : ',N_ACTIONS) #  6
N_STATES = env.observation_space.shape;print('N_STATES : ',N_STATES) # (4, 84, 84)
# Total simulation step
N_STEP = 10**7
# gamma for MDP
GAMMA = 0.99
# visualize for agent playing
RENDERING = False

'''Training settings'''
# check GPU usage
USE_GPU = torch.cuda.is_available()
print('USE GPU: '+str(USE_GPU))
# mini-batch size
BATCH_SIZE = 32
# learning rage
LR = 1e-4
# clip gradient
MAX_GRAD_NORM = 0.1
ZERO_GP = True
# log optimization
LOG_OPT = False

'''Save&Load Settings'''
# log frequency
LOG_FREQ = 1
# check save/load
SAVE = True
LOAD = False
# paths for predction net, target net, result log
NET_PATH = './data/model/ppo_net.pkl'
DIS_PATH = './data/model/gail_dis_net.pkl'
# Out:
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# N_ACTIONS :  4
# N_STATES :  (4, 84, 84)
# USE GPU: True
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/sungyubkim/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: <class 'wrappers.FrameStack'> doesn't implement 'reset' method, but it implements deprecated '_reset' method.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## 네트워크 구조 정의하기

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc = nn.Linear(7 * 7 * 64, 256)
        # actor
        self.actor = nn.Linear(256, N_ACTIONS)
        # critic
        self.critic = nn.Linear(256, 1)
            
        # parameter initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc(x))
        # use log_softmax for numerical stability
        action_log_prob = F.log_softmax(self.actor(x), dim=1)
        state_value = self.critic(x)

        return action_log_prob, state_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))
        
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # architecture def
        self.feature_extraction = nn.Sequential(
            nn.Conv2d(STATE_LEN, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )
        self.fc1 = nn.Linear(7 * 7 * 64, 256)
        self.action_feature = nn.Linear(N_ACTIONS, 256)
        # actor
        self.fc2 = nn.Linear(256, 1)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.orthogonal_(m.weight, gain = np.sqrt(2))
                nn.init.constant_(m.bias, 0.0)
            elif isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0.0)
            

    def forward(self, x, a):
        # x is a tensor of (m, 4, 84, 84)
        x = self.feature_extraction(x / 255.0)
        # x.size(0) : mini-batch size
        x = x.view(x.size(0), -1)
        a_onehot = torch.zeros(x.size(0), N_ACTIONS)
        if USE_GPU:
            a_onehot = a_onehot.cuda(device=0)
        a_onehot.scatter_(1, a.unsqueeze(1), 1)
        x = F.relu(self.fc1(x) * F.leaky_relu(self.action_feature(a_onehot), negative_slope=2e-1))
        action_value = self.fc2(x)

        return action_value

    def save(self, PATH):
        torch.save(self.state_dict(),PATH)

    def load(self, PATH):
        self.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## PPO 정의하기

# %%
class PPO:
    def __init__(self):
        self.net = ConvNet()
        self.dis_net = Discriminator()
        # use gpu
        if USE_GPU:
            self.net = self.net.cuda()
            self.dis_net = self.dis_net.cuda()
            
        # simulator step conter
        self.memory_counter = 0
        
        # create the replay buffer for expert
        with open( "replay.pkl", "rb" ) as f:
            self.expert_replay_buffer = pickle.load(f)
        
        # define optimizer
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=LR)
        self.dis_opt = torch.optim.RMSprop(self.dis_net.parameters(), lr=LR, alpha=0.9)
        
        # ppo clip range
        self.clip_range = CLIP_RANGE
        
    def save_model(self):
        self.net.cpu()
        self.dis_net.cpu()
        self.net.save(NET_PATH)
        self.dis_net.save(DIS_PATH)
        if USE_GPU:
            self.net.cuda()
            self.dis_net.cuda()
            
    def load_model(self):
        self.net.cpu()
        self.dis_net.cpu()
        self.net.load(NET_PATH)
        self.dis_net.load(DIS_PATH)
        if USE_GPU:
            self.net.cuda()
            self.dis_net.cuda()
        
    def choose_action(self, x):
        self.memory_counter += 1
        # Assume that x is a np.array of shape (nenvs, 4, 84, 84)
        x = torch.FloatTensor(x)
        if USE_GPU:
            x = x.cuda()
        # get action log probs and state values
        action_log_probs, state_values = self.net(x) # (nenvs, N_ACTIONS)
        probs = F.softmax(action_log_probs, dim=1).data.cpu().numpy()
        probs = (probs+1e-8)/np.sum((probs+1e-8), axis=1, keepdims=True)
        # sample actions
        actions = np.array([np.random.choice(N_ACTIONS,p=probs[i]) for i in range(len(probs))])
        # convert tensor to np.array
        action_log_probs , state_values = action_log_probs.data.cpu().numpy() , state_values.squeeze(1).data.cpu().numpy()
        # calc selected logprob
        selected_log_probs = np.array([action_log_probs[i][actions[i]] for i in range(len(probs))])
        return actions, state_values, selected_log_probs
    
    def reward_dis(self, s, a):
        s = torch.FloatTensor(s)
        a = torch.LongTensor(a)
        
        if USE_GPU:
            s , a = s.cuda(), a.cuda()
        
        d_reward = -torch.log(torch.sigmoid(self.dis_net(s, a)))
        return d_reward.squeeze(1).data.cpu().numpy()
    
    def learn_dis(self, obs, returns, masks, actions, values, selected_log_probs):
        # optimize discriminator
        b_s = torch.FloatTensor(obs)
        b_s.requires_grad = True
        b_a = torch.LongTensor(actions)
        
        # data sample from expert experience replay
        e_state_memory, e_action_memory, e_reward_memory, \
        e_next_state_memory, e_done = self.expert_replay_buffer.sample(len(b_s))
        
        e_s = torch.FloatTensor(e_state_memory)
        e_s.requires_grad = True
        e_a = torch.LongTensor(e_action_memory)
        
        if USE_GPU:
            b_s, b_a, e_s, e_a = b_s.cuda(device=0), b_a.cuda(device=0), e_s.cuda(device=0), e_a.cuda(device=0)
        
        d_policy = self.dis_net(b_s, b_a).squeeze(1) # (m)
        d_expert = self.dis_net(e_s, e_a).squeeze(1) # (m)
        
        d_loss = -torch.log(torch.sigmoid(d_policy)).mean() -torch.log(1-torch.sigmoid(d_expert)).mean()
        loss = d_loss
        
        # calc gradient penalty
        if ZERO_GP:
            b_grad = autograd.grad(d_policy, b_s, create_graph=True,
                            grad_outputs=torch.ones_like(d_policy),
                            retain_graph=True, only_inputs=True)[0].view(BATCH_SIZE, -1)
            e_grad = autograd.grad(d_expert, e_s, create_graph=True,
                            grad_outputs=torch.ones_like(d_expert),
                            retain_graph=True, only_inputs=True)[0].view(BATCH_SIZE, -1)
            b_grad = b_grad.norm(dim=1)
            e_grad = e_grad.norm(dim=1)
            gp_loss = 1e+5 * ((b_grad)**2 + (e_grad)**2).mean()
            loss += gp_loss
        
        self.dis_opt.zero_grad()
        loss.backward()
        self.dis_opt.step()
        
        return round(float(d_loss.item()), 4), round(float(gp_loss.item()), 4)

    def learn(self, obs, returns, masks, actions, values, selected_log_probs):
        
        # calculate the advantages
        advs = returns - values
        advs = (advs - advs.mean())/(advs.std() + 1e-8)
        
        # np.array -> torch.Tensor
        obs = torch.FloatTensor(obs) # (m, 4, 84, 84)
        returns = torch.FloatTensor(returns) # (m)
        advs = torch.FloatTensor(advs) # (m)
        actions = torch.LongTensor(actions) # (m)
        selected_log_probs = torch.FloatTensor(selected_log_probs) # (m)
        values = torch.FloatTensor(values) # (m)
        if USE_GPU:
            obs = obs.cuda()
            returns = returns.cuda()
            advs = advs.cuda()
            actions = actions.cuda()
            selected_log_probs = selected_log_probs.cuda()
            values = values.cuda()
        
        # get action log probs and state values
        action_log_probs, state_values = self.net(obs)
        # (m, N_ACTIONS), (m, 1)
        
        # calc probs
        probs = F.softmax(action_log_probs, dim=1)
        # (m, N_ACTIONS)
        
        # calc entropy loss
        ent_loss = ENT_COEF *((action_log_probs * probs).sum(dim=1)).mean()
        # (1)
        
        # calc log probs
        cur_log_probs = action_log_probs.gather(1,actions.unsqueeze(1))
        # cur : (m, 1)
        ratio = torch.exp(cur_log_probs.squeeze(1)-selected_log_probs)
        # (m)
        
        # actor loss
        surr1 = ratio * advs # (m)
        surr2 = torch.clamp(ratio, 1.0 - self.clip_range, 1.0 + self.clip_range)*advs # (m)
        actor_loss = -torch.min(surr1, surr2).mean() # (1)
        # critic loss
        critic_loss = F.smooth_l1_loss(state_values.squeeze(1), returns) # (1)

        loss = actor_loss + critic_loss + ent_loss # (1)
        
        actor_loss, critic_loss, ent_loss, total_loss = actor_loss.data.cpu().numpy(), \
        critic_loss.data.cpu().numpy(), ent_loss.data.cpu().numpy(), loss.data.cpu().numpy()

        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.net.parameters(), MAX_GRAD_NORM)
        self.optimizer.step()
        
        return round(float(actor_loss), 4), round(float(critic_loss), 4),\
    round(float(ent_loss), 4), round(float(total_loss), 4)

# %% [markdown]
# ## 학습

# %%
ppo = PPO()
runner = Runner(env=env, model=ppo, nsteps=TRAJ_LEN, gamma=GAMMA, lam=LAMBDA)

# model load with check
if LOAD and os.path.isfile(PRED_PATH) and os.path.isfile(TARGET_PATH):
    ppo.load_model()
    pkl_file = open(RESULT_PATH,'rb')
    result = pickle.load(pkl_file)
    pkl_file.close()
    print('Load complete!')
else:
    result = []
    print('Initialize results!')

print('Collecting experience...')

# episode step for accumulate reward 
epinfobuf = deque(maxlen=100)
# in PPO, we iterate over optimization step
nbatch = N_ENVS * TRAJ_LEN
nupdates = N_STEP// nbatch
# check learning time
start_time = time.time()

for update in range(1, nupdates+1):
    # get minibatch
    obs, returns, masks, actions, values, neglogpacs, epinfos = runner.run()
    epinfobuf.extend(epinfos)
    
    inds = np.arange(nbatch)
    for start in range(0, nbatch, BATCH_SIZE):
        end = start + BATCH_SIZE
        mbinds = inds[start:end]
        slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
        d_loss, gp_loss = ppo.learn_dis(*slices)
    
    # calculate loss
    inds = np.arange(nbatch)
    for _ in range(N_OPT_EPOCHS):
        a_losses, c_losses, e_losses, t_losses = list(), list(), list(), list()
        # shuffle indices for i.i.d.
        np.random.shuffle(inds)
        # 0 to batch_size with batch_train_size step
        for start in range(0, nbatch, BATCH_SIZE):
            end = start + BATCH_SIZE
            mbinds = inds[start:end]
            slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
            actor_loss, critic_loss, ent_loss, total_loss = ppo.learn(*slices)
            # save opt log
            a_losses.append(actor_loss)
            c_losses.append(critic_loss)
            e_losses.append(ent_loss)
            t_losses.append(total_loss)
        # print opt log
        if LOG_OPT:
            print('Iter ',_,
                 'actor loss : ',round(float(np.mean(a_losses)), 3),
                 'critic loss : ', round(float(np.mean(c_losses)), 3),
                 'ent loss : ', round(float(np.mean(e_losses)), 3),
                 'total loss : ', round(float(np.mean(t_losses)), 3))
            
    if update % LOG_FREQ == 0:
        # print log and save
        # check time interval
        time_interval = round(time.time() - start_time, 2)
        # calc mean return
        mean_100_ep_return = round(np.mean([epinfo['r'] for epinfo in epinfobuf]),2)
        result.append(mean_100_ep_return)
        # print epi log
        print('N update: ',update,
              '| Mean ep 100 return: ', mean_100_ep_return,
              '/Used Time:',time_interval,
              '/Used Step:',ppo.memory_counter*N_ENVS,
             '| Dis loss : ',d_loss,
             '| GP loss : ', gp_loss)
        # save model
        if SAVE:
            ppo.save_model()
# Out:
# Initialize results!
# Collecting experience...
# N update:  1 | Mean ep 100 return:  1.71 /Used Time: 9.48 /Used Step: 4004 | Dis loss :  1.2009 | GP loss :  0.3298
# N update:  2 | Mean ep 100 return:  1.39 /Used Time: 18.81 /Used Step: 8008 | Dis loss :  0.9293 | GP loss :  0.2144
# N update:  3 | Mean ep 100 return:  1.39 /Used Time: 28.15 /Used Step: 12012 | Dis loss :  0.9029 | GP loss :  0.2175
# N update:  4 | Mean ep 100 return:  1.34 /Used Time: 37.51 /Used Step: 16016 | Dis loss :  0.8206 | GP loss :  0.1924
# N update:  5 | Mean ep 100 return:  1.39 /Used Time: 46.9 /Used Step: 20020 | Dis loss :  0.7839 | GP loss :  0.1717
# N update:  6 | Mean ep 100 return:  1.57 /Used Time: 56.43 /Used Step: 24024 | Dis loss :  0.669 | GP loss :  0.1945
# N update:  7 | Mean ep 100 return:  1.77 /Used Time: 65.75 /Used Step: 28028 | Dis loss :  0.753 | GP loss :  0.2014
# N update:  8 | Mean ep 100 return:  1.88 /Used Time: 75.05 /Used Step: 32032 | Dis loss :  0.7546 | GP loss :  0.1574
# N update:  9 | Mean ep 100 return:  2.18 /Used Time: 84.28 /Used Step: 36036 | Dis loss :  0.5863 | GP loss :  0.1623
# N update:  10 | Mean ep 100 return:  2.35 /Used Time: 93.39 /Used Step: 40040 | Dis loss :  0.7036 | GP loss :  0.1706
# N update:  11 | Mean ep 100 return:  2.68 /Used Time: 102.53 /Used Step: 44044 | Dis loss :  0.6431 | GP loss :  0.1835
# N update:  12 | Mean ep 100 return:  2.81 /Used Time: 111.86 /Used Step: 48048 | Dis loss :  0.6669 | GP loss :  0.1662
# N update:  13 | Mean ep 100 return:  3.01 /Used Time: 121.25 /Used Step: 52052 | Dis loss :  0.5218 | GP loss :  0.1553
# N update:  14 | Mean ep 100 return:  3.31 /Used Time: 130.28 /Used Step: 56056 | Dis loss :  0.8505 | GP loss :  0.1694
# N update:  15 | Mean ep 100 return:  3.27 /Used Time: 139.42 /Used Step: 60060 | Dis loss :  0.7091 | GP loss :  0.143
# N update:  16 | Mean ep 100 return:  3.25 /Used Time: 148.59 /Used Step: 64064 | Dis loss :  0.7132 | GP loss :  0.1709
# N update:  17 | Mean ep 100 return:  3.45 /Used Time: 157.61 /Used Step: 68068 | Dis loss :  0.7581 | GP loss :  0.1768
# N update:  18 | Mean ep 100 return:  3.62 /Used Time: 166.73 /Used Step: 72072 | Dis loss :  0.928 | GP loss :  0.1627
# N update:  19 | Mean ep 100 return:  3.97 /Used Time: 175.99 /Used Step: 76076 | Dis loss :  0.8104 | GP loss :  0.185
# N update:  20 | Mean ep 100 return:  4.18 /Used Time: 185.09 /Used Step: 80080 | Dis loss :  0.6644 | GP loss :  0.1691
# N update:  21 | Mean ep 100 return:  4.4 /Used Time: 194.2 /Used Step: 84084 | Dis loss :  0.7242 | GP loss :  0.1465
# N update:  22 | Mean ep 100 return:  4.66 /Used Time: 203.54 /Used Step: 88088 | Dis loss :  0.8545 | GP loss :  0.1556
# N update:  23 | Mean ep 100 return:  4.66 /Used Time: 212.91 /Used Step: 92092 | Dis loss :  0.6795 | GP loss :  0.1558
# N update:  24 | Mean ep 100 return:  4.96 /Used Time: 221.98 /Used Step: 96096 | Dis loss :  0.6528 | GP loss :  0.1605
# N update:  25 | Mean ep 100 return:  5.21 /Used Time: 231.27 /Used Step: 100100 | Dis loss :  0.6376 | GP loss :  0.1429
# N update:  26 | Mean ep 100 return:  5.48 /Used Time: 240.31 /Used Step: 104104 | Dis loss :  0.626 | GP loss :  0.1552
# N update:  27 | Mean ep 100 return:  5.75 /Used Time: 249.25 /Used Step: 108108 | Dis loss :  0.6448 | GP loss :  0.1411
# N update:  28 | Mean ep 100 return:  6.23 /Used Time: 258.42 /Used Step: 112112 | Dis loss :  0.7347 | GP loss :  0.1309
# N update:  29 | Mean ep 100 return:  6.51 /Used Time: 267.3 /Used Step: 116116 | Dis loss :  0.6727 | GP loss :  0.1634
# N update:  30 | Mean ep 100 return:  6.59 /Used Time: 276.41 /Used Step: 120120 | Dis loss :  0.6258 | GP loss :  0.1528
# N update:  31 | Mean ep 100 return:  6.76 /Used Time: 285.47 /Used Step: 124124 | Dis loss :  0.6883 | GP loss :  0.1292
# N update:  32 | Mean ep 100 return:  7.0 /Used Time: 294.72 /Used Step: 128128 | Dis loss :  0.6927 | GP loss :  0.1634
# N update:  33 | Mean ep 100 return:  7.11 /Used Time: 303.68 /Used Step: 132132 | Dis loss :  0.7374 | GP loss :  0.1405
# N update:  34 | Mean ep 100 return:  7.35 /Used Time: 312.75 /Used Step: 136136 | Dis loss :  0.7047 | GP loss :  0.1626
# N update:  35 | Mean ep 100 return:  7.32 /Used Time: 321.85 /Used Step: 140140 | Dis loss :  0.6727 | GP loss :  0.147
# N update:  36 | Mean ep 100 return:  7.14 /Used Time: 330.88 /Used Step: 144144 | Dis loss :  0.611 | GP loss :  0.1654
# N update:  37 | Mean ep 100 return:  6.83 /Used Time: 339.84 /Used Step: 148148 | Dis loss :  0.9132 | GP loss :  0.1732
# N update:  38 | Mean ep 100 return:  6.98 /Used Time: 348.88 /Used Step: 152152 | Dis loss :  0.6646 | GP loss :  0.1647
# N update:  39 | Mean ep 100 return:  7.07 /Used Time: 357.95 /Used Step: 156156 | Dis loss :  0.758 | GP loss :  0.1441
# N update:  40 | Mean ep 100 return:  7.25 /Used Time: 366.93 /Used Step: 160160 | Dis loss :  0.6082 | GP loss :  0.1456
# N update:  41 | Mean ep 100 return:  7.33 /Used Time: 375.92 /Used Step: 164164 | Dis loss :  0.6503 | GP loss :  0.1479
# N update:  42 | Mean ep 100 return:  7.6 /Used Time: 384.78 /Used Step: 168168 | Dis loss :  0.7562 | GP loss :  0.1374
# N update:  43 | Mean ep 100 return:  7.65 /Used Time: 393.67 /Used Step: 172172 | Dis loss :  0.7504 | GP loss :  0.1538
# N update:  44 | Mean ep 100 return:  7.73 /Used Time: 402.52 /Used Step: 176176 | Dis loss :  0.8228 | GP loss :  0.1393
# N update:  45 | Mean ep 100 return:  7.82 /Used Time: 411.53 /Used Step: 180180 | Dis loss :  0.6022 | GP loss :  0.1617
# N update:  46 | Mean ep 100 return:  7.94 /Used Time: 420.58 /Used Step: 184184 | Dis loss :  0.8197 | GP loss :  0.1527
# N update:  47 | Mean ep 100 return:  8.05 /Used Time: 429.64 /Used Step: 188188 | Dis loss :  0.7989 | GP loss :  0.1357
# N update:  48 | Mean ep 100 return:  7.95 /Used Time: 438.6 /Used Step: 192192 | Dis loss :  0.6817 | GP loss :  0.1501
# N update:  49 | Mean ep 100 return:  8.17 /Used Time: 447.64 /Used Step: 196196 | Dis loss :  0.9439 | GP loss :  0.1732
# N update:  50 | Mean ep 100 return:  8.09 /Used Time: 456.55 /Used Step: 200200 | Dis loss :  0.797 | GP loss :  0.1558
# N update:  51 | Mean ep 100 return:  8.19 /Used Time: 465.44 /Used Step: 204204 | Dis loss :  0.6926 | GP loss :  0.16
# N update:  52 | Mean ep 100 return:  8.1 /Used Time: 474.27 /Used Step: 208208 | Dis loss :  0.7821 | GP loss :  0.1766
# N update:  53 | Mean ep 100 return:  8.27 /Used Time: 483.13 /Used Step: 212212 | Dis loss :  0.9011 | GP loss :  0.1442
# N update:  54 | Mean ep 100 return:  8.28 /Used Time: 492.36 /Used Step: 216216 | Dis loss :  0.8409 | GP loss :  0.1712
# N update:  55 | Mean ep 100 return:  8.25 /Used Time: 501.23 /Used Step: 220220 | Dis loss :  0.7306 | GP loss :  0.1452
# N update:  56 | Mean ep 100 return:  8.3 /Used Time: 510.15 /Used Step: 224224 | Dis loss :  0.5582 | GP loss :  0.1631
# N update:  57 | Mean ep 100 return:  8.16 /Used Time: 519.16 /Used Step: 228228 | Dis loss :  0.7911 | GP loss :  0.1342
# N update:  58 | Mean ep 100 return:  8.28 /Used Time: 528.1 /Used Step: 232232 | Dis loss :  0.696 | GP loss :  0.1647
# N update:  59 | Mean ep 100 return:  8.49 /Used Time: 536.89 /Used Step: 236236 | Dis loss :  0.5562 | GP loss :  0.1394
# N update:  60 | Mean ep 100 return:  8.47 /Used Time: 545.81 /Used Step: 240240 | Dis loss :  0.6038 | GP loss :  0.1644
# N update:  61 | Mean ep 100 return:  8.59 /Used Time: 554.76 /Used Step: 244244 | Dis loss :  0.7562 | GP loss :  0.1776
# N update:  62 | Mean ep 100 return:  8.68 /Used Time: 563.63 /Used Step: 248248 | Dis loss :  0.6327 | GP loss :  0.1441
# N update:  63 | Mean ep 100 return:  8.66 /Used Time: 572.48 /Used Step: 252252 | Dis loss :  0.7059 | GP loss :  0.1293
# N update:  64 | Mean ep 100 return:  8.64 /Used Time: 581.32 /Used Step: 256256 | Dis loss :  0.6099 | GP loss :  0.1542
# N update:  65 | Mean ep 100 return:  8.61 /Used Time: 590.35 /Used Step: 260260 | Dis loss :  0.7708 | GP loss :  0.1472
# N update:  66 | Mean ep 100 return:  8.79 /Used Time: 599.25 /Used Step: 264264 | Dis loss :  0.8431 | GP loss :  0.1615
# N update:  67 | Mean ep 100 return:  8.95 /Used Time: 608.06 /Used Step: 268268 | Dis loss :  0.6483 | GP loss :  0.1506
# N update:  68 | Mean ep 100 return:  8.84 /Used Time: 617.04 /Used Step: 272272 | Dis loss :  0.5883 | GP loss :  0.147
# N update:  69 | Mean ep 100 return:  8.99 /Used Time: 626.08 /Used Step: 276276 | Dis loss :  0.7333 | GP loss :  0.1513
# N update:  70 | Mean ep 100 return:  8.73 /Used Time: 635.09 /Used Step: 280280 | Dis loss :  0.6195 | GP loss :  0.1391
# N update:  71 | Mean ep 100 return:  8.66 /Used Time: 644.13 /Used Step: 284284 | Dis loss :  0.8874 | GP loss :  0.144
# N update:  72 | Mean ep 100 return:  8.94 /Used Time: 652.92 /Used Step: 288288 | Dis loss :  0.7037 | GP loss :  0.136
# N update:  73 | Mean ep 100 return:  8.87 /Used Time: 661.83 /Used Step: 292292 | Dis loss :  0.6532 | GP loss :  0.1307
# N update:  74 | Mean ep 100 return:  9.01 /Used Time: 670.69 /Used Step: 296296 | Dis loss :  0.7187 | GP loss :  0.132
# N update:  75 | Mean ep 100 return:  8.92 /Used Time: 679.63 /Used Step: 300300 | Dis loss :  0.5949 | GP loss :  0.1399
# N update:  76 | Mean ep 100 return:  8.97 /Used Time: 688.65 /Used Step: 304304 | Dis loss :  0.7229 | GP loss :  0.1277
# N update:  77 | Mean ep 100 return:  8.95 /Used Time: 697.63 /Used Step: 308308 | Dis loss :  0.5401 | GP loss :  0.1092
# N update:  78 | Mean ep 100 return:  8.92 /Used Time: 706.66 /Used Step: 312312 | Dis loss :  0.784 | GP loss :  0.1414
# N update:  79 | Mean ep 100 return:  9.22 /Used Time: 715.67 /Used Step: 316316 | Dis loss :  0.7106 | GP loss :  0.1599
# N update:  80 | Mean ep 100 return:  9.43 /Used Time: 724.55 /Used Step: 320320 | Dis loss :  0.7889 | GP loss :  0.1461
# N update:  81 | Mean ep 100 return:  9.41 /Used Time: 733.57 /Used Step: 324324 | Dis loss :  0.6819 | GP loss :  0.1541
# N update:  82 | Mean ep 100 return:  9.57 /Used Time: 742.3 /Used Step: 328328 | Dis loss :  0.4524 | GP loss :  0.1122
# N update:  83 | Mean ep 100 return:  9.56 /Used Time: 751.15 /Used Step: 332332 | Dis loss :  0.8039 | GP loss :  0.1428
# N update:  84 | Mean ep 100 return:  9.56 /Used Time: 760.22 /Used Step: 336336 | Dis loss :  0.6429 | GP loss :  0.1415
# N update:  85 | Mean ep 100 return:  9.75 /Used Time: 769.07 /Used Step: 340340 | Dis loss :  0.5684 | GP loss :  0.1457
# N update:  86 | Mean ep 100 return:  9.78 /Used Time: 777.95 /Used Step: 344344 | Dis loss :  0.6531 | GP loss :  0.1186
# N update:  87 | Mean ep 100 return:  10.03 /Used Time: 786.84 /Used Step: 348348 | Dis loss :  0.8031 | GP loss :  0.1497
# N update:  88 | Mean ep 100 return:  10.09 /Used Time: 795.65 /Used Step: 352352 | Dis loss :  0.6104 | GP loss :  0.1181
# N update:  89 | Mean ep 100 return:  10.28 /Used Time: 804.54 /Used Step: 356356 | Dis loss :  0.7815 | GP loss :  0.1435
# N update:  90 | Mean ep 100 return:  10.26 /Used Time: 813.46 /Used Step: 360360 | Dis loss :  0.6404 | GP loss :  0.1321
# N update:  91 | Mean ep 100 return:  10.18 /Used Time: 822.29 /Used Step: 364364 | Dis loss :  0.7224 | GP loss :  0.1458
# N update:  92 | Mean ep 100 return:  10.08 /Used Time: 831.22 /Used Step: 368368 | Dis loss :  0.5596 | GP loss :  0.1372
# N update:  93 | Mean ep 100 return:  10.05 /Used Time: 840.2 /Used Step: 372372 | Dis loss :  0.8272 | GP loss :  0.134
# N update:  94 | Mean ep 100 return:  9.99 /Used Time: 849.06 /Used Step: 376376 | Dis loss :  0.7536 | GP loss :  0.1511
# N update:  95 | Mean ep 100 return:  10.05 /Used Time: 857.89 /Used Step: 380380 | Dis loss :  0.8082 | GP loss :  0.1341
# N update:  96 | Mean ep 100 return:  10.0 /Used Time: 866.67 /Used Step: 384384 | Dis loss :  0.6052 | GP loss :  0.13
# N update:  97 | Mean ep 100 return:  9.97 /Used Time: 875.51 /Used Step: 388388 | Dis loss :  0.7703 | GP loss :  0.1367
# N update:  98 | Mean ep 100 return:  10.08 /Used Time: 884.41 /Used Step: 392392 | Dis loss :  0.7776 | GP loss :  0.1149
# N update:  99 | Mean ep 100 return:  10.04 /Used Time: 893.3 /Used Step: 396396 | Dis loss :  0.6764 | GP loss :  0.1081
# N update:  100 | Mean ep 100 return:  10.06 /Used Time: 902.39 /Used Step: 400400 | Dis loss :  0.5945 | GP loss :  0.1374
# N update:  101 | Mean ep 100 return:  9.89 /Used Time: 911.42 /Used Step: 404404 | Dis loss :  0.6518 | GP loss :  0.1335
# N update:  102 | Mean ep 100 return:  9.95 /Used Time: 920.43 /Used Step: 408408 | Dis loss :  0.8341 | GP loss :  0.1828
# N update:  103 | Mean ep 100 return:  10.16 /Used Time: 929.27 /Used Step: 412412 | Dis loss :  0.7047 | GP loss :  0.1112
# N update:  104 | Mean ep 100 return:  10.29 /Used Time: 938.36 /Used Step: 416416 | Dis loss :  0.7046 | GP loss :  0.1336
# N update:  105 | Mean ep 100 return:  10.55 /Used Time: 947.45 /Used Step: 420420 | Dis loss :  0.6891 | GP loss :  0.1279
# N update:  106 | Mean ep 100 return:  10.76 /Used Time: 956.32 /Used Step: 424424 | Dis loss :  0.6941 | GP loss :  0.1514
# N update:  107 | Mean ep 100 return:  10.96 /Used Time: 965.19 /Used Step: 428428 | Dis loss :  0.5543 | GP loss :  0.1421
# N update:  108 | Mean ep 100 return:  10.88 /Used Time: 974.04 /Used Step: 432432 | Dis loss :  1.2163 | GP loss :  0.1095
# N update:  109 | Mean ep 100 return:  11.13 /Used Time: 983.21 /Used Step: 436436 | Dis loss :  0.7662 | GP loss :  0.111
# N update:  110 | Mean ep 100 return:  11.17 /Used Time: 992.15 /Used Step: 440440 | Dis loss :  0.7664 | GP loss :  0.1562
# N update:  111 | Mean ep 100 return:  10.89 /Used Time: 1001.11 /Used Step: 444444 | Dis loss :  0.6958 | GP loss :  0.1213
# N update:  112 | Mean ep 100 return:  10.82 /Used Time: 1009.95 /Used Step: 448448 | Dis loss :  0.697 | GP loss :  0.1141
# N update:  113 | Mean ep 100 return:  10.93 /Used Time: 1018.79 /Used Step: 452452 | Dis loss :  0.5096 | GP loss :  0.1003
# N update:  114 | Mean ep 100 return:  10.89 /Used Time: 1027.79 /Used Step: 456456 | Dis loss :  0.7568 | GP loss :  0.1341
# N update:  115 | Mean ep 100 return:  10.94 /Used Time: 1036.59 /Used Step: 460460 | Dis loss :  0.6391 | GP loss :  0.1082
# N update:  116 | Mean ep 100 return:  11.06 /Used Time: 1045.48 /Used Step: 464464 | Dis loss :  0.6499 | GP loss :  0.1201
# N update:  117 | Mean ep 100 return:  11.09 /Used Time: 1054.48 /Used Step: 468468 | Dis loss :  0.7072 | GP loss :  0.1115
# N update:  118 | Mean ep 100 return:  10.92 /Used Time: 1063.25 /Used Step: 472472 | Dis loss :  0.7284 | GP loss :  0.132
# N update:  119 | Mean ep 100 return:  11.07 /Used Time: 1072.2 /Used Step: 476476 | Dis loss :  0.5701 | GP loss :  0.1171
# N update:  120 | Mean ep 100 return:  10.92 /Used Time: 1080.95 /Used Step: 480480 | Dis loss :  0.606 | GP loss :  0.1321
# N update:  121 | Mean ep 100 return:  10.92 /Used Time: 1089.79 /Used Step: 484484 | Dis loss :  0.8523 | GP loss :  0.1656
# N update:  122 | Mean ep 100 return:  10.97 /Used Time: 1098.76 /Used Step: 488488 | Dis loss :  0.593 | GP loss :  0.1095
# N update:  123 | Mean ep 100 return:  10.91 /Used Time: 1107.67 /Used Step: 492492 | Dis loss :  0.5694 | GP loss :  0.1377
# N update:  124 | Mean ep 100 return:  11.15 /Used Time: 1116.52 /Used Step: 496496 | Dis loss :  0.8972 | GP loss :  0.1448
# N update:  125 | Mean ep 100 return:  10.9 /Used Time: 1125.53 /Used Step: 500500 | Dis loss :  0.4817 | GP loss :  0.0965
# N update:  126 | Mean ep 100 return:  10.82 /Used Time: 1134.44 /Used Step: 504504 | Dis loss :  0.7133 | GP loss :  0.1453
# N update:  127 | Mean ep 100 return:  10.75 /Used Time: 1143.35 /Used Step: 508508 | Dis loss :  0.7286 | GP loss :  0.1135
# N update:  128 | Mean ep 100 return:  10.78 /Used Time: 1152.27 /Used Step: 512512 | Dis loss :  0.4914 | GP loss :  0.1326
# N update:  129 | Mean ep 100 return:  10.59 /Used Time: 1161.14 /Used Step: 516516 | Dis loss :  0.5779 | GP loss :  0.1316
# N update:  130 | Mean ep 100 return:  10.63 /Used Time: 1170.16 /Used Step: 520520 | Dis loss :  0.8155 | GP loss :  0.1344
# N update:  131 | Mean ep 100 return:  10.46 /Used Time: 1179.2 /Used Step: 524524 | Dis loss :  0.6071 | GP loss :  0.1534
# N update:  132 | Mean ep 100 return:  10.45 /Used Time: 1187.9 /Used Step: 528528 | Dis loss :  0.6764 | GP loss :  0.1357
# N update:  133 | Mean ep 100 return:  10.43 /Used Time: 1196.75 /Used Step: 532532 | Dis loss :  0.5883 | GP loss :  0.1254
# N update:  134 | Mean ep 100 return:  10.52 /Used Time: 1205.55 /Used Step: 536536 | Dis loss :  0.5994 | GP loss :  0.1385
# N update:  135 | Mean ep 100 return:  10.44 /Used Time: 1214.7 /Used Step: 540540 | Dis loss :  0.7906 | GP loss :  0.1116
# N update:  136 | Mean ep 100 return:  10.35 /Used Time: 1223.78 /Used Step: 544544 | Dis loss :  0.7367 | GP loss :  0.1043
# N update:  137 | Mean ep 100 return:  10.39 /Used Time: 1232.54 /Used Step: 548548 | Dis loss :  0.5809 | GP loss :  0.1093
# N update:  138 | Mean ep 100 return:  10.48 /Used Time: 1241.6 /Used Step: 552552 | Dis loss :  0.714 | GP loss :  0.1713
# N update:  139 | Mean ep 100 return:  10.55 /Used Time: 1250.62 /Used Step: 556556 | Dis loss :  0.7355 | GP loss :  0.1255
# N update:  140 | Mean ep 100 return:  10.65 /Used Time: 1259.61 /Used Step: 560560 | Dis loss :  0.4813 | GP loss :  0.1381
# N update:  141 | Mean ep 100 return:  10.85 /Used Time: 1268.5 /Used Step: 564564 | Dis loss :  0.6004 | GP loss :  0.1495
# N update:  142 | Mean ep 100 return:  10.92 /Used Time: 1277.57 /Used Step: 568568 | Dis loss :  0.7088 | GP loss :  0.1203
# N update:  143 | Mean ep 100 return:  11.09 /Used Time: 1286.51 /Used Step: 572572 | Dis loss :  0.7655 | GP loss :  0.1579
# N update:  144 | Mean ep 100 return:  11.27 /Used Time: 1295.51 /Used Step: 576576 | Dis loss :  0.5779 | GP loss :  0.119
# N update:  145 | Mean ep 100 return:  11.48 /Used Time: 1304.49 /Used Step: 580580 | Dis loss :  0.6352 | GP loss :  0.1378
# N update:  146 | Mean ep 100 return:  11.45 /Used Time: 1313.32 /Used Step: 584584 | Dis loss :  0.7463 | GP loss :  0.1576
# N update:  147 | Mean ep 100 return:  11.39 /Used Time: 1322.32 /Used Step: 588588 | Dis loss :  0.7002 | GP loss :  0.1422
# N update:  148 | Mean ep 100 return:  11.52 /Used Time: 1331.3 /Used Step: 592592 | Dis loss :  0.6887 | GP loss :  0.1558
# N update:  149 | Mean ep 100 return:  11.47 /Used Time: 1340.06 /Used Step: 596596 | Dis loss :  0.5985 | GP loss :  0.1321
# N update:  150 | Mean ep 100 return:  11.62 /Used Time: 1348.85 /Used Step: 600600 | Dis loss :  0.586 | GP loss :  0.1119
# N update:  151 | Mean ep 100 return:  11.78 /Used Time: 1357.69 /Used Step: 604604 | Dis loss :  0.6904 | GP loss :  0.1457
# N update:  152 | Mean ep 100 return:  11.93 /Used Time: 1366.67 /Used Step: 608608 | Dis loss :  0.5989 | GP loss :  0.1493
# N update:  153 | Mean ep 100 return:  11.84 /Used Time: 1375.72 /Used Step: 612612 | Dis loss :  0.5134 | GP loss :  0.1484
# N update:  154 | Mean ep 100 return:  12.16 /Used Time: 1384.49 /Used Step: 616616 | Dis loss :  0.7619 | GP loss :  0.1163
# N update:  155 | Mean ep 100 return:  12.18 /Used Time: 1393.37 /Used Step: 620620 | Dis loss :  0.5962 | GP loss :  0.1315
# N update:  156 | Mean ep 100 return:  12.22 /Used Time: 1402.05 /Used Step: 624624 | Dis loss :  0.596 | GP loss :  0.1084
# N update:  157 | Mean ep 100 return:  12.07 /Used Time: 1410.78 /Used Step: 628628 | Dis loss :  0.6047 | GP loss :  0.161
# N update:  158 | Mean ep 100 return:  12.2 /Used Time: 1419.48 /Used Step: 632632 | Dis loss :  0.6894 | GP loss :  0.1599
# N update:  159 | Mean ep 100 return:  12.37 /Used Time: 1428.24 /Used Step: 636636 | Dis loss :  0.5956 | GP loss :  0.1192
# N update:  160 | Mean ep 100 return:  12.74 /Used Time: 1437.17 /Used Step: 640640 | Dis loss :  0.6445 | GP loss :  0.1309
# N update:  161 | Mean ep 100 return:  12.9 /Used Time: 1446.07 /Used Step: 644644 | Dis loss :  0.6046 | GP loss :  0.1245
# N update:  162 | Mean ep 100 return:  12.99 /Used Time: 1455.04 /Used Step: 648648 | Dis loss :  0.8532 | GP loss :  0.1195
# N update:  163 | Mean ep 100 return:  13.21 /Used Time: 1464.0 /Used Step: 652652 | Dis loss :  0.7127 | GP loss :  0.1818
# N update:  164 | Mean ep 100 return:  13.4 /Used Time: 1472.69 /Used Step: 656656 | Dis loss :  0.5431 | GP loss :  0.1178
# N update:  165 | Mean ep 100 return:  13.3 /Used Time: 1481.55 /Used Step: 660660 | Dis loss :  0.6925 | GP loss :  0.1055
# N update:  166 | Mean ep 100 return:  13.4 /Used Time: 1490.39 /Used Step: 664664 | Dis loss :  0.5567 | GP loss :  0.1241
# N update:  167 | Mean ep 100 return:  13.67 /Used Time: 1499.31 /Used Step: 668668 | Dis loss :  0.5832 | GP loss :  0.1375
# N update:  168 | Mean ep 100 return:  13.81 /Used Time: 1508.2 /Used Step: 672672 | Dis loss :  0.6211 | GP loss :  0.1587
# N update:  169 | Mean ep 100 return:  13.77 /Used Time: 1517.15 /Used Step: 676676 | Dis loss :  1.1653 | GP loss :  0.152
# N update:  170 | Mean ep 100 return:  13.85 /Used Time: 1526.04 /Used Step: 680680 | Dis loss :  0.6157 | GP loss :  0.162
# N update:  171 | Mean ep 100 return:  13.93 /Used Time: 1534.88 /Used Step: 684684 | Dis loss :  0.564 | GP loss :  0.1302
# N update:  172 | Mean ep 100 return:  14.09 /Used Time: 1543.72 /Used Step: 688688 | Dis loss :  0.6456 | GP loss :  0.1384
# N update:  173 | Mean ep 100 return:  14.13 /Used Time: 1552.51 /Used Step: 692692 | Dis loss :  0.669 | GP loss :  0.1202
# N update:  174 | Mean ep 100 return:  14.12 /Used Time: 1561.25 /Used Step: 696696 | Dis loss :  0.5856 | GP loss :  0.1579
# N update:  175 | Mean ep 100 return:  14.0 /Used Time: 1570.09 /Used Step: 700700 | Dis loss :  0.5219 | GP loss :  0.1421
# N update:  176 | Mean ep 100 return:  14.07 /Used Time: 1578.92 /Used Step: 704704 | Dis loss :  0.6348 | GP loss :  0.088
# N update:  177 | Mean ep 100 return:  14.1 /Used Time: 1587.85 /Used Step: 708708 | Dis loss :  0.623 | GP loss :  0.148
# N update:  178 | Mean ep 100 return:  14.3 /Used Time: 1596.72 /Used Step: 712712 | Dis loss :  0.7777 | GP loss :  0.1649
# N update:  179 | Mean ep 100 return:  14.23 /Used Time: 1605.62 /Used Step: 716716 | Dis loss :  0.5056 | GP loss :  0.0977
# N update:  180 | Mean ep 100 return:  14.18 /Used Time: 1614.49 /Used Step: 720720 | Dis loss :  0.594 | GP loss :  0.106
# N update:  181 | Mean ep 100 return:  14.23 /Used Time: 1623.31 /Used Step: 724724 | Dis loss :  0.7747 | GP loss :  0.1415
# N update:  182 | Mean ep 100 return:  14.35 /Used Time: 1632.06 /Used Step: 728728 | Dis loss :  0.7214 | GP loss :  0.1286
# N update:  183 | Mean ep 100 return:  14.37 /Used Time: 1641.05 /Used Step: 732732 | Dis loss :  0.5249 | GP loss :  0.1418
# N update:  184 | Mean ep 100 return:  14.3 /Used Time: 1649.95 /Used Step: 736736 | Dis loss :  0.8873 | GP loss :  0.1419
# N update:  185 | Mean ep 100 return:  14.35 /Used Time: 1658.8 /Used Step: 740740 | Dis loss :  0.5444 | GP loss :  0.1421
# N update:  186 | Mean ep 100 return:  14.55 /Used Time: 1667.61 /Used Step: 744744 | Dis loss :  0.6074 | GP loss :  0.1617
# N update:  187 | Mean ep 100 return:  14.53 /Used Time: 1676.41 /Used Step: 748748 | Dis loss :  0.5074 | GP loss :  0.108
# N update:  188 | Mean ep 100 return:  14.62 /Used Time: 1685.27 /Used Step: 752752 | Dis loss :  0.6307 | GP loss :  0.1767
# N update:  189 | Mean ep 100 return:  14.5 /Used Time: 1693.93 /Used Step: 756756 | Dis loss :  0.6556 | GP loss :  0.1013
# N update:  190 | Mean ep 100 return:  14.59 /Used Time: 1702.7 /Used Step: 760760 | Dis loss :  0.5175 | GP loss :  0.1194
# N update:  191 | Mean ep 100 return:  14.46 /Used Time: 1711.58 /Used Step: 764764 | Dis loss :  0.7802 | GP loss :  0.1807
# N update:  192 | Mean ep 100 return:  14.41 /Used Time: 1720.55 /Used Step: 768768 | Dis loss :  0.607 | GP loss :  0.0943
# N update:  193 | Mean ep 100 return:  14.42 /Used Time: 1729.32 /Used Step: 772772 | Dis loss :  0.6883 | GP loss :  0.1468
# N update:  194 | Mean ep 100 return:  14.77 /Used Time: 1738.08 /Used Step: 776776 | Dis loss :  0.8619 | GP loss :  0.1565
# N update:  195 | Mean ep 100 return:  14.81 /Used Time: 1746.87 /Used Step: 780780 | Dis loss :  0.5803 | GP loss :  0.1324
# N update:  196 | Mean ep 100 return:  15.06 /Used Time: 1755.57 /Used Step: 784784 | Dis loss :  0.746 | GP loss :  0.1171
# N update:  197 | Mean ep 100 return:  15.49 /Used Time: 1764.41 /Used Step: 788788 | Dis loss :  0.6783 | GP loss :  0.1387
# N update:  198 | Mean ep 100 return:  15.32 /Used Time: 1773.19 /Used Step: 792792 | Dis loss :  0.6671 | GP loss :  0.1093
# N update:  199 | Mean ep 100 return:  15.46 /Used Time: 1782.19 /Used Step: 796796 | Dis loss :  0.6286 | GP loss :  0.1094
# N update:  200 | Mean ep 100 return:  15.59 /Used Time: 1790.96 /Used Step: 800800 | Dis loss :  0.7808 | GP loss :  0.1363
# N update:  201 | Mean ep 100 return:  15.59 /Used Time: 1799.91 /Used Step: 804804 | Dis loss :  0.5464 | GP loss :  0.0996
# N update:  202 | Mean ep 100 return:  15.77 /Used Time: 1808.88 /Used Step: 808808 | Dis loss :  0.6945 | GP loss :  0.1172
# N update:  203 | Mean ep 100 return:  15.92 /Used Time: 1817.7 /Used Step: 812812 | Dis loss :  0.6032 | GP loss :  0.1369
# N update:  204 | Mean ep 100 return:  16.1 /Used Time: 1826.34 /Used Step: 816816 | Dis loss :  0.5717 | GP loss :  0.1495
# N update:  205 | Mean ep 100 return:  16.45 /Used Time: 1835.3 /Used Step: 820820 | Dis loss :  0.539 | GP loss :  0.1128
# N update:  206 | Mean ep 100 return:  16.32 /Used Time: 1844.17 /Used Step: 824824 | Dis loss :  0.7377 | GP loss :  0.0787
# N update:  207 | Mean ep 100 return:  16.52 /Used Time: 1852.94 /Used Step: 828828 | Dis loss :  0.6032 | GP loss :  0.1595
# N update:  208 | Mean ep 100 return:  16.71 /Used Time: 1861.72 /Used Step: 832832 | Dis loss :  0.6077 | GP loss :  0.135
# N update:  209 | Mean ep 100 return:  16.8 /Used Time: 1870.54 /Used Step: 836836 | Dis loss :  0.7026 | GP loss :  0.1714
# N update:  210 | Mean ep 100 return:  16.65 /Used Time: 1879.39 /Used Step: 840840 | Dis loss :  0.6018 | GP loss :  0.1102
# N update:  211 | Mean ep 100 return:  16.65 /Used Time: 1888.09 /Used Step: 844844 | Dis loss :  0.8318 | GP loss :  0.1517
# N update:  212 | Mean ep 100 return:  16.29 /Used Time: 1897.03 /Used Step: 848848 | Dis loss :  0.6943 | GP loss :  0.1082
# N update:  213 | Mean ep 100 return:  16.18 /Used Time: 1906.14 /Used Step: 852852 | Dis loss :  0.5967 | GP loss :  0.1624
# N update:  214 | Mean ep 100 return:  15.93 /Used Time: 1915.05 /Used Step: 856856 | Dis loss :  0.641 | GP loss :  0.1121
# N update:  215 | Mean ep 100 return:  15.61 /Used Time: 1924.03 /Used Step: 860860 | Dis loss :  0.522 | GP loss :  0.1613
# N update:  216 | Mean ep 100 return:  15.2 /Used Time: 1932.88 /Used Step: 864864 | Dis loss :  0.5846 | GP loss :  0.1015
# N update:  217 | Mean ep 100 return:  15.04 /Used Time: 1941.72 /Used Step: 868868 | Dis loss :  0.9611 | GP loss :  0.1598
# N update:  218 | Mean ep 100 return:  14.38 /Used Time: 1950.54 /Used Step: 872872 | Dis loss :  0.5928 | GP loss :  0.106
# N update:  219 | Mean ep 100 return:  13.93 /Used Time: 1959.56 /Used Step: 876876 | Dis loss :  0.5347 | GP loss :  0.1189
# N update:  220 | Mean ep 100 return:  14.13 /Used Time: 1968.45 /Used Step: 880880 | Dis loss :  0.6337 | GP loss :  0.1187
# N update:  221 | Mean ep 100 return:  14.07 /Used Time: 1977.29 /Used Step: 884884 | Dis loss :  0.5288 | GP loss :  0.1235
# N update:  222 | Mean ep 100 return:  13.97 /Used Time: 1985.96 /Used Step: 888888 | Dis loss :  0.6381 | GP loss :  0.1101
# N update:  223 | Mean ep 100 return:  14.11 /Used Time: 1994.84 /Used Step: 892892 | Dis loss :  0.6067 | GP loss :  0.1428
# N update:  224 | Mean ep 100 return:  13.99 /Used Time: 2003.9 /Used Step: 896896 | Dis loss :  0.7599 | GP loss :  0.1386
# N update:  225 | Mean ep 100 return:  13.79 /Used Time: 2012.68 /Used Step: 900900 | Dis loss :  0.6538 | GP loss :  0.1019
# N update:  226 | Mean ep 100 return:  13.7 /Used Time: 2021.47 /Used Step: 904904 | Dis loss :  0.647 | GP loss :  0.1246
# N update:  227 | Mean ep 100 return:  14.05 /Used Time: 2030.32 /Used Step: 908908 | Dis loss :  0.6011 | GP loss :  0.1243
# N update:  228 | Mean ep 100 return:  14.08 /Used Time: 2039.2 /Used Step: 912912 | Dis loss :  0.597 | GP loss :  0.1368
# N update:  229 | Mean ep 100 return:  14.17 /Used Time: 2048.13 /Used Step: 916916 | Dis loss :  0.7044 | GP loss :  0.1156
# N update:  230 | Mean ep 100 return:  14.24 /Used Time: 2057.06 /Used Step: 920920 | Dis loss :  0.5558 | GP loss :  0.127
# N update:  231 | Mean ep 100 return:  14.35 /Used Time: 2066.0 /Used Step: 924924 | Dis loss :  0.6239 | GP loss :  0.1466
# N update:  232 | Mean ep 100 return:  14.85 /Used Time: 2074.72 /Used Step: 928928 | Dis loss :  0.8283 | GP loss :  0.1208
# N update:  233 | Mean ep 100 return:  14.98 /Used Time: 2083.47 /Used Step: 932932 | Dis loss :  0.6656 | GP loss :  0.2108
# N update:  234 | Mean ep 100 return:  15.1 /Used Time: 2092.28 /Used Step: 936936 | Dis loss :  0.5087 | GP loss :  0.1218
# N update:  235 | Mean ep 100 return:  14.97 /Used Time: 2101.17 /Used Step: 940940 | Dis loss :  0.5473 | GP loss :  0.1334
# N update:  236 | Mean ep 100 return:  14.99 /Used Time: 2110.02 /Used Step: 944944 | Dis loss :  0.6611 | GP loss :  0.1379
# N update:  237 | Mean ep 100 return:  14.88 /Used Time: 2118.78 /Used Step: 948948 | Dis loss :  0.6142 | GP loss :  0.1359
# N update:  238 | Mean ep 100 return:  14.86 /Used Time: 2127.72 /Used Step: 952952 | Dis loss :  0.6937 | GP loss :  0.1528
# N update:  239 | Mean ep 100 return:  14.97 /Used Time: 2136.62 /Used Step: 956956 | Dis loss :  0.8897 | GP loss :  0.1375
# N update:  240 | Mean ep 100 return:  14.96 /Used Time: 2145.63 /Used Step: 960960 | Dis loss :  0.586 | GP loss :  0.1156
# N update:  241 | Mean ep 100 return:  15.11 /Used Time: 2154.5 /Used Step: 964964 | Dis loss :  0.4602 | GP loss :  0.0795
# N update:  242 | Mean ep 100 return:  14.95 /Used Time: 2163.32 /Used Step: 968968 | Dis loss :  0.6526 | GP loss :  0.1338
# N update:  243 | Mean ep 100 return:  14.99 /Used Time: 2172.24 /Used Step: 972972 | Dis loss :  0.6445 | GP loss :  0.1005
# N update:  244 | Mean ep 100 return:  14.99 /Used Time: 2181.06 /Used Step: 976976 | Dis loss :  0.8501 | GP loss :  0.1342
# N update:  245 | Mean ep 100 return:  14.99 /Used Time: 2189.95 /Used Step: 980980 | Dis loss :  0.5414 | GP loss :  0.1523
# N update:  246 | Mean ep 100 return:  15.07 /Used Time: 2199.02 /Used Step: 984984 | Dis loss :  0.5556 | GP loss :  0.1486
# N update:  247 | Mean ep 100 return:  15.05 /Used Time: 2208.06 /Used Step: 988988 | Dis loss :  0.5406 | GP loss :  0.1422
# N update:  248 | Mean ep 100 return:  14.86 /Used Time: 2216.78 /Used Step: 992992 | Dis loss :  0.5902 | GP loss :  0.1702
# N update:  249 | Mean ep 100 return:  14.82 /Used Time: 2225.61 /Used Step: 996996 | Dis loss :  0.5387 | GP loss :  0.0996
# N update:  250 | Mean ep 100 return:  15.14 /Used Time: 2234.55 /Used Step: 1001000 | Dis loss :  0.6725 | GP loss :  0.1083
# N update:  251 | Mean ep 100 return:  14.93 /Used Time: 2243.64 /Used Step: 1005004 | Dis loss :  0.7338 | GP loss :  0.1228
# N update:  252 | Mean ep 100 return:  15.04 /Used Time: 2252.52 /Used Step: 1009008 | Dis loss :  0.5062 | GP loss :  0.1342
# N update:  253 | Mean ep 100 return:  15.15 /Used Time: 2261.53 /Used Step: 1013012 | Dis loss :  0.5503 | GP loss :  0.1658
# N update:  254 | Mean ep 100 return:  15.19 /Used Time: 2270.35 /Used Step: 1017016 | Dis loss :  0.6525 | GP loss :  0.1118
# N update:  255 | Mean ep 100 return:  15.36 /Used Time: 2279.05 /Used Step: 1021020 | Dis loss :  0.584 | GP loss :  0.1384
# N update:  256 | Mean ep 100 return:  15.28 /Used Time: 2287.86 /Used Step: 1025024 | Dis loss :  0.6828 | GP loss :  0.1851
# N update:  257 | Mean ep 100 return:  15.46 /Used Time: 2296.67 /Used Step: 1029028 | Dis loss :  0.5053 | GP loss :  0.1337
# N update:  258 | Mean ep 100 return:  15.93 /Used Time: 2305.44 /Used Step: 1033032 | Dis loss :  0.7412 | GP loss :  0.1194
# N update:  259 | Mean ep 100 return:  15.88 /Used Time: 2314.43 /Used Step: 1037036 | Dis loss :  0.526 | GP loss :  0.1416
# N update:  260 | Mean ep 100 return:  16.08 /Used Time: 2323.45 /Used Step: 1041040 | Dis loss :  0.6023 | GP loss :  0.1411
# N update:  261 | Mean ep 100 return:  16.23 /Used Time: 2332.43 /Used Step: 1045044 | Dis loss :  0.652 | GP loss :  0.163
# N update:  262 | Mean ep 100 return:  16.21 /Used Time: 2341.27 /Used Step: 1049048 | Dis loss :  0.412 | GP loss :  0.1295
# N update:  263 | Mean ep 100 return:  16.68 /Used Time: 2350.16 /Used Step: 1053052 | Dis loss :  0.4951 | GP loss :  0.18
# N update:  264 | Mean ep 100 return:  16.96 /Used Time: 2359.44 /Used Step: 1057056 | Dis loss :  0.6585 | GP loss :  0.1202
# N update:  265 | Mean ep 100 return:  17.35 /Used Time: 2368.49 /Used Step: 1061060 | Dis loss :  0.4668 | GP loss :  0.144
# N update:  266 | Mean ep 100 return:  17.49 /Used Time: 2377.24 /Used Step: 1065064 | Dis loss :  0.3428 | GP loss :  0.1366
# N update:  267 | Mean ep 100 return:  17.53 /Used Time: 2386.11 /Used Step: 1069068 | Dis loss :  0.7081 | GP loss :  0.1398
# N update:  268 | Mean ep 100 return:  17.62 /Used Time: 2394.92 /Used Step: 1073072 | Dis loss :  0.387 | GP loss :  0.1506
# N update:  269 | Mean ep 100 return:  17.73 /Used Time: 2403.72 /Used Step: 1077076 | Dis loss :  0.7553 | GP loss :  0.1431
# N update:  270 | Mean ep 100 return:  17.66 /Used Time: 2412.5 /Used Step: 1081080 | Dis loss :  0.548 | GP loss :  0.1394
# N update:  271 | Mean ep 100 return:  17.6 /Used Time: 2421.3 /Used Step: 1085084 | Dis loss :  0.7504 | GP loss :  0.1237
# N update:  272 | Mean ep 100 return:  17.53 /Used Time: 2430.12 /Used Step: 1089088 | Dis loss :  0.7118 | GP loss :  0.1274
# N update:  273 | Mean ep 100 return:  17.77 /Used Time: 2439.05 /Used Step: 1093092 | Dis loss :  0.5559 | GP loss :  0.1076
# N update:  274 | Mean ep 100 return:  17.91 /Used Time: 2447.89 /Used Step: 1097096 | Dis loss :  0.5095 | GP loss :  0.1167
# N update:  275 | Mean ep 100 return:  17.68 /Used Time: 2456.78 /Used Step: 1101100 | Dis loss :  0.7489 | GP loss :  0.1252
# N update:  276 | Mean ep 100 return:  17.54 /Used Time: 2465.64 /Used Step: 1105104 | Dis loss :  0.7931 | GP loss :  0.0972
# N update:  277 | Mean ep 100 return:  17.2 /Used Time: 2474.46 /Used Step: 1109108 | Dis loss :  0.7548 | GP loss :  0.1758
# N update:  278 | Mean ep 100 return:  17.38 /Used Time: 2483.26 /Used Step: 1113112 | Dis loss :  0.4371 | GP loss :  0.1378
# N update:  279 | Mean ep 100 return:  17.54 /Used Time: 2492.07 /Used Step: 1117116 | Dis loss :  0.4831 | GP loss :  0.1536
# N update:  280 | Mean ep 100 return:  17.43 /Used Time: 2500.87 /Used Step: 1121120 | Dis loss :  0.5672 | GP loss :  0.1232
# N update:  281 | Mean ep 100 return:  17.19 /Used Time: 2509.81 /Used Step: 1125124 | Dis loss :  0.6003 | GP loss :  0.1955
# N update:  282 | Mean ep 100 return:  17.08 /Used Time: 2518.69 /Used Step: 1129128 | Dis loss :  0.5408 | GP loss :  0.1024
# N update:  283 | Mean ep 100 return:  16.83 /Used Time: 2527.57 /Used Step: 1133132 | Dis loss :  0.7374 | GP loss :  0.1419
# N update:  284 | Mean ep 100 return:  16.78 /Used Time: 2536.36 /Used Step: 1137136 | Dis loss :  0.605 | GP loss :  0.1139
# N update:  285 | Mean ep 100 return:  16.96 /Used Time: 2545.11 /Used Step: 1141140 | Dis loss :  0.6554 | GP loss :  0.1306
# N update:  286 | Mean ep 100 return:  16.81 /Used Time: 2553.87 /Used Step: 1145144 | Dis loss :  0.6758 | GP loss :  0.1053
# N update:  287 | Mean ep 100 return:  16.71 /Used Time: 2562.67 /Used Step: 1149148 | Dis loss :  0.4966 | GP loss :  0.146
# N update:  288 | Mean ep 100 return:  17.09 /Used Time: 2571.56 /Used Step: 1153152 | Dis loss :  0.9039 | GP loss :  0.1677
# N update:  289 | Mean ep 100 return:  17.34 /Used Time: 2580.27 /Used Step: 1157156 | Dis loss :  0.9155 | GP loss :  0.1269
# N update:  290 | Mean ep 100 return:  17.37 /Used Time: 2588.97 /Used Step: 1161160 | Dis loss :  0.8662 | GP loss :  0.1341
# N update:  291 | Mean ep 100 return:  17.56 /Used Time: 2597.72 /Used Step: 1165164 | Dis loss :  0.5767 | GP loss :  0.091
# N update:  292 | Mean ep 100 return:  17.95 /Used Time: 2606.53 /Used Step: 1169168 | Dis loss :  0.6385 | GP loss :  0.1507
# N update:  293 | Mean ep 100 return:  18.09 /Used Time: 2615.36 /Used Step: 1173172 | Dis loss :  0.4993 | GP loss :  0.1434
# N update:  294 | Mean ep 100 return:  18.24 /Used Time: 2624.14 /Used Step: 1177176 | Dis loss :  0.7076 | GP loss :  0.1628
# N update:  295 | Mean ep 100 return:  18.07 /Used Time: 2632.98 /Used Step: 1181180 | Dis loss :  0.7178 | GP loss :  0.0973
# N update:  296 | Mean ep 100 return:  18.3 /Used Time: 2641.84 /Used Step: 1185184 | Dis loss :  0.6655 | GP loss :  0.1148
# N update:  297 | Mean ep 100 return:  18.47 /Used Time: 2650.68 /Used Step: 1189188 | Dis loss :  0.4849 | GP loss :  0.1426
# N update:  298 | Mean ep 100 return:  18.53 /Used Time: 2659.55 /Used Step: 1193192 | Dis loss :  0.4567 | GP loss :  0.1097
# N update:  299 | Mean ep 100 return:  18.63 /Used Time: 2668.28 /Used Step: 1197196 | Dis loss :  0.5527 | GP loss :  0.179
# N update:  300 | Mean ep 100 return:  18.73 /Used Time: 2677.02 /Used Step: 1201200 | Dis loss :  0.5533 | GP loss :  0.1371
# N update:  301 | Mean ep 100 return:  19.19 /Used Time: 2685.81 /Used Step: 1205204 | Dis loss :  0.4443 | GP loss :  0.129
# N update:  302 | Mean ep 100 return:  19.3 /Used Time: 2694.58 /Used Step: 1209208 | Dis loss :  0.6931 | GP loss :  0.1688
# N update:  303 | Mean ep 100 return:  19.34 /Used Time: 2703.41 /Used Step: 1213212 | Dis loss :  0.5238 | GP loss :  0.1446
# N update:  304 | Mean ep 100 return:  19.69 /Used Time: 2712.12 /Used Step: 1217216 | Dis loss :  0.5125 | GP loss :  0.0975
# N update:  305 | Mean ep 100 return:  20.12 /Used Time: 2721.08 /Used Step: 1221220 | Dis loss :  0.6716 | GP loss :  0.1354
# N update:  306 | Mean ep 100 return:  19.93 /Used Time: 2729.88 /Used Step: 1225224 | Dis loss :  0.4909 | GP loss :  0.1273
# N update:  307 | Mean ep 100 return:  19.64 /Used Time: 2738.61 /Used Step: 1229228 | Dis loss :  0.4974 | GP loss :  0.1319
# N update:  308 | Mean ep 100 return:  19.66 /Used Time: 2747.45 /Used Step: 1233232 | Dis loss :  0.6496 | GP loss :  0.09
# N update:  309 | Mean ep 100 return:  19.69 /Used Time: 2756.27 /Used Step: 1237236 | Dis loss :  0.5156 | GP loss :  0.1215
# N update:  310 | Mean ep 100 return:  19.75 /Used Time: 2765.11 /Used Step: 1241240 | Dis loss :  0.4423 | GP loss :  0.1257
# N update:  311 | Mean ep 100 return:  20.01 /Used Time: 2774.03 /Used Step: 1245244 | Dis loss :  0.7124 | GP loss :  0.1322
# N update:  312 | Mean ep 100 return:  20.25 /Used Time: 2782.88 /Used Step: 1249248 | Dis loss :  0.675 | GP loss :  0.0968
# N update:  313 | Mean ep 100 return:  20.3 /Used Time: 2791.73 /Used Step: 1253252 | Dis loss :  0.703 | GP loss :  0.1149
# N update:  314 | Mean ep 100 return:  20.3 /Used Time: 2800.4 /Used Step: 1257256 | Dis loss :  0.5604 | GP loss :  0.0912
# N update:  315 | Mean ep 100 return:  20.25 /Used Time: 2809.19 /Used Step: 1261260 | Dis loss :  0.6359 | GP loss :  0.1175
# N update:  316 | Mean ep 100 return:  20.15 /Used Time: 2817.97 /Used Step: 1265264 | Dis loss :  0.7593 | GP loss :  0.1332
# N update:  317 | Mean ep 100 return:  19.93 /Used Time: 2826.76 /Used Step: 1269268 | Dis loss :  0.693 | GP loss :  0.0873
# N update:  318 | Mean ep 100 return:  20.05 /Used Time: 2835.47 /Used Step: 1273272 | Dis loss :  0.4503 | GP loss :  0.101
# N update:  319 | Mean ep 100 return:  19.97 /Used Time: 2844.22 /Used Step: 1277276 | Dis loss :  0.5025 | GP loss :  0.1457
# N update:  320 | Mean ep 100 return:  19.73 /Used Time: 2853.06 /Used Step: 1281280 | Dis loss :  0.5726 | GP loss :  0.0945
# N update:  321 | Mean ep 100 return:  19.75 /Used Time: 2861.88 /Used Step: 1285284 | Dis loss :  0.5878 | GP loss :  0.1221
# N update:  322 | Mean ep 100 return:  19.64 /Used Time: 2870.65 /Used Step: 1289288 | Dis loss :  0.5296 | GP loss :  0.0826
# N update:  323 | Mean ep 100 return:  19.6 /Used Time: 2879.37 /Used Step: 1293292 | Dis loss :  0.5391 | GP loss :  0.1288
# N update:  324 | Mean ep 100 return:  19.15 /Used Time: 2888.19 /Used Step: 1297296 | Dis loss :  0.6275 | GP loss :  0.1005
# N update:  325 | Mean ep 100 return:  18.98 /Used Time: 2896.98 /Used Step: 1301300 | Dis loss :  0.5322 | GP loss :  0.1651
# N update:  326 | Mean ep 100 return:  19.26 /Used Time: 2905.86 /Used Step: 1305304 | Dis loss :  0.7646 | GP loss :  0.11
# N update:  327 | Mean ep 100 return:  18.51 /Used Time: 2914.61 /Used Step: 1309308 | Dis loss :  0.5985 | GP loss :  0.0806
# N update:  328 | Mean ep 100 return:  18.05 /Used Time: 2923.37 /Used Step: 1313312 | Dis loss :  0.7057 | GP loss :  0.14
# N update:  329 | Mean ep 100 return:  18.12 /Used Time: 2932.17 /Used Step: 1317316 | Dis loss :  0.41 | GP loss :  0.1283
# N update:  330 | Mean ep 100 return:  17.74 /Used Time: 2941.07 /Used Step: 1321320 | Dis loss :  0.5098 | GP loss :  0.1233
# N update:  331 | Mean ep 100 return:  17.46 /Used Time: 2949.9 /Used Step: 1325324 | Dis loss :  0.4262 | GP loss :  0.126
# N update:  332 | Mean ep 100 return:  17.2 /Used Time: 2959.09 /Used Step: 1329328 | Dis loss :  0.5038 | GP loss :  0.1173
# N update:  333 | Mean ep 100 return:  17.14 /Used Time: 2967.97 /Used Step: 1333332 | Dis loss :  0.5664 | GP loss :  0.156
# N update:  334 | Mean ep 100 return:  17.05 /Used Time: 2976.9 /Used Step: 1337336 | Dis loss :  0.5084 | GP loss :  0.103
# N update:  335 | Mean ep 100 return:  16.65 /Used Time: 2985.67 /Used Step: 1341340 | Dis loss :  0.6821 | GP loss :  0.1619
# N update:  336 | Mean ep 100 return:  16.17 /Used Time: 2994.51 /Used Step: 1345344 | Dis loss :  0.618 | GP loss :  0.1097
# N update:  337 | Mean ep 100 return:  15.87 /Used Time: 3003.34 /Used Step: 1349348 | Dis loss :  0.7806 | GP loss :  0.1331
# N update:  338 | Mean ep 100 return:  15.64 /Used Time: 3012.19 /Used Step: 1353352 | Dis loss :  0.7657 | GP loss :  0.1248
# N update:  339 | Mean ep 100 return:  15.44 /Used Time: 3020.96 /Used Step: 1357356 | Dis loss :  0.5631 | GP loss :  0.1017
# N update:  340 | Mean ep 100 return:  15.46 /Used Time: 3029.77 /Used Step: 1361360 | Dis loss :  0.5624 | GP loss :  0.115
# N update:  341 | Mean ep 100 return:  15.29 /Used Time: 3038.6 /Used Step: 1365364 | Dis loss :  0.5421 | GP loss :  0.0843
# N update:  342 | Mean ep 100 return:  14.87 /Used Time: 3047.47 /Used Step: 1369368 | Dis loss :  0.5997 | GP loss :  0.1482
# N update:  343 | Mean ep 100 return:  14.84 /Used Time: 3056.27 /Used Step: 1373372 | Dis loss :  0.6611 | GP loss :  0.0812
# N update:  344 | Mean ep 100 return:  15.14 /Used Time: 3065.02 /Used Step: 1377376 | Dis loss :  0.5966 | GP loss :  0.1002
# N update:  345 | Mean ep 100 return:  14.87 /Used Time: 3074.0 /Used Step: 1381380 | Dis loss :  0.6011 | GP loss :  0.1188
# N update:  346 | Mean ep 100 return:  14.81 /Used Time: 3082.8 /Used Step: 1385384 | Dis loss :  0.8634 | GP loss :  0.0915
# N update:  347 | Mean ep 100 return:  15.07 /Used Time: 3091.61 /Used Step: 1389388 | Dis loss :  0.707 | GP loss :  0.1016
# N update:  348 | Mean ep 100 return:  14.79 /Used Time: 3100.57 /Used Step: 1393392 | Dis loss :  0.5215 | GP loss :  0.1446
# N update:  349 | Mean ep 100 return:  14.87 /Used Time: 3109.4 /Used Step: 1397396 | Dis loss :  0.4696 | GP loss :  0.1274
# N update:  350 | Mean ep 100 return:  14.96 /Used Time: 3118.15 /Used Step: 1401400 | Dis loss :  0.5163 | GP loss :  0.1469
# N update:  351 | Mean ep 100 return:  15.27 /Used Time: 3127.01 /Used Step: 1405404 | Dis loss :  0.6439 | GP loss :  0.1185
# N update:  352 | Mean ep 100 return:  15.52 /Used Time: 3135.79 /Used Step: 1409408 | Dis loss :  0.5501 | GP loss :  0.134
# N update:  353 | Mean ep 100 return:  15.64 /Used Time: 3144.63 /Used Step: 1413412 | Dis loss :  0.6715 | GP loss :  0.115
# N update:  354 | Mean ep 100 return:  15.98 /Used Time: 3153.3 /Used Step: 1417416 | Dis loss :  0.6441 | GP loss :  0.1115
# N update:  355 | Mean ep 100 return:  16.35 /Used Time: 3162.04 /Used Step: 1421420 | Dis loss :  0.7164 | GP loss :  0.1197
# N update:  356 | Mean ep 100 return:  16.8 /Used Time: 3170.81 /Used Step: 1425424 | Dis loss :  0.96 | GP loss :  0.1073
# N update:  357 | Mean ep 100 return:  17.07 /Used Time: 3179.65 /Used Step: 1429428 | Dis loss :  0.6077 | GP loss :  0.0921
# N update:  358 | Mean ep 100 return:  17.51 /Used Time: 3188.48 /Used Step: 1433432 | Dis loss :  0.4695 | GP loss :  0.1428
# N update:  359 | Mean ep 100 return:  17.58 /Used Time: 3197.3 /Used Step: 1437436 | Dis loss :  0.6932 | GP loss :  0.0997
# N update:  360 | Mean ep 100 return:  17.95 /Used Time: 3206.32 /Used Step: 1441440 | Dis loss :  0.617 | GP loss :  0.1575
# N update:  361 | Mean ep 100 return:  17.84 /Used Time: 3215.24 /Used Step: 1445444 | Dis loss :  0.4582 | GP loss :  0.0984
# N update:  362 | Mean ep 100 return:  17.68 /Used Time: 3224.15 /Used Step: 1449448 | Dis loss :  0.9116 | GP loss :  0.1086
# N update:  363 | Mean ep 100 return:  17.81 /Used Time: 3232.78 /Used Step: 1453452 | Dis loss :  0.8536 | GP loss :  0.1497
# N update:  364 | Mean ep 100 return:  17.94 /Used Time: 3241.48 /Used Step: 1457456 | Dis loss :  0.689 | GP loss :  0.1091
# N update:  365 | Mean ep 100 return:  18.21 /Used Time: 3250.24 /Used Step: 1461460 | Dis loss :  0.7461 | GP loss :  0.1201
# N update:  366 | Mean ep 100 return:  18.16 /Used Time: 3259.12 /Used Step: 1465464 | Dis loss :  0.6331 | GP loss :  0.1055
# N update:  367 | Mean ep 100 return:  18.22 /Used Time: 3268.23 /Used Step: 1469468 | Dis loss :  0.7443 | GP loss :  0.1417
# N update:  368 | Mean ep 100 return:  18.25 /Used Time: 3276.96 /Used Step: 1473472 | Dis loss :  0.6221 | GP loss :  0.1201
# N update:  369 | Mean ep 100 return:  18.57 /Used Time: 3285.75 /Used Step: 1477476 | Dis loss :  0.7181 | GP loss :  0.1492
# N update:  370 | Mean ep 100 return:  18.89 /Used Time: 3294.61 /Used Step: 1481480 | Dis loss :  0.6282 | GP loss :  0.0881
# N update:  371 | Mean ep 100 return:  18.79 /Used Time: 3303.34 /Used Step: 1485484 | Dis loss :  0.6003 | GP loss :  0.1524
# N update:  372 | Mean ep 100 return:  18.47 /Used Time: 3312.17 /Used Step: 1489488 | Dis loss :  0.8199 | GP loss :  0.1276
# N update:  373 | Mean ep 100 return:  18.6 /Used Time: 3320.92 /Used Step: 1493492 | Dis loss :  0.4245 | GP loss :  0.1541
# N update:  374 | Mean ep 100 return:  18.6 /Used Time: 3329.95 /Used Step: 1497496 | Dis loss :  0.5473 | GP loss :  0.0834
# N update:  375 | Mean ep 100 return:  18.42 /Used Time: 3338.76 /Used Step: 1501500 | Dis loss :  0.5123 | GP loss :  0.1105
# N update:  376 | Mean ep 100 return:  18.26 /Used Time: 3347.79 /Used Step: 1505504 | Dis loss :  0.6184 | GP loss :  0.0914
# N update:  377 | Mean ep 100 return:  18.26 /Used Time: 3356.56 /Used Step: 1509508 | Dis loss :  0.5903 | GP loss :  0.1242
# N update:  378 | Mean ep 100 return:  18.02 /Used Time: 3365.3 /Used Step: 1513512 | Dis loss :  0.6196 | GP loss :  0.1203
# N update:  379 | Mean ep 100 return:  18.31 /Used Time: 3374.03 /Used Step: 1517516 | Dis loss :  0.8171 | GP loss :  0.1046
# N update:  380 | Mean ep 100 return:  18.68 /Used Time: 3382.9 /Used Step: 1521520 | Dis loss :  0.6543 | GP loss :  0.0755
# N update:  381 | Mean ep 100 return:  19.02 /Used Time: 3391.72 /Used Step: 1525524 | Dis loss :  0.7408 | GP loss :  0.0957
# N update:  382 | Mean ep 100 return:  19.32 /Used Time: 3400.65 /Used Step: 1529528 | Dis loss :  0.7146 | GP loss :  0.0933
# N update:  383 | Mean ep 100 return:  19.17 /Used Time: 3409.57 /Used Step: 1533532 | Dis loss :  0.6622 | GP loss :  0.1567
# N update:  384 | Mean ep 100 return:  19.14 /Used Time: 3418.29 /Used Step: 1537536 | Dis loss :  0.5995 | GP loss :  0.1584
# N update:  385 | Mean ep 100 return:  19.21 /Used Time: 3427.04 /Used Step: 1541540 | Dis loss :  0.8202 | GP loss :  0.0837
# N update:  386 | Mean ep 100 return:  19.26 /Used Time: 3435.73 /Used Step: 1545544 | Dis loss :  0.6399 | GP loss :  0.111
# N update:  387 | Mean ep 100 return:  19.68 /Used Time: 3444.43 /Used Step: 1549548 | Dis loss :  0.832 | GP loss :  0.1199
# N update:  388 | Mean ep 100 return:  19.56 /Used Time: 3453.13 /Used Step: 1553552 | Dis loss :  0.7521 | GP loss :  0.1035
# N update:  389 | Mean ep 100 return:  19.54 /Used Time: 3461.88 /Used Step: 1557556 | Dis loss :  0.6585 | GP loss :  0.0992
# ...
# N update:  622 | Mean ep 100 return:  21.05 /Used Time: 5511.97 /Used Step: 2490488 | Dis loss :  0.8683 | GP loss :  0.1092
# N update:  623 | Mean ep 100 return:  21.17 /Used Time: 5520.67 /Used Step: 2494492 | Dis loss :  0.6625 | GP loss :  0.1023
# N update:  624 | Mean ep 100 return:  21.37 /Used Time: 5529.46 /Used Step: 2498496 | Dis loss :  0.5962 | GP loss :  0.0885
# N update:  625 | Mean ep 100 return:  21.04 /Used Time: 5538.25 /Used Step: 2502500 | Dis loss :  0.6461 | GP loss :  0.1081
# N update:  626 | Mean ep 100 return:  21.1 /Used Time: 5547.08 /Used Step: 2506504 | Dis loss :  0.8361 | GP loss :  0.1529
# N update:  627 | Mean ep 100 return:  20.93 /Used Time: 5555.85 /Used Step: 2510508 | Dis loss :  0.8561 | GP loss :  0.1347
# N update:  628 | Mean ep 100 return:  21.49 /Used Time: 5564.76 /Used Step: 2514512 | Dis loss :  0.5485 | GP loss :  0.0809
# N update:  629 | Mean ep 100 return:  21.19 /Used Time: 5573.57 /Used Step: 2518516 | Dis loss :  0.51 | GP loss :  0.1285
# N update:  630 | Mean ep 100 return:  21.31 /Used Time: 5582.28 /Used Step: 2522520 | Dis loss :  0.7298 | GP loss :  0.2204
# N update:  631 | Mean ep 100 return:  21.42 /Used Time: 5591.09 /Used Step: 2526524 | Dis loss :  0.7357 | GP loss :  0.0879
# N update:  632 | Mean ep 100 return:  21.15 /Used Time: 5599.96 /Used Step: 2530528 | Dis loss :  0.4821 | GP loss :  0.1448
# N update:  633 | Mean ep 100 return:  20.84 /Used Time: 5608.95 /Used Step: 2534532 | Dis loss :  0.4919 | GP loss :  0.1549
# N update:  634 | Mean ep 100 return:  20.67 /Used Time: 5617.77 /Used Step: 2538536 | Dis loss :  0.9171 | GP loss :  0.1324
# N update:  635 | Mean ep 100 return:  20.78 /Used Time: 5626.53 /Used Step: 2542540 | Dis loss :  0.8249 | GP loss :  0.1746
# N update:  636 | Mean ep 100 return:  20.34 /Used Time: 5635.4 /Used Step: 2546544 | Dis loss :  0.8289 | GP loss :  0.1035
# N update:  637 | Mean ep 100 return:  20.16 /Used Time: 5644.06 /Used Step: 2550548 | Dis loss :  0.7476 | GP loss :  0.165
# N update:  638 | Mean ep 100 return:  19.89 /Used Time: 5652.86 /Used Step: 2554552 | Dis loss :  0.7362 | GP loss :  0.1071
# N update:  639 | Mean ep 100 return:  19.71 /Used Time: 5661.83 /Used Step: 2558556 | Dis loss :  0.6462 | GP loss :  0.1161
# N update:  640 | Mean ep 100 return:  19.31 /Used Time: 5670.67 /Used Step: 2562560 | Dis loss :  0.5016 | GP loss :  0.1541
# N update:  641 | Mean ep 100 return:  19.22 /Used Time: 5679.37 /Used Step: 2566564 | Dis loss :  0.4308 | GP loss :  0.0667
# N update:  642 | Mean ep 100 return:  19.15 /Used Time: 5688.17 /Used Step: 2570568 | Dis loss :  0.6245 | GP loss :  0.1798
# N update:  643 | Mean ep 100 return:  19.11 /Used Time: 5696.97 /Used Step: 2574572 | Dis loss :  0.6606 | GP loss :  0.0999
# N update:  644 | Mean ep 100 return:  19.76 /Used Time: 5705.77 /Used Step: 2578576 | Dis loss :  0.6733 | GP loss :  0.0857
# N update:  645 | Mean ep 100 return:  19.81 /Used Time: 5714.46 /Used Step: 2582580 | Dis loss :  0.5484 | GP loss :  0.1445
# N update:  646 | Mean ep 100 return:  19.96 /Used Time: 5723.3 /Used Step: 2586584 | Dis loss :  0.7334 | GP loss :  0.1521
# N update:  647 | Mean ep 100 return:  19.61 /Used Time: 5732.13 /Used Step: 2590588 | Dis loss :  0.5034 | GP loss :  0.1103
# N update:  648 | Mean ep 100 return:  19.48 /Used Time: 5741.05 /Used Step: 2594592 | Dis loss :  0.7958 | GP loss :  0.1345
# N update:  649 | Mean ep 100 return:  18.99 /Used Time: 5749.94 /Used Step: 2598596 | Dis loss :  0.5494 | GP loss :  0.1189
# N update:  650 | Mean ep 100 return:  18.87 /Used Time: 5758.71 /Used Step: 2602600 | Dis loss :  1.3076 | GP loss :  0.0868
# N update:  651 | Mean ep 100 return:  18.9 /Used Time: 5767.49 /Used Step: 2606604 | Dis loss :  0.5947 | GP loss :  0.066
# N update:  652 | Mean ep 100 return:  18.89 /Used Time: 5776.19 /Used Step: 2610608 | Dis loss :  0.6114 | GP loss :  0.1186
# N update:  653 | Mean ep 100 return:  18.78 /Used Time: 5784.86 /Used Step: 2614612 | Dis loss :  0.5038 | GP loss :  0.1592
# N update:  654 | Mean ep 100 return:  18.76 /Used Time: 5793.55 /Used Step: 2618616 | Dis loss :  0.6605 | GP loss :  0.0865
# N update:  655 | Mean ep 100 return:  18.8 /Used Time: 5802.59 /Used Step: 2622620 | Dis loss :  0.9124 | GP loss :  0.1352
# N update:  656 | Mean ep 100 return:  18.64 /Used Time: 5811.31 /Used Step: 2626624 | Dis loss :  1.8073 | GP loss :  0.1506
# N update:  657 | Mean ep 100 return:  18.89 /Used Time: 5820.12 /Used Step: 2630628 | Dis loss :  1.1171 | GP loss :  0.1128
# N update:  658 | Mean ep 100 return:  18.92 /Used Time: 5828.89 /Used Step: 2634632 | Dis loss :  0.593 | GP loss :  0.11
# N update:  659 | Mean ep 100 return:  19.37 /Used Time: 5837.79 /Used Step: 2638636 | Dis loss :  0.4755 | GP loss :  0.1429
# N update:  660 | Mean ep 100 return:  19.09 /Used Time: 5846.61 /Used Step: 2642640 | Dis loss :  0.7331 | GP loss :  0.1541
# N update:  661 | Mean ep 100 return:  19.22 /Used Time: 5855.37 /Used Step: 2646644 | Dis loss :  0.8389 | GP loss :  0.1039
# N update:  662 | Mean ep 100 return:  19.39 /Used Time: 5863.99 /Used Step: 2650648 | Dis loss :  0.7482 | GP loss :  0.0864
# N update:  663 | Mean ep 100 return:  19.41 /Used Time: 5872.7 /Used Step: 2654652 | Dis loss :  0.723 | GP loss :  0.0871
# N update:  664 | Mean ep 100 return:  19.89 /Used Time: 5881.56 /Used Step: 2658656 | Dis loss :  0.5399 | GP loss :  0.102
# N update:  665 | Mean ep 100 return:  19.87 /Used Time: 5890.39 /Used Step: 2662660 | Dis loss :  0.5881 | GP loss :  0.0826
# N update:  666 | Mean ep 100 return:  20.06 /Used Time: 5899.19 /Used Step: 2666664 | Dis loss :  0.8602 | GP loss :  0.0786
# N update:  667 | Mean ep 100 return:  20.15 /Used Time: 5908.1 /Used Step: 2670668 | Dis loss :  0.4774 | GP loss :  0.1441
# N update:  668 | Mean ep 100 return:  20.02 /Used Time: 5916.84 /Used Step: 2674672 | Dis loss :  0.838 | GP loss :  0.0918
# N update:  669 | Mean ep 100 return:  19.72 /Used Time: 5925.62 /Used Step: 2678676 | Dis loss :  1.1784 | GP loss :  0.099
# N update:  670 | Mean ep 100 return:  19.77 /Used Time: 5934.37 /Used Step: 2682680 | Dis loss :  0.8122 | GP loss :  0.1123
# N update:  671 | Mean ep 100 return:  20.18 /Used Time: 5943.18 /Used Step: 2686684 | Dis loss :  0.55 | GP loss :  0.123
# N update:  672 | Mean ep 100 return:  20.39 /Used Time: 5952.1 /Used Step: 2690688 | Dis loss :  0.5762 | GP loss :  0.0923
# N update:  673 | Mean ep 100 return:  20.29 /Used Time: 5960.95 /Used Step: 2694692 | Dis loss :  0.718 | GP loss :  0.1165
# N update:  674 | Mean ep 100 return:  20.29 /Used Time: 5969.76 /Used Step: 2698696 | Dis loss :  0.6101 | GP loss :  0.0814
# N update:  675 | Mean ep 100 return:  20.19 /Used Time: 5978.59 /Used Step: 2702700 | Dis loss :  0.7066 | GP loss :  0.1188
# N update:  676 | Mean ep 100 return:  19.74 /Used Time: 5987.31 /Used Step: 2706704 | Dis loss :  0.7723 | GP loss :  0.1197
# N update:  677 | Mean ep 100 return:  19.62 /Used Time: 5996.08 /Used Step: 2710708 | Dis loss :  0.6601 | GP loss :  0.118
# N update:  678 | Mean ep 100 return:  19.8 /Used Time: 6004.97 /Used Step: 2714712 | Dis loss :  0.7532 | GP loss :  0.0846
# N update:  679 | Mean ep 100 return:  19.4 /Used Time: 6013.79 /Used Step: 2718716 | Dis loss :  0.4735 | GP loss :  0.1329
# N update:  680 | Mean ep 100 return:  18.82 /Used Time: 6022.77 /Used Step: 2722720 | Dis loss :  1.531 | GP loss :  0.0931
# N update:  681 | Mean ep 100 return:  18.53 /Used Time: 6031.67 /Used Step: 2726724 | Dis loss :  0.5827 | GP loss :  0.1388
# N update:  682 | Mean ep 100 return:  18.27 /Used Time: 6040.73 /Used Step: 2730728 | Dis loss :  0.7639 | GP loss :  0.1649
# N update:  683 | Mean ep 100 return:  18.57 /Used Time: 6049.6 /Used Step: 2734732 | Dis loss :  0.8311 | GP loss :  0.0897
# N update:  684 | Mean ep 100 return:  18.44 /Used Time: 6058.36 /Used Step: 2738736 | Dis loss :  0.5399 | GP loss :  0.1603
# N update:  685 | Mean ep 100 return:  19.23 /Used Time: 6067.29 /Used Step: 2742740 | Dis loss :  0.7643 | GP loss :  0.0962
# N update:  686 | Mean ep 100 return:  19.48 /Used Time: 6076.15 /Used Step: 2746744 | Dis loss :  0.6691 | GP loss :  0.156
# N update:  687 | Mean ep 100 return:  19.98 /Used Time: 6085.01 /Used Step: 2750748 | Dis loss :  0.491 | GP loss :  0.1787
# N update:  688 | Mean ep 100 return:  19.99 /Used Time: 6093.81 /Used Step: 2754752 | Dis loss :  0.6408 | GP loss :  0.1236
# N update:  689 | Mean ep 100 return:  19.89 /Used Time: 6102.54 /Used Step: 2758756 | Dis loss :  0.644 | GP loss :  0.1722
# N update:  690 | Mean ep 100 return:  19.86 /Used Time: 6111.2 /Used Step: 2762760 | Dis loss :  0.5471 | GP loss :  0.1595
# N update:  691 | Mean ep 100 return:  20.37 /Used Time: 6119.99 /Used Step: 2766764 | Dis loss :  0.6058 | GP loss :  0.0969
# N update:  692 | Mean ep 100 return:  20.52 /Used Time: 6128.86 /Used Step: 2770768 | Dis loss :  0.7315 | GP loss :  0.1404
# N update:  693 | Mean ep 100 return:  20.87 /Used Time: 6137.62 /Used Step: 2774772 | Dis loss :  0.6238 | GP loss :  0.1373
# N update:  694 | Mean ep 100 return:  21.17 /Used Time: 6146.5 /Used Step: 2778776 | Dis loss :  0.702 | GP loss :  0.0785
# N update:  695 | Mean ep 100 return:  21.43 /Used Time: 6155.43 /Used Step: 2782780 | Dis loss :  0.5506 | GP loss :  0.092
# N update:  696 | Mean ep 100 return:  21.61 /Used Time: 6164.21 /Used Step: 2786784 | Dis loss :  0.595 | GP loss :  0.1184
# N update:  697 | Mean ep 100 return:  21.75 /Used Time: 6172.92 /Used Step: 2790788 | Dis loss :  0.4026 | GP loss :  0.1566
# N update:  698 | Mean ep 100 return:  22.11 /Used Time: 6181.67 /Used Step: 2794792 | Dis loss :  0.7996 | GP loss :  0.1078
# N update:  699 | Mean ep 100 return:  22.35 /Used Time: 6190.38 /Used Step: 2798796 | Dis loss :  0.5586 | GP loss :  0.1041
# N update:  700 | Mean ep 100 return:  22.97 /Used Time: 6199.21 /Used Step: 2802800 | Dis loss :  0.7579 | GP loss :  0.1445
# N update:  701 | Mean ep 100 return:  23.34 /Used Time: 6208.04 /Used Step: 2806804 | Dis loss :  0.6372 | GP loss :  0.0968
# N update:  702 | Mean ep 100 return:  23.19 /Used Time: 6216.87 /Used Step: 2810808 | Dis loss :  0.7615 | GP loss :  0.1207
# N update:  703 | Mean ep 100 return:  22.55 /Used Time: 6225.66 /Used Step: 2814812 | Dis loss :  0.6031 | GP loss :  0.1045
# N update:  704 | Mean ep 100 return:  22.91 /Used Time: 6234.38 /Used Step: 2818816 | Dis loss :  0.7458 | GP loss :  0.0963
# N update:  705 | Mean ep 100 return:  23.3 /Used Time: 6243.11 /Used Step: 2822820 | Dis loss :  0.9476 | GP loss :  0.0922
# N update:  706 | Mean ep 100 return:  23.3 /Used Time: 6251.86 /Used Step: 2826824 | Dis loss :  0.7149 | GP loss :  0.1074
# N update:  707 | Mean ep 100 return:  23.34 /Used Time: 6260.7 /Used Step: 2830828 | Dis loss :  0.5551 | GP loss :  0.169
# N update:  708 | Mean ep 100 return:  23.16 /Used Time: 6269.5 /Used Step: 2834832 | Dis loss :  0.6139 | GP loss :  0.0953
# N update:  709 | Mean ep 100 return:  23.25 /Used Time: 6278.33 /Used Step: 2838836 | Dis loss :  0.6108 | GP loss :  0.1431
# N update:  710 | Mean ep 100 return:  22.99 /Used Time: 6287.24 /Used Step: 2842840 | Dis loss :  0.684 | GP loss :  0.1127
# N update:  711 | Mean ep 100 return:  22.38 /Used Time: 6296.02 /Used Step: 2846844 | Dis loss :  0.7096 | GP loss :  0.1199
# N update:  712 | Mean ep 100 return:  22.29 /Used Time: 6304.73 /Used Step: 2850848 | Dis loss :  0.7521 | GP loss :  0.1234
# N update:  713 | Mean ep 100 return:  21.98 /Used Time: 6313.5 /Used Step: 2854852 | Dis loss :  0.6942 | GP loss :  0.1485
# N update:  714 | Mean ep 100 return:  21.67 /Used Time: 6322.22 /Used Step: 2858856 | Dis loss :  0.687 | GP loss :  0.1071
# N update:  715 | Mean ep 100 return:  21.37 /Used Time: 6331.03 /Used Step: 2862860 | Dis loss :  0.8382 | GP loss :  0.1245
# N update:  716 | Mean ep 100 return:  21.41 /Used Time: 6339.94 /Used Step: 2866864 | Dis loss :  0.5716 | GP loss :  0.1551
# N update:  717 | Mean ep 100 return:  21.08 /Used Time: 6348.8 /Used Step: 2870868 | Dis loss :  0.6796 | GP loss :  0.1217
# N update:  718 | Mean ep 100 return:  20.96 /Used Time: 6357.73 /Used Step: 2874872 | Dis loss :  0.7062 | GP loss :  0.1352
# N update:  719 | Mean ep 100 return:  20.6 /Used Time: 6366.48 /Used Step: 2878876 | Dis loss :  0.6013 | GP loss :  0.1218
# N update:  720 | Mean ep 100 return:  20.5 /Used Time: 6375.16 /Used Step: 2882880 | Dis loss :  1.2659 | GP loss :  0.1105
# N update:  721 | Mean ep 100 return:  20.48 /Used Time: 6383.94 /Used Step: 2886884 | Dis loss :  0.6027 | GP loss :  0.1628
# N update:  722 | Mean ep 100 return:  20.87 /Used Time: 6392.66 /Used Step: 2890888 | Dis loss :  0.7831 | GP loss :  0.1198
# N update:  723 | Mean ep 100 return:  20.73 /Used Time: 6401.4 /Used Step: 2894892 | Dis loss :  0.5676 | GP loss :  0.1075
# N update:  724 | Mean ep 100 return:  20.15 /Used Time: 6410.19 /Used Step: 2898896 | Dis loss :  0.6127 | GP loss :  0.1495
# N update:  725 | Mean ep 100 return:  20.24 /Used Time: 6419.01 /Used Step: 2902900 | Dis loss :  0.5479 | GP loss :  0.1684
# N update:  726 | Mean ep 100 return:  20.34 /Used Time: 6427.84 /Used Step: 2906904 | Dis loss :  0.8288 | GP loss :  0.0984
# N update:  727 | Mean ep 100 return:  20.47 /Used Time: 6436.66 /Used Step: 2910908 | Dis loss :  0.4477 | GP loss :  0.0671
# N update:  728 | Mean ep 100 return:  20.77 /Used Time: 6445.58 /Used Step: 2914912 | Dis loss :  0.6927 | GP loss :  0.0949
# N update:  729 | Mean ep 100 return:  20.87 /Used Time: 6454.3 /Used Step: 2918916 | Dis loss :  0.7676 | GP loss :  0.1509
# N update:  730 | Mean ep 100 return:  21.27 /Used Time: 6462.98 /Used Step: 2922920 | Dis loss :  0.6632 | GP loss :  0.1169
# N update:  731 | Mean ep 100 return:  21.54 /Used Time: 6471.73 /Used Step: 2926924 | Dis loss :  0.683 | GP loss :  0.0835
# N update:  732 | Mean ep 100 return:  21.97 /Used Time: 6480.54 /Used Step: 2930928 | Dis loss :  0.5584 | GP loss :  0.1236
# N update:  733 | Mean ep 100 return:  22.12 /Used Time: 6489.32 /Used Step: 2934932 | Dis loss :  0.4709 | GP loss :  0.1268
# N update:  734 | Mean ep 100 return:  22.5 /Used Time: 6498.15 /Used Step: 2938936 | Dis loss :  0.5049 | GP loss :  0.1684
# N update:  735 | Mean ep 100 return:  22.4 /Used Time: 6506.94 /Used Step: 2942940 | Dis loss :  0.8159 | GP loss :  0.133
# N update:  736 | Mean ep 100 return:  22.75 /Used Time: 6515.66 /Used Step: 2946944 | Dis loss :  0.4574 | GP loss :  0.1462
# N update:  737 | Mean ep 100 return:  23.17 /Used Time: 6524.66 /Used Step: 2950948 | Dis loss :  0.5003 | GP loss :  0.139
# N update:  738 | Mean ep 100 return:  23.31 /Used Time: 6533.55 /Used Step: 2954952 | Dis loss :  0.7243 | GP loss :  0.1208
# N update:  739 | Mean ep 100 return:  23.28 /Used Time: 6542.5 /Used Step: 2958956 | Dis loss :  1.3114 | GP loss :  0.1144
# N update:  740 | Mean ep 100 return:  23.64 /Used Time: 6551.45 /Used Step: 2962960 | Dis loss :  0.7076 | GP loss :  0.0971
# N update:  741 | Mean ep 100 return:  23.83 /Used Time: 6560.33 /Used Step: 2966964 | Dis loss :  0.8108 | GP loss :  0.095
# N update:  742 | Mean ep 100 return:  23.81 /Used Time: 6569.17 /Used Step: 2970968 | Dis loss :  0.6687 | GP loss :  0.1076
# N update:  743 | Mean ep 100 return:  23.87 /Used Time: 6578.02 /Used Step: 2974972 | Dis loss :  0.5693 | GP loss :  0.1455
# N update:  744 | Mean ep 100 return:  24.07 /Used Time: 6586.74 /Used Step: 2978976 | Dis loss :  0.735 | GP loss :  0.0935
# N update:  745 | Mean ep 100 return:  24.4 /Used Time: 6595.56 /Used Step: 2982980 | Dis loss :  0.5521 | GP loss :  0.1559
# N update:  746 | Mean ep 100 return:  24.0 /Used Time: 6604.33 /Used Step: 2986984 | Dis loss :  0.6773 | GP loss :  0.0671
# N update:  747 | Mean ep 100 return:  23.7 /Used Time: 6613.18 /Used Step: 2990988 | Dis loss :  0.7041 | GP loss :  0.0847
# N update:  748 | Mean ep 100 return:  23.71 /Used Time: 6622.07 /Used Step: 2994992 | Dis loss :  1.7413 | GP loss :  0.0963
# N update:  749 | Mean ep 100 return:  23.3 /Used Time: 6630.91 /Used Step: 2998996 | Dis loss :  0.978 | GP loss :  0.1512

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot(range(len(result)), result)
plt.tight_layout()
plt.show()

# %%
from matplotlib import animation

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./gail_breakout_result.gif', writer='imagemagick', fps=30)

# %%
env = wrap(gym.make('BreakoutNoFrameskip-v4'))
s = np.array(env.reset())
total_reward = 0
frames = []

for t in range(10000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    a, v, l = ppo.choose_action(np.expand_dims(s,axis=0))
    # take action and get next state
    s_, r, done, info = env.step(a)
    s_ = np.array(s_)
    total_reward += r
    if done:
        break
    s = s_
env.close()
print('Total Reward : %.2f'%total_reward)
display_frames_as_gif(frames)

# %% [markdown]
# ![alt text](./ppo_pong_result.gif "segment")
